# %% [markdown]
# # INFO
#
# This notebook will be used for construction data processing nodes and exploration purposes within Kedro framework.
#
# For better experience in previewing and manipulating data in `csv` and `parquet` format when working in VS Code I use [Data Wrangler](https://marketplace.visualstudio.com/items?itemName=ms-toolsai.datawrangler) extension.

# %%
##############################################################################
# It is recommended to create new virtual environment for each Kedro project #
##############################################################################

# Uncomment and run the line below if your environment does't have
# Kedro or any other dependencies needed.

#! pip install -r requirements.txt

# Load Kedro extention
# %load_ext kedro.ipython
# Out:
# The kedro.ipython extension is already loaded. To reload it, use:
#   %reload_ext kedro.ipython

# %% [markdown]
# # Data processing
# ---

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('max_colwidth', 500)

# %%
# Load Lending Club dataset defined as 'original_lc_dataset' in catalog.yml
lending_club = catalog.load("original_lc_dataset")
lending_club.head()
# Out:
#                     INFO     Loading data from original_lc_dataset (CSVDataset)...              data_catalog.py:389
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#    Unnamed: 0.1  Unnamed: 0         id  loan_amnt  funded_amnt  \
# 0       1746494       25450  167338079     4000.0       4000.0
# 1       2370717       81861   71016917    24000.0      24000.0
# 2       2264870      397109   39589826     5000.0       5000.0
# 3        595422       15492  134798709    24000.0      24000.0
# 4        562657       90591  127097355    14000.0      14000.0
#
#    funded_amnt_inv        term int_rate  installment grade sub_grade  \
# 0           4000.0   36 months   13.08%       134.93     B        B5
# 1          24000.0   60 months    9.16%       500.07     B        B2
# 2           5000.0   36 months   10.49%       162.49     B        B3
# 3          24000.0   60 months   11.05%       522.42     B        B4
# 4          14000.0   60 months   13.59%       322.79     C        C2
#
#         emp_title emp_length home_ownership  annual_inc verification_status  \
# 0         cashier  10+ years       MORTGAGE     48000.0     Source Verified
# 1             ABM    6 years           RENT     57000.0     Source Verified
# 2          driver  10+ years       MORTGAGE     55000.0        Not Verified
# 3             NaN        NaN       MORTGAGE     43500.0        Not Verified
# 4  Shipping Clerk  10+ years       MORTGAGE     48000.0     Source Verified
#
#     issue_d loan_status pymnt_plan  \
# 0  Mar-2020     Current          n
# 1  Feb-2016     Current          n
# 2  Jan-2015  Fully Paid          n
# 3  Jun-2018     Current          n
# 4  Jan-2018  Fully Paid          n
#
#                                                                   url  \
# 0  https://lendingclub.com/browse/loanDetail.action?loan_id=167338079
# 1   https://lendingclub.com/browse/loanDetail.action?loan_id=71016917
# 2   https://lendingclub.com/browse/loanDetail.action?loan_id=39589826
# 3  https://lendingclub.com/browse/loanDetail.action?loan_id=134798709
# 4  https://lendingclub.com/browse/loanDetail.action?loan_id=127097355
#
#               purpose                    title zip_code addr_state    dti  \
# 0    home_improvement         Home improvement    115xx         NY  20.25
# 1         credit_card  Credit card refinancing    708xx         LA  25.33
# 2         credit_card  Credit card refinancing    347xx         FL   7.22
# 3  debt_consolidation       Debt consolidation    443xx         OH  24.55
# 4  debt_consolidation       Debt consolidation    681xx         NE  24.30
#
#    delinq_2yrs earliest_cr_line  fico_range_low  fico_range_high  \
# 0          1.0         Dec-2004           665.0            669.0
# 1          0.0         Jan-2004           680.0            684.0
# 2          0.0         Apr-2010           665.0            669.0
# 3          0.0         Oct-2005           750.0            754.0
# 4          0.0         Apr-2008           735.0            739.0
#
#    inq_last_6mths  mths_since_last_delinq  mths_since_last_record  open_acc  \
# 0             0.0                    19.0                   110.0       4.0
# 1             0.0                     NaN                     NaN      10.0
# 2             0.0                     NaN                    61.0       7.0
# 3             0.0                     NaN                     NaN      15.0
# 4             1.0                     NaN                     NaN      16.0
#
#    pub_rec  revol_bal revol_util  total_acc initial_list_status  out_prncp  \
# 0      1.0     1988.0      82.8%       12.0                   w    3816.34
# 1      0.0    22697.0      64.5%       24.0                   w    4333.29
# 2      1.0     6001.0      52.6%        9.0                   f       0.00
# 3      0.0     6573.0      12.1%       23.0                   w   16317.69
# 4      0.0    11894.0      27.1%       23.0                   w       0.00
#
#    out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 0        3816.34    266.950000           266.95           183.66
# 1        4333.29  25496.160000         25496.16         19666.71
# 2           0.00   5846.672836          5846.67          5000.00
# 3       16317.69  12000.930000         12000.93          7682.31
# 4           0.00  16605.680000         16605.68         14000.00
#
#    total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee  \
# 0          83.29                 0.0         0.0                      0.0
# 1        5829.45                 0.0         0.0                      0.0
# 2         846.67                 0.0         0.0                      0.0
# 3        4318.62                 0.0         0.0                      0.0
# 4        2605.68                 0.0         0.0                      0.0
#
#   last_pymnt_d  last_pymnt_amnt next_pymnt_d last_credit_pull_d  \
# 0     May-2020           134.93     Jun-2020           May-2020
# 1     May-2020           500.07     Jun-2020           May-2020
# 2     Jan-2018           162.43          NaN           May-2020
# 3     May-2020           522.42     Jun-2020           May-2020
# 4     Jul-2019         11128.82          NaN           Feb-2020
#
#    last_fico_range_high  last_fico_range_low  collections_12_mths_ex_med  \
# 0                 669.0                665.0                         1.0
# 1                 704.0                700.0                         0.0
# 2                 789.0                785.0                         0.0
# 3                 749.0                745.0                         0.0
# 4                 779.0                775.0                         0.0
#
#    mths_since_last_major_derog  policy_code application_type  \
# 0                          NaN          1.0       Individual
# 1                          NaN          1.0       Individual
# 2                          NaN          1.0       Individual
# 3                          NaN          1.0       Individual
# 4                          NaN          1.0       Individual
#
#    annual_inc_joint  dti_joint verification_status_joint  acc_now_delinq  \
# 0               NaN        NaN                       NaN             0.0
# 1               NaN        NaN                       NaN             0.0
# 2               NaN        NaN                       NaN             0.0
# 3               NaN        NaN                       NaN             0.0
# 4               NaN        NaN                       NaN             0.0
#
#    tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  open_il_12m  \
# 0        3832.0     259024.0          0.0          1.0          0.0
# 1           0.0      61815.0          0.0          3.0          0.0
# 2           0.0     159131.0          NaN          NaN          NaN
# 3           0.0     104590.0          2.0          1.0          0.0
# 4           0.0      90253.0          2.0          2.0          1.0
#
#    open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 0          1.0                16.0        9960.0     56.0          0.0
# 1          3.0                14.0       39118.0     72.0          1.0
# 2          NaN                 NaN           NaN      NaN          NaN
# 3          1.0                17.0       11947.0     60.0          2.0
# 4          1.0                 7.0       22953.0     60.0          3.0
#
#    open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  total_cu_tl  \
# 0          0.0         0.0      59.0            2400.0     1.0          0.0
# 1          1.0      2137.0      67.0           35200.0     0.0          7.0
# 2          NaN         NaN       NaN           11400.0     NaN          NaN
# 3          3.0      2223.0      25.0           54500.0     2.0          0.0
# 4          4.0      3907.0      43.0           43900.0     1.0          0.0
#
#    inq_last_12m  acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  bc_util  \
# 0           0.0                   1.0      64756.0             NaN      NaN
# 1           0.0                   4.0       6182.0          7741.0     40.5
# 2           NaN                   4.0      22733.0          4521.0     54.8
# 3           2.0                   4.0       6973.0         43140.0     12.0
# 4           2.0                   5.0       5641.0         17318.0     39.9
#
#    chargeoff_within_12_mths  delinq_amnt  mo_sin_old_il_acct  \
# 0                       0.0          0.0               179.0
# 1                       0.0          0.0               145.0
# 2                       0.0          0.0                57.0
# 3                       0.0          0.0                37.0
# 4                       0.0          0.0                72.0
#
#    mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  \
# 0                  75.0                   38.0            16.0       2.0
# 1                 137.0                    7.0             7.0       0.0
# 2                  57.0                   14.0             9.0       1.0
# 3                 132.0                    1.0             1.0       2.0
# 4                 117.0                    6.0             6.0       2.0
#
#    mths_since_recent_bc  mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 0                   NaN                      19.0                   16.0
# 1                   7.0                       NaN                   24.0
# 2                  14.0                       NaN                    1.0
# 3                   1.0                       NaN                    3.0
# 4                   6.0                       NaN                    5.0
#
#    mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 0                            19.0                    1.0             0.0
# 1                             NaN                    0.0             3.0
# 2                             NaN                    0.0             3.0
# 3                             NaN                    1.0             6.0
# 4                             NaN                    0.0             4.0
#
#    num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 0              2.0          0.0        1.0        5.0            2.0
# 1              5.0          5.0        6.0       15.0            7.0
# 2              5.0          3.0        3.0        2.0            5.0
# 3              7.0         11.0       16.0        2.0           13.0
# 4              5.0          5.0        6.0        5.0           13.0
#
#    num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 0            5.0                  2.0       4.0               0.0
# 1            9.0                  5.0      10.0               0.0
# 2            6.0                  5.0       7.0               0.0
# 3           19.0                  7.0      15.0               0.0
# 4           16.0                  5.0      16.0               0.0
#
#    num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 0           0.0                 0.0                 0.0            75.0
# 1           0.0                 0.0                 1.0            95.8
# 2           0.0                 0.0                 1.0           100.0
# 3           0.0                 0.0                 2.0            95.7
# 4           0.0                 0.0                 4.0           100.0
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0               NaN                   1.0        0.0         395328.0
# 1              60.0                   0.0        0.0          88154.0
# 2              33.3                   0.0        1.0         171118.0
# 3               0.0                   0.0        0.0         202606.0
# 4               0.0                   0.0        0.0         152081.0
#
#    total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0            11948.0             0.0                     17928.0
# 1            61815.0         13000.0                     52954.0
# 2            13124.0         10000.0                      7526.0
# 3            18520.0         49000.0                     20000.0
# 4            34847.0         28800.0                     38181.0
#
#    revol_bal_joint  sec_app_fico_range_low  sec_app_fico_range_high  \
# 0              NaN                     NaN                      NaN
# 1              NaN                     NaN                      NaN
# 2              NaN                     NaN                      NaN
# 3              NaN                     NaN                      NaN
# 4              NaN                     NaN                      NaN
#
#   sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# 0                      NaN                     NaN               NaN
# 1                      NaN                     NaN               NaN
# 2                      NaN                     NaN               NaN
# 3                      NaN                     NaN               NaN
# 4                      NaN                     NaN               NaN
#
#    sec_app_open_acc  sec_app_revol_util  sec_app_open_act_il  \
# 0               NaN                 NaN                  NaN
# 1               NaN                 NaN                  NaN
# 2               NaN                 NaN                  NaN
# 3               NaN                 NaN                  NaN
# 4               NaN                 NaN                  NaN
#
#    sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# 0                    NaN                               NaN
# 1                    NaN                               NaN
# 2                    NaN                               NaN
# 3                    NaN                               NaN
# 4                    NaN                               NaN
#
#    sec_app_collections_12_mths_ex_med hardship_flag hardship_type  \
# 0                                 NaN             N           NaN
# 1                                 NaN             N           NaN
# 2                                 NaN             N           NaN
# 3                                 NaN             N           NaN
# 4                                 NaN             N           NaN
#
#   hardship_reason hardship_status  deferral_term  hardship_amount  \
# 0             NaN             NaN            NaN              NaN
# 1             NaN             NaN            NaN              NaN
# 2             NaN             NaN            NaN              NaN
# 3             NaN             NaN            NaN              NaN
# 4             NaN             NaN            NaN              NaN
#
#   hardship_start_date hardship_end_date payment_plan_start_date  \
# 0                 NaN               NaN                     NaN
# 1                 NaN               NaN                     NaN
# 2                 NaN               NaN                     NaN
# 3                 NaN               NaN                     NaN
# 4                 NaN               NaN                     NaN
#
#    hardship_length  hardship_dpd hardship_loan_status  \
# 0              NaN           NaN                  NaN
# 1              NaN           NaN                  NaN
# 2              NaN           NaN                  NaN
# 3              NaN           NaN                  NaN
# 4              NaN           NaN                  NaN
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                         NaN                             NaN
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
#
#    hardship_last_payment_amount debt_settlement_flag
# 0                           NaN                    N
# 1                           NaN                    N
# 2                           NaN                    N
# 3                           NaN                    N
# 4                           NaN                    N

# %% [markdown]
# ## Dataset Dictionary

# %%
# Load dictionary
lc_dict = catalog.load("lc_dataset_dictionary")
lc_dict.LoanStatNew = lc_dict.LoanStatNew.str.strip()
lc_dict = lc_dict.set_index('LoanStatNew', drop=True)
lc_dict.drop(np.nan, inplace=True)
lc_dict
# Out:
# [11/04/24 13:45:58] INFO     Loading data from lc_dataset_dictionary (ExcelDataset)...          data_catalog.py:389
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                                                                                                                                                                                                                                           Description
# LoanStatNew
# acc_now_delinq                                                                                                                                                                                                        The number of accounts on which the borrower is now delinquent.
# acc_open_past_24mths                                                                                                                                                                                                                       Number of trades opened in past 24 months.
# addr_state                                                                                                                                                                                                                 The state provided by the borrower in the loan application
# all_util                                                                                                                                                                                                                                        Balance to credit limit on all trades
# annual_inc                                                                                                                                                                                              The self-reported annual income provided by the borrower during registration.
# annual_inc_joint                                                                                                                                                                            The combined self-reported annual income provided by the co-borrowers during registration
# application_type                                                                                                                                                                 Indicates whether the loan is an individual application or a joint application with two co-borrowers
# avg_cur_bal                                                                                                                                                                                                                                   Average current balance of all accounts
# bc_open_to_buy                                                                                                                                                                                                                              Total open to buy on revolving bankcards.
# bc_util                                                                                                                                                                                         Ratio of total current balance to high credit/credit limit for all bankcard accounts.
# chargeoff_within_12_mths                                                                                                                                                                                                                       Number of charge-offs within 12 months
# collection_recovery_fee                                                                                                                                                                                                                                post charge off collection fee
# collections_12_mths_ex_med                                                                                                                                                                                           Number of collections in 12 months excluding medical collections
# debt_settlement_flag                                                                                                                                                               Flags whether or not the borrower, who has charged-off, is working with a debt-settlement company.
# debt_settlement_flag_date                                                                                                                                                                                           The most recent date that the Debt_Settlement_Flag has been set
# deferral_term                                                                                                                                           Amount of months that the borrower is expected to pay less than the contractual monthly payment amount due to a hardship plan
# delinq_2yrs                                                                                                                                                              The number of 30+ days past-due incidences of delinquency in the borrower's credit file for the past 2 years
# delinq_amnt                                                                                                                                                                                        The past-due amount owed for the accounts on which the borrower is now delinquent.
# desc                                                                                                                                                                                                                                        Loan description provided by the borrower
# disbursement_method                                                                                                                                                                       The method by which the borrower receives their loan. Possible values are: CASH, DIRECT_PAY
# dti                                                                          A ratio calculated using the borrower’s total monthly debt payments on the total debt obligations, excluding mortgage and the requested LC loan, divided by the borrower’s self-reported monthly income.
# dti_joint                                                          A ratio calculated using the co-borrowers' total monthly payments on the total debt obligations, excluding mortgages and the requested LC loan, divided by the co-borrowers' combined self-reported monthly income
# earliest_cr_line                                                                                                                                                                                                    The month the borrower's earliest reported credit line was opened
# emp_length                                                                                                                                         Employment length in years. Possible values are between 0 and 10 where 0 means less than one year and 10 means ten or more years.
# emp_title                                                                                                                                                                                                         The job title supplied by the Borrower when applying for the loan.*
# fico_range_high                                                                                                                                                                                          The upper boundary range the borrower’s FICO at loan origination belongs to.
# fico_range_low                                                                                                                                                                                           The lower boundary range the borrower’s FICO at loan origination belongs to.
# funded_amnt                                                                                                                                                                                                            The total amount committed to that loan at that point in time.
# funded_amnt_inv                                                                                                                                                                                          The total amount committed by investors for that loan at that point in time.
# grade                                                                                                                                                                                                                                                          LC assigned loan grade
# hardship_amount                                                                                                                                                             The interest payment that the borrower has committed to make each month while they are on a hardship plan
# hardship_dpd                                                                                                                                                                                                                 Account days past due as of the hardship plan start date
# hardship_end_date                                                                                                                                                                                                                            The end date of the hardship plan period
# hardship_flag                                                                                                                                                                                                                 Flags whether or not the borrower is on a hardship plan
# hardship_last_payment_amount                                                                                                                                                                                               The last payment amount as of the hardship plan start date
# hardship_length                                                                                                                                                           The number of months the borrower will make smaller payments than normally obligated due to a hardship plan
# hardship_loan_status                                                                                                                                                                                                                   Loan Status as of the hardship plan start date
# hardship_payoff_balance_amount                                                                                                                                                                                           The payoff balance amount as of the hardship plan start date
# hardship_reason                                                                                                                                                                                                                    Describes the reason the hardship plan was offered
# hardship_start_date                                                                                                                                                                                                                        The start date of the hardship plan period
# hardship_status                                                                                                                                                                                     Describes if the hardship plan is active, pending, canceled, completed, or broken
# hardship_type                                                                                                                                                                                                                                    Describes the hardship plan offering
# home_ownership                                                                                                                  The home ownership status provided by the borrower during registration or obtained from the credit report. Our values are: RENT, OWN, MORTGAGE, OTHER
# id                                                                                                                                                                                                                                      A unique LC assigned ID for the loan listing.
# il_util                                                                                                                                                                                                Ratio of total current balance to high credit/credit limit on all install acct
# initial_list_status                                                                                                                                                                                                The initial listing status of the loan. Possible values are – W, F
# inq_fi                                                                                                                                                                                                                                           Number of personal finance inquiries
# inq_last_12m                                                                                                                                                                                                                             Number of credit inquiries in past 12 months
# inq_last_6mths                                                                                                                                                                                       The number of inquiries in past 6 months (excluding auto and mortgage inquiries)
# installment                                                                                                                                                                                                          The monthly payment owed by the borrower if the loan originates.
# int_rate                                                                                                                                                                                                                                                    Interest Rate on the loan
# issue_d                                                                                                                                                                                                                                           The month which the loan was funded
# last_credit_pull_d                                                                                                                                                                                                               The most recent month LC pulled credit for this loan
# last_fico_range_high                                                                                                                                                                                             The upper boundary range the borrower’s last FICO pulled belongs to.
# last_fico_range_low                                                                                                                                                                                              The lower boundary range the borrower’s last FICO pulled belongs to.
# last_pymnt_amnt                                                                                                                                                                                                                                    Last total payment amount received
# last_pymnt_d                                                                                                                                                                                                                                          Last month payment was received
# loan_amnt                                                                                                The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value.
# loan_status                                                                                                                                                                                                                                                Current status of the loan
# max_bal_bc                                                                                                                                                                                                                     Maximum current balance owed on all revolving accounts
# member_id                                                                                                                                                                                                                            A unique LC assigned Id for the borrower member.
# mo_sin_old_il_acct                                                                                                                                                                                                                Months since oldest bank installment account opened
# mo_sin_old_rev_tl_op                                                                                                                                                                                                                     Months since oldest revolving account opened
# mo_sin_rcnt_rev_tl_op                                                                                                                                                                                                               Months since most recent revolving account opened
# mo_sin_rcnt_tl                                                                                                                                                                                                                                Months since most recent account opened
# mort_acc                                                                                                                                                                                                                                                 Number of mortgage accounts.
# mths_since_last_delinq                                                                                                                                                                                                    The number of months since the borrower's last delinquency.
# mths_since_last_major_derog                                                                                                                                                                                                           Months since most recent 90-day or worse rating
# mths_since_last_record                                                                                                                                                                                                             The number of months since the last public record.
# mths_since_rcnt_il                                                                                                                                                                                                               Months since most recent installment accounts opened
# mths_since_recent_bc                                                                                                                                                                                                                Months since most recent bankcard account opened.
# mths_since_recent_bc_dlq                                                                                                                                                                                                                Months since most recent bankcard delinquency
# mths_since_recent_inq                                                                                                                                                                                                                               Months since most recent inquiry.
# mths_since_recent_revol_delinq                                                                                                                                                                                                        Months since most recent revolving delinquency.
# next_pymnt_d                                                                                                                                                                                                                                              Next scheduled payment date
# num_accts_ever_120_pd                                                                                                                                                                                                               Number of accounts ever 120 or more days past due
# num_actv_bc_tl                                                                                                                                                                                                                           Number of currently active bankcard accounts
# num_actv_rev_tl                                                                                                                                                                                                                           Number of currently active revolving trades
# num_bc_sats                                                                                                                                                                                                                                  Number of satisfactory bankcard accounts
# num_bc_tl                                                                                                                                                                                                                                                 Number of bankcard accounts
# num_il_tl                                                                                                                                                                                                                                              Number of installment accounts
# num_op_rev_tl                                                                                                                                                                                                                                       Number of open revolving accounts
# num_rev_accts                                                                                                                                                                                                                                            Number of revolving accounts
# num_rev_tl_bal_gt_0                                                                                                                                                                                                                        Number of revolving trades with balance >0
# num_sats                                                                                                                                                                                                                                              Number of satisfactory accounts
# num_tl_120dpd_2m                                                                                                                                                                                            Number of accounts currently 120 days past due (updated in past 2 months)
# num_tl_30dpd                                                                                                                                                                                                 Number of accounts currently 30 days past due (updated in past 2 months)
# num_tl_90g_dpd_24m                                                                                                                                                                                                      Number of accounts 90 or more days past due in last 24 months
# num_tl_op_past_12m                                                                                                                                                                                                                        Number of accounts opened in past 12 months
# open_acc                                                                                                                                                                                                               The number of open credit lines in the borrower's credit file.
# open_acc_6m                                                                                                                                                                                                                                    Number of open trades in last 6 months
# open_act_il                                                                                                                                                                                                                             Number of currently active installment trades
# open_il_12m                                                                                                                                                                                                                   Number of installment accounts opened in past 12 months
# open_il_24m                                                                                                                                                                                                                   Number of installment accounts opened in past 24 months
# open_rv_12m                                                                                                                                                                                                                       Number of revolving trades opened in past 12 months
# open_rv_24m                                                                                                                                                                                                                       Number of revolving trades opened in past 24 months
# orig_projected_additional_accrued_interest                      The original projected additional interest amount that will accrue for the given hardship payment plan as of the Hardship Start Date. This field will be null if the borrower has broken their hardship payment plan.
# out_prncp                                                                                                                                                                                                                     Remaining outstanding principal for total amount funded
# out_prncp_inv                                                                                                                                                                                         Remaining outstanding principal for portion of total amount funded by investors
# payment_plan_start_date                     The day the first hardship plan payment is due. For example, if a borrower has a hardship plan period of 3 months, the start date is the start of the three-month period in which the borrower is allowed to make interest-only payments.
# pct_tl_nvr_dlq                                                                                                                                                                                                                                     Percent of trades never delinquent
# percent_bc_gt_75                                                                                                                                                                                                                  Percentage of all bankcard accounts > 75% of limit.
# policy_code                                                                                                                                                                                       publicly available policy_code=1\nnew products not publicly available policy_code=2
# pub_rec                                                                                                                                                                                                                                           Number of derogatory public records
# pub_rec_bankruptcies                                                                                                                                                                                                                             Number of public record bankruptcies
# purpose                                                                                                                                                                                                                    A category provided by the borrower for the loan request.
# pymnt_plan                                                                                                                                                                                                             Indicates if a payment plan has been put in place for the loan
# recoveries                                                                                                                                                                                                                                             post charge off gross recovery
# revol_bal                                                                                                                                                                                                                                              Total credit revolving balance
# revol_bal_joint                                                                                                                                                                                        Sum of revolving credit balance of the co-borrowers, net of duplicate balances
# revol_util                                                                                                                                                 Revolving line utilization rate, or the amount of credit the borrower is using relative to all available revolving credit.
# sec_app_chargeoff_within_12_mths                                                                                                                                                       Number of charge-offs within last 12 months at time of application for the secondary applicant
# sec_app_collections_12_mths_ex_med                                                                                                                       Number of collections within last 12 months excluding medical collections at time of application for the secondary applicant
# sec_app_earliest_cr_line                                                                                                                                                                                      Earliest credit line at time of application for the secondary applicant
# sec_app_fico_range_high                                                                                                                                                                                                                  FICO range (low) for the secondary applicant
# sec_app_fico_range_low                                                                                                                                                                                                                  FICO range (high) for the secondary applicant
# sec_app_inq_last_6mths                                                                                                                                                                       Credit inquiries in the last 6 months at time of application for the secondary applicant
# sec_app_mort_acc                                                                                                                                                                                       Number of mortgage accounts at time of application for the secondary applicant
# sec_app_mths_since_last_major_derog                                                                                                                                                Months since most recent 90-day or worse rating at time of application for the secondary applicant
# sec_app_num_rev_accts                                                                                                                                                                                 Number of revolving accounts at time of application for the secondary applicant
# sec_app_open_acc                                                                                                                                                                                             Number of open trades at time of application for the secondary applicant
# sec_app_open_act_il                                                                                                                                                                  Number of currently active installment trades at time of application for the secondary applicant
# sec_app_revol_util                                                                                                                                                                              Ratio of total current balance to high credit/credit limit for all revolving accounts
# settlement_amount                                                                                                                                                                                                          The loan amount that the borrower has agreed to settle for
# settlement_date                                                                                                                                                                                                              The date that the borrower agrees to the settlement plan
# settlement_percentage                                                                                                                                                                                  The settlement amount as a percentage of the payoff balance amount on the loan
# settlement_status                                                                                                                                               The status of the borrower’s settlement plan. Possible values are: COMPLETE, ACTIVE, BROKEN, CANCELLED, DENIED, DRAFT
# settlement_term                                                                                                                                                                                                 The number of months that the borrower will be on the settlement plan
# sub_grade                                                                                                                                                                                                                                                   LC assigned loan subgrade
# tax_liens                                                                                                                                                                                                                                                         Number of tax liens
# term                                                                                                                                                                                             The number of payments on the loan. Values are in months and can be either 36 or 60.
# title                                                                                                                                                                                                                                         The loan title provided by the borrower
# tot_coll_amt                                                                                                                                                                                                                                       Total collection amounts ever owed
# tot_cur_bal                                                                                                                                                                                                                                     Total current balance of all accounts
# tot_hi_cred_lim                                                                                                                                                                                                                                        Total high credit/credit limit
# total_acc                                                                                                                                                                                                    The total number of credit lines currently in the borrower's credit file
# total_bal_ex_mort                                                                                                                                                                                                                             Total credit balance excluding mortgage
# total_bal_il                                                                                                                                                                                                                        Total current balance of all installment accounts
# total_bc_limit                                                                                                                                                                                                                                Total bankcard high credit/credit limit
# total_cu_tl                                                                                                                                                                                                                                                  Number of finance trades
# total_il_high_credit_limit                                                                                                                                                                                                                 Total installment high credit/credit limit
# total_pymnt                                                                                                                                                                                                                         Payments received to date for total amount funded
# total_pymnt_inv                                                                                                                                                                                             Payments received to date for portion of total amount funded by investors
# total_rec_int                                                                                                                                                                                                                                               Interest received to date
# total_rec_late_fee                                                                                                                                                                                                                                         Late fees received to date
# total_rec_prncp                                                                                                                                                                                                                                            Principal received to date
# total_rev_hi_lim                                                                                                                                                                                                                             Total revolving high credit/credit limit
# url                                                                                                                                                                                                                                            URL for the LC page with listing data.
# verification_status                                                                                                                                                                        Indicates if income was verified by LC, not verified, or if the income source was verified
# verified_status_joint                                                                                                                                              Indicates if the co-borrowers' joint income was verified by LC, not verified, or if the income source was verified
# zip_code                                                                                                                                                                                        The first 3 numbers of the zip code provided by the borrower in the loan application.

# %% [markdown]
# ## Converting strings to appropriate formats

# %%
lending_club.select_dtypes(object).head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#          term int_rate grade sub_grade       emp_title emp_length  \
# 0   36 months   13.08%     B        B5         cashier  10+ years
# 1   60 months    9.16%     B        B2             ABM    6 years
# 2   36 months   10.49%     B        B3          driver  10+ years
# 3   60 months   11.05%     B        B4             NaN        NaN
# 4   60 months   13.59%     C        C2  Shipping Clerk  10+ years
#
#   home_ownership verification_status   issue_d loan_status pymnt_plan  \
# 0       MORTGAGE     Source Verified  Mar-2020     Current          n
# 1           RENT     Source Verified  Feb-2016     Current          n
# 2       MORTGAGE        Not Verified  Jan-2015  Fully Paid          n
# 3       MORTGAGE        Not Verified  Jun-2018     Current          n
# 4       MORTGAGE     Source Verified  Jan-2018  Fully Paid          n
#
#                                                                   url  \
# 0  https://lendingclub.com/browse/loanDetail.action?loan_id=167338079
# 1   https://lendingclub.com/browse/loanDetail.action?loan_id=71016917
# 2   https://lendingclub.com/browse/loanDetail.action?loan_id=39589826
# 3  https://lendingclub.com/browse/loanDetail.action?loan_id=134798709
# 4  https://lendingclub.com/browse/loanDetail.action?loan_id=127097355
#
#               purpose                    title zip_code addr_state  \
# 0    home_improvement         Home improvement    115xx         NY
# 1         credit_card  Credit card refinancing    708xx         LA
# 2         credit_card  Credit card refinancing    347xx         FL
# 3  debt_consolidation       Debt consolidation    443xx         OH
# 4  debt_consolidation       Debt consolidation    681xx         NE
#
#   earliest_cr_line revol_util initial_list_status last_pymnt_d next_pymnt_d  \
# 0         Dec-2004      82.8%                   w     May-2020     Jun-2020
# 1         Jan-2004      64.5%                   w     May-2020     Jun-2020
# 2         Apr-2010      52.6%                   f     Jan-2018          NaN
# 3         Oct-2005      12.1%                   w     May-2020     Jun-2020
# 4         Apr-2008      27.1%                   w     Jul-2019          NaN
#
#   last_credit_pull_d application_type verification_status_joint  \
# 0           May-2020       Individual                       NaN
# 1           May-2020       Individual                       NaN
# 2           May-2020       Individual                       NaN
# 3           May-2020       Individual                       NaN
# 4           Feb-2020       Individual                       NaN
#
#   sec_app_earliest_cr_line hardship_flag hardship_type hardship_reason  \
# 0                      NaN             N           NaN             NaN
# 1                      NaN             N           NaN             NaN
# 2                      NaN             N           NaN             NaN
# 3                      NaN             N           NaN             NaN
# 4                      NaN             N           NaN             NaN
#
#   hardship_status hardship_start_date hardship_end_date  \
# 0             NaN                 NaN               NaN
# 1             NaN                 NaN               NaN
# 2             NaN                 NaN               NaN
# 3             NaN                 NaN               NaN
# 4             NaN                 NaN               NaN
#
#   payment_plan_start_date hardship_loan_status debt_settlement_flag
# 0                     NaN                  NaN                    N
# 1                     NaN                  NaN                    N
# 2                     NaN                  NaN                    N
# 3                     NaN                  NaN                    N
# 4                     NaN                  NaN                    N

# %%
# Check some features if they are boolean
bool_list = ['pymnt_plan', 'hardship_flag', 'debt_settlement_flag', 'verification_status', 'verification_status_joint', ]
for x in bool_list:
    print(lending_club[x].value_counts())
    print("")
# Out:
# pymnt_plan
# n    100000
# Name: count, dtype: int64
#
# hardship_flag
# N    94507
# Y     4166
# Name: count, dtype: int64
#
# debt_settlement_flag
# N    98244
# Y     1756
# Name: count, dtype: int64
#
# verification_status
# Source Verified    38932
# Not Verified       36467
# Verified           24601
# Name: count, dtype: int64
#
# verification_status_joint
# Not Verified       3350
# Source Verified    1934
# Verified           1347
# Name: count, dtype: int64

# %%
# Define functions to parse different kind of values to numbers
def _parse_pct(x: pd.Series) -> pd.Series:
    return x.str.replace("%", "").astype(float)

def _parse_term(x: pd.Series) -> pd.Series:
    return x.str.replace(" months", "").astype(int)

def _parse_date(x: pd.Series) -> pd.Series:
    return pd.to_datetime(x, format="%b-%Y")

def _parse_bool(x: pd.Series) -> pd.Series:
    return x=="Y"

# Make a list of percentage features, formatted as string
pct_list = ['int_rate', 'revol_util']

# Make a list of columns that contains dates in text format
date_list = ['issue_d', 'earliest_cr_line', 'last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d',
             'sec_app_earliest_cr_line', 'hardship_start_date', 'hardship_end_date', 'payment_plan_start_date']

# Make a list of boolean features
bool_list = ['pymnt_plan', 'hardship_flag', 'debt_settlement_flag']

# %% [markdown]
# ### Test functions

# %%
# Check functions output
print(f"Parse percentage:\n{_parse_pct(lending_club.int_rate.head())}\n")
print(f"Parse term:\n{_parse_term(lending_club.term.head())}\n")
print(f"Parse date:\n{_parse_date(lending_club.issue_d.head())}\n")
print(f"Parse bool:\n{pd.concat([lending_club.hardship_flag.head(15),_parse_bool(lending_club.hardship_flag.head(15))], axis=1)}\n")
# Out:
# Parse percentage:
# 0    13.08
# 1     9.16
# 2    10.49
# 3    11.05
# 4    13.59
# Name: int_rate, dtype: float64
#
# Parse term:
# 0    36
# 1    60
# 2    36
# 3    60
# 4    60
# Name: term, dtype: int32
#
# Parse date:
# 0   2020-03-01
# 1   2016-02-01
# 2   2015-01-01
# 3   2018-06-01
# 4   2018-01-01
# Name: issue_d, dtype: datetime64[ns]
#
# Parse bool:
#     hardship_flag  hardship_flag
# 0               N          False
# 1               N          False
# 2               N          False
# 3               N          False
# 4               N          False
# 5               N          False
# 6               N          False
# 7               N          False
# 8               Y           True
# 9               N          False
# 10            NaN          False
# 11              N          False
# 12              N          False
# 13              N          False
# 14              N          False

# %% [markdown]
# Functions defined above where used in `data_processing` pipeline to process raw dataset and save into intermediate dataset with proper data types in `.parquet` format:
# - [nodes.py](https://github.com/Andrii-Chemerys/lending-club/blob/master/src/lending_club/pipelines/data_processing/nodes.py) in `src/lending_club/pipelines/data_processing/nodes.py`
# - [pipeline.py](https://github.com/Andrii-Chemerys/lending-club/blob/master/src/lending_club/pipelines/data_processing/pipeline.py) in `src/lending_club/pipelines/data_processing/pipeline.py`)
#
# Run this pipeline with command:

# %%
# !kedro run -p data_processing
# Out:
# [11/04/24 13:46:07] INFO     Using 'D:\Program                  __init__.py:270
#                              Files\Python\Python
#                              Venv\lc\lib\site-packages\kedro\fr
#                              amework\project\rich_logging.yml'
#                              as logging configuration.
# [11/04/24 13:46:09] INFO     Kedro project lending-club          session.py:329
# [11/04/24 13:48:55] WARNING  D:\Program Files\Python\Python     warnings.py:109
#                              Venv\lc\lib\site-packages\kedro\fr
#                              amework\project\__init__.py:347:
#                              UserWarning: The
#                              'lending_club.pipelines.outliers'
#                              module does not expose a
#                              'create_pipeline' function, so no
#                              pipelines defined therein will be
#                              returned by 'find_pipelines'.
#                                warnings.warn(
#
#                     INFO     Using synchronous mode for sequential_runner.py:67
#                              loading and saving data.
#                              Use the --async flag for
#                              potential performance
#                              gains.
#                              https://docs.kedro.org/en/
#                              stable/nodes_and_pipelines
#                              /run_a_pipeline.html#load-
#                              and-save-asynchronously
#                     INFO     Loading data from              data_catalog.py:389
#                              original_lc_dataset
#                              (CSVDataset)...
# [11/04/24 13:49:02] INFO     Running node: processing_lc_node:      node.py:367
#                              processing_lc([original_lc_dataset])
#                              -> [intermediate_lc_dataset]
# [11/04/24 13:49:05] INFO     Saving data to                 data_catalog.py:431
#                              intermediate_lc_dataset
#                              (ParquetDataset)...
# [11/04/24 13:49:14] INFO     Completed 1 out of 1 tasks sequential_runner.py:93
#                     INFO     Pipeline execution completed         runner.py:125
#                              successfully.

# %% [markdown]
# # Data cleaning
# ---
# New dataset with apropriate data types, produced by `data_processing` pipeline will be used for further data cleaning process

# %%
lending_club = catalog.load("intermediate_lc_dataset")
lending_club.dtypes
# Out:
# [11/04/24 13:49:17] INFO     Loading data from intermediate_lc_dataset (ParquetDataset)...      data_catalog.py:389
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Unnamed: 0.1                                           int64
# Unnamed: 0                                             int64
# loan_amnt                                            float64
# funded_amnt                                          float64
# funded_amnt_inv                                      float64
# term                                                   int32
# int_rate                                             float64
# installment                                          float64
# grade                                                 object
# sub_grade                                             object
# emp_title                                             object
# emp_length                                            object
# home_ownership                                        object
# annual_inc                                           float64
# verification_status                                   object
# issue_d                                       datetime64[ns]
# loan_status                                           object
# pymnt_plan                                            object
# url                                                   object
# purpose                                               object
# title                                                 object
# zip_code                                              object
# addr_state                                            object
# dti                                                  float64
# delinq_2yrs                                          float64
# earliest_cr_line                              datetime64[ns]
# fico_range_low                                       float64
# fico_range_high                                      float64
# inq_last_6mths                                       float64
# mths_since_last_delinq                               float64
# mths_since_last_record                               float64
# open_acc                                             float64
# pub_rec                                              float64
# revol_bal                                            float64
# revol_util                                           float64
# total_acc                                            float64
# initial_list_status                                   object
# out_prncp                                            float64
# out_prncp_inv                                        float64
# total_pymnt                                          float64
# total_pymnt_inv                                      float64
# total_rec_prncp                                      float64
# total_rec_int                                        float64
# total_rec_late_fee                                   float64
# recoveries                                           float64
# collection_recovery_fee                              float64
# last_pymnt_d                                  datetime64[ns]
# last_pymnt_amnt                                      float64
# next_pymnt_d                                  datetime64[ns]
# last_credit_pull_d                            datetime64[ns]
# last_fico_range_high                                 float64
# last_fico_range_low                                  float64
# collections_12_mths_ex_med                           float64
# mths_since_last_major_derog                          float64
# policy_code                                          float64
# application_type                                      object
# annual_inc_joint                                     float64
# dti_joint                                            float64
# verification_status_joint                             object
# acc_now_delinq                                       float64
# tot_coll_amt                                         float64
# tot_cur_bal                                          float64
# open_acc_6m                                          float64
# open_act_il                                          float64
# open_il_12m                                          float64
# open_il_24m                                          float64
# mths_since_rcnt_il                                   float64
# total_bal_il                                         float64
# il_util                                              float64
# open_rv_12m                                          float64
# open_rv_24m                                          float64
# max_bal_bc                                           float64
# all_util                                             float64
# total_rev_hi_lim                                     float64
# inq_fi                                               float64
# total_cu_tl                                          float64
# inq_last_12m                                         float64
# acc_open_past_24mths                                 float64
# avg_cur_bal                                          float64
# bc_open_to_buy                                       float64
# bc_util                                              float64
# chargeoff_within_12_mths                             float64
# delinq_amnt                                          float64
# mo_sin_old_il_acct                                   float64
# mo_sin_old_rev_tl_op                                 float64
# mo_sin_rcnt_rev_tl_op                                float64
# mo_sin_rcnt_tl                                       float64
# mort_acc                                             float64
# mths_since_recent_bc                                 float64
# mths_since_recent_bc_dlq                             float64
# mths_since_recent_inq                                float64
# mths_since_recent_revol_delinq                       float64
# num_accts_ever_120_pd                                float64
# num_actv_bc_tl                                       float64
# num_actv_rev_tl                                      float64
# num_bc_sats                                          float64
# num_bc_tl                                            float64
# num_il_tl                                            float64
# num_op_rev_tl                                        float64
# num_rev_accts                                        float64
# num_rev_tl_bal_gt_0                                  float64
# num_sats                                             float64
# num_tl_120dpd_2m                                     float64
# num_tl_30dpd                                         float64
# num_tl_90g_dpd_24m                                   float64
# num_tl_op_past_12m                                   float64
# pct_tl_nvr_dlq                                       float64
# percent_bc_gt_75                                     float64
# pub_rec_bankruptcies                                 float64
# tax_liens                                            float64
# tot_hi_cred_lim                                      float64
# total_bal_ex_mort                                    float64
# total_bc_limit                                       float64
# total_il_high_credit_limit                           float64
# revol_bal_joint                                      float64
# sec_app_fico_range_low                               float64
# sec_app_fico_range_high                              float64
# sec_app_earliest_cr_line                      datetime64[ns]
# sec_app_inq_last_6mths                               float64
# sec_app_mort_acc                                     float64
# sec_app_open_acc                                     float64
# sec_app_revol_util                                   float64
# sec_app_open_act_il                                  float64
# sec_app_num_rev_accts                                float64
# sec_app_chargeoff_within_12_mths                     float64
# sec_app_collections_12_mths_ex_med                   float64
# hardship_flag                                           bool
# hardship_type                                         object
# hardship_reason                                       object
# hardship_status                                       object
# deferral_term                                        float64
# hardship_amount                                      float64
# hardship_start_date                           datetime64[ns]
# hardship_end_date                             datetime64[ns]
# payment_plan_start_date                       datetime64[ns]
# hardship_length                                      float64
# hardship_dpd                                         float64
# hardship_loan_status                                  object
# orig_projected_additional_accrued_interest           float64
# hardship_payoff_balance_amount                       float64
# hardship_last_payment_amount                         float64
# debt_settlement_flag                                    bool
# dtype: object

# %% [markdown]
# ## Drop columns / fill missing values

# %%
# Identify categorical features that has too much unique values to drop them later
# and identify the ones with missing values to address them
unique_val = lending_club.select_dtypes(object).nunique()
missing_val = lending_club.select_dtypes(object).isna().sum()
cat_feat = pd.concat([
    pd.DataFrame({'unique_val':unique_val, 'missing_val':missing_val}),
    lc_dict
    ], axis=1, join='inner'
).sort_values(by='unique_val', ascending=False)
cat_feat
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                       unique_val  missing_val  \
# url                       100000            0
# emp_title                  40094         8954
# title                       3455          780
# zip_code                     878            0
# addr_state                    51            0
# sub_grade                     35            0
# hardship_reason               17        95105
# purpose                       14            0
# emp_length                    11         6950
# loan_status                   10            0
# hardship_loan_status           9        95116
# grade                          7            0
# hardship_type                  6        95105
# home_ownership                 6            0
# hardship_status                4        95105
# verification_status            3            0
# initial_list_status            2            0
# application_type               2            0
# pymnt_plan                     1            0
#
#                                                                                                                                                                 Description
# url                                                                                                                                  URL for the LC page with listing data.
# emp_title                                                                                               The job title supplied by the Borrower when applying for the loan.*
# title                                                                                                                               The loan title provided by the borrower
# zip_code                                                                              The first 3 numbers of the zip code provided by the borrower in the loan application.
# addr_state                                                                                                       The state provided by the borrower in the loan application
# sub_grade                                                                                                                                         LC assigned loan subgrade
# hardship_reason                                                                                                          Describes the reason the hardship plan was offered
# purpose                                                                                                          A category provided by the borrower for the loan request.
# emp_length                               Employment length in years. Possible values are between 0 and 10 where 0 means less than one year and 10 means ten or more years.
# loan_status                                                                                                                                      Current status of the loan
# hardship_loan_status                                                                                                         Loan Status as of the hardship plan start date
# grade                                                                                                                                                LC assigned loan grade
# hardship_type                                                                                                                          Describes the hardship plan offering
# home_ownership        The home ownership status provided by the borrower during registration or obtained from the credit report. Our values are: RENT, OWN, MORTGAGE, OTHER
# hardship_status                                                                           Describes if the hardship plan is active, pending, canceled, completed, or broken
# verification_status                                                              Indicates if income was verified by LC, not verified, or if the income source was verified
# initial_list_status                                                                                      The initial listing status of the loan. Possible values are – W, F
# application_type                                                       Indicates whether the loan is an individual application or a joint application with two co-borrowers
# pymnt_plan                                                                                                   Indicates if a payment plan has been put in place for the loan

# %%
# Prepare dictionary-like parameters for 'parameters_data_clean.yml'
data_clean_dict = {
    # Columns that makes no sense or has too many or only one categorical unique values and will be dropped
    'drop_list': ['Unnamed: 0.1', 'Unnamed: 0', 'url', 'emp_title', 'title', 'zip_code', 'pymnt_plan'],
    # Columns that missing values will be replaced by 'none'
    'none_list': ['hardship_reason', 'hardship_loan_status', 'hardship_type', 'hardship_status', 'verification_status_joint'],
    # Columns that missing values will be replaced by most frequent value
    'freq_list': ['emp_length'],
}

# %%
# Identify missing values in numerical features to address them later
missing_val = lending_club.select_dtypes([int, float]).isna().sum().sort_values(ascending=False)
missing_val = missing_val.to_frame()
missing_val = pd.concat([missing_val, lc_dict], axis=1, join='inner')
missing_val = missing_val[missing_val[0] != 0]
missing_val
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                 0  \
# hardship_dpd                                95105
# hardship_length                             95105
# deferral_term                               95105
# orig_projected_additional_accrued_interest  93873
# hardship_last_payment_amount                93778
# hardship_payoff_balance_amount              93778
# hardship_amount                             93778
# sec_app_revol_util                          93387
# revol_bal_joint                             93261
# sec_app_open_acc                            93260
# sec_app_fico_range_high                     93260
# sec_app_inq_last_6mths                      93260
# sec_app_mort_acc                            93260
# sec_app_fico_range_low                      93260
# sec_app_open_act_il                         93260
# sec_app_num_rev_accts                       93260
# sec_app_chargeoff_within_12_mths            93260
# sec_app_collections_12_mths_ex_med          93260
# dti_joint                                   92834
# annual_inc_joint                            92834
# mths_since_last_record                      85370
# mths_since_recent_bc_dlq                    78057
# mths_since_last_major_derog                 75398
# mths_since_recent_revol_delinq              68342
# mths_since_last_delinq                      52814
# il_util                                     39685
# mths_since_rcnt_il                          31773
# all_util                                    29657
# inq_fi                                      29644
# open_rv_24m                                 29644
# open_rv_12m                                 29644
# total_bal_il                                29644
# open_il_24m                                 29644
# open_il_12m                                 29644
# total_cu_tl                                 29644
# open_act_il                                 29644
# open_acc_6m                                 29644
# max_bal_bc                                  29644
# inq_last_12m                                29644
# mths_since_recent_inq                       12810
# num_tl_120dpd_2m                             5512
# mo_sin_old_il_acct                           5373
# bc_util                                      2899
# percent_bc_gt_75                             2867
# bc_open_to_buy                               2848
# mths_since_recent_bc                         2788
# pct_tl_nvr_dlq                               2442
# avg_cur_bal                                  2440
# tot_coll_amt                                 2438
# tot_cur_bal                                  2438
# num_accts_ever_120_pd                        2438
# num_actv_bc_tl                               2438
# num_actv_rev_tl                              2438
# num_op_rev_tl                                2438
# num_il_tl                                    2438
# mo_sin_rcnt_rev_tl_op                        2438
# num_rev_accts                                2438
# num_rev_tl_bal_gt_0                          2438
# num_tl_30dpd                                 2438
# num_tl_90g_dpd_24m                           2438
# num_tl_op_past_12m                           2438
# tot_hi_cred_lim                              2438
# total_il_high_credit_limit                   2438
# mo_sin_rcnt_tl                               2438
# num_bc_tl                                    2438
# mo_sin_old_rev_tl_op                         2438
# total_rev_hi_lim                             2438
# num_sats                                     2051
# num_bc_sats                                  2051
# total_bc_limit                               1778
# acc_open_past_24mths                         1778
# total_bal_ex_mort                            1778
# mort_acc                                     1778
# dti                                           102
# revol_util                                     81
# pub_rec_bankruptcies                           45
# chargeoff_within_12_mths                        6
# collections_12_mths_ex_med                      6
# tax_liens                                       5
#
#                                                                                                                                                                                                                                                       Description
# hardship_dpd                                                                                                                                                                                             Account days past due as of the hardship plan start date
# hardship_length                                                                                                                                       The number of months the borrower will make smaller payments than normally obligated due to a hardship plan
# deferral_term                                                                                                                       Amount of months that the borrower is expected to pay less than the contractual monthly payment amount due to a hardship plan
# orig_projected_additional_accrued_interest  The original projected additional interest amount that will accrue for the given hardship payment plan as of the Hardship Start Date. This field will be null if the borrower has broken their hardship payment plan.
# hardship_last_payment_amount                                                                                                                                                                           The last payment amount as of the hardship plan start date
# hardship_payoff_balance_amount                                                                                                                                                                       The payoff balance amount as of the hardship plan start date
# hardship_amount                                                                                                                                         The interest payment that the borrower has committed to make each month while they are on a hardship plan
# sec_app_revol_util                                                                                                                                                          Ratio of total current balance to high credit/credit limit for all revolving accounts
# revol_bal_joint                                                                                                                                                                    Sum of revolving credit balance of the co-borrowers, net of duplicate balances
# sec_app_open_acc                                                                                                                                                                         Number of open trades at time of application for the secondary applicant
# sec_app_fico_range_high                                                                                                                                                                                              FICO range (low) for the secondary applicant
# sec_app_inq_last_6mths                                                                                                                                                   Credit inquiries in the last 6 months at time of application for the secondary applicant
# sec_app_mort_acc                                                                                                                                                                   Number of mortgage accounts at time of application for the secondary applicant
# sec_app_fico_range_low                                                                                                                                                                                              FICO range (high) for the secondary applicant
# sec_app_open_act_il                                                                                                                                              Number of currently active installment trades at time of application for the secondary applicant
# sec_app_num_rev_accts                                                                                                                                                             Number of revolving accounts at time of application for the secondary applicant
# sec_app_chargeoff_within_12_mths                                                                                                                                   Number of charge-offs within last 12 months at time of application for the secondary applicant
# sec_app_collections_12_mths_ex_med                                                                                                   Number of collections within last 12 months excluding medical collections at time of application for the secondary applicant
# dti_joint                                      A ratio calculated using the co-borrowers' total monthly payments on the total debt obligations, excluding mortgages and the requested LC loan, divided by the co-borrowers' combined self-reported monthly income
# annual_inc_joint                                                                                                                                                        The combined self-reported annual income provided by the co-borrowers during registration
# mths_since_last_record                                                                                                                                                                                         The number of months since the last public record.
# mths_since_recent_bc_dlq                                                                                                                                                                                            Months since most recent bankcard delinquency
# mths_since_last_major_derog                                                                                                                                                                                       Months since most recent 90-day or worse rating
# mths_since_recent_revol_delinq                                                                                                                                                                                    Months since most recent revolving delinquency.
# mths_since_last_delinq                                                                                                                                                                                The number of months since the borrower's last delinquency.
# il_util                                                                                                                                                                            Ratio of total current balance to high credit/credit limit on all install acct
# mths_since_rcnt_il                                                                                                                                                                                           Months since most recent installment accounts opened
# all_util                                                                                                                                                                                                                    Balance to credit limit on all trades
# inq_fi                                                                                                                                                                                                                       Number of personal finance inquiries
# open_rv_24m                                                                                                                                                                                                   Number of revolving trades opened in past 24 months
# open_rv_12m                                                                                                                                                                                                   Number of revolving trades opened in past 12 months
# total_bal_il                                                                                                                                                                                                    Total current balance of all installment accounts
# open_il_24m                                                                                                                                                                                               Number of installment accounts opened in past 24 months
# open_il_12m                                                                                                                                                                                               Number of installment accounts opened in past 12 months
# total_cu_tl                                                                                                                                                                                                                              Number of finance trades
# open_act_il                                                                                                                                                                                                         Number of currently active installment trades
# open_acc_6m                                                                                                                                                                                                                Number of open trades in last 6 months
# max_bal_bc                                                                                                                                                                                                 Maximum current balance owed on all revolving accounts
# inq_last_12m                                                                                                                                                                                                         Number of credit inquiries in past 12 months
# mths_since_recent_inq                                                                                                                                                                                                           Months since most recent inquiry.
# num_tl_120dpd_2m                                                                                                                                                                        Number of accounts currently 120 days past due (updated in past 2 months)
# mo_sin_old_il_acct                                                                                                                                                                                            Months since oldest bank installment account opened
# bc_util                                                                                                                                                                     Ratio of total current balance to high credit/credit limit for all bankcard accounts.
# percent_bc_gt_75                                                                                                                                                                                              Percentage of all bankcard accounts > 75% of limit.
# bc_open_to_buy                                                                                                                                                                                                          Total open to buy on revolving bankcards.
# mths_since_recent_bc                                                                                                                                                                                            Months since most recent bankcard account opened.
# pct_tl_nvr_dlq                                                                                                                                                                                                                 Percent of trades never delinquent
# avg_cur_bal                                                                                                                                                                                                               Average current balance of all accounts
# tot_coll_amt                                                                                                                                                                                                                   Total collection amounts ever owed
# tot_cur_bal                                                                                                                                                                                                                 Total current balance of all accounts
# num_accts_ever_120_pd                                                                                                                                                                                           Number of accounts ever 120 or more days past due
# num_actv_bc_tl                                                                                                                                                                                                       Number of currently active bankcard accounts
# num_actv_rev_tl                                                                                                                                                                                                       Number of currently active revolving trades
# num_op_rev_tl                                                                                                                                                                                                                   Number of open revolving accounts
# num_il_tl                                                                                                                                                                                                                          Number of installment accounts
# mo_sin_rcnt_rev_tl_op                                                                                                                                                                                           Months since most recent revolving account opened
# num_rev_accts                                                                                                                                                                                                                        Number of revolving accounts
# num_rev_tl_bal_gt_0                                                                                                                                                                                                    Number of revolving trades with balance >0
# num_tl_30dpd                                                                                                                                                                             Number of accounts currently 30 days past due (updated in past 2 months)
# num_tl_90g_dpd_24m                                                                                                                                                                                  Number of accounts 90 or more days past due in last 24 months
# num_tl_op_past_12m                                                                                                                                                                                                    Number of accounts opened in past 12 months
# tot_hi_cred_lim                                                                                                                                                                                                                    Total high credit/credit limit
# total_il_high_credit_limit                                                                                                                                                                                             Total installment high credit/credit limit
# mo_sin_rcnt_tl                                                                                                                                                                                                            Months since most recent account opened
# num_bc_tl                                                                                                                                                                                                                             Number of bankcard accounts
# mo_sin_old_rev_tl_op                                                                                                                                                                                                 Months since oldest revolving account opened
# total_rev_hi_lim                                                                                                                                                                                                         Total revolving high credit/credit limit
# num_sats                                                                                                                                                                                                                          Number of satisfactory accounts
# num_bc_sats                                                                                                                                                                                                              Number of satisfactory bankcard accounts
# total_bc_limit                                                                                                                                                                                                            Total bankcard high credit/credit limit
# acc_open_past_24mths                                                                                                                                                                                                   Number of trades opened in past 24 months.
# total_bal_ex_mort                                                                                                                                                                                                         Total credit balance excluding mortgage
# mort_acc                                                                                                                                                                                                                             Number of mortgage accounts.
# dti                                                      A ratio calculated using the borrower’s total monthly debt payments on the total debt obligations, excluding mortgage and the requested LC loan, divided by the borrower’s self-reported monthly income.
# revol_util                                                                                                                             Revolving line utilization rate, or the amount of credit the borrower is using relative to all available revolving credit.
# pub_rec_bankruptcies                                                                                                                                                                                                         Number of public record bankruptcies
# chargeoff_within_12_mths                                                                                                                                                                                                   Number of charge-offs within 12 months
# collections_12_mths_ex_med                                                                                                                                                                       Number of collections in 12 months excluding medical collections
# tax_liens                                                                                                                                                                                                                                     Number of tax liens

# %%
# Update dictionary of parameters for 'parameters_data_clean.yml':
#   - columns that null values will be replaced by 0
data_clean_dict['fill_zero'] =['hardship_dpd', 'hardship_length', 'deferral_term', 'orig_projected_additional_accrued_interest',
                  'hardship_last_payment_amount', 'hardship_payoff_balance_amount', 'hardship_amount', 'sec_app_open_act_il',
                  'dti_joint', 'annual_inc_joint', 'mths_since_last_record', 'mths_since_recent_bc_dlq', 'mths_since_last_major_derog',
                  'mths_since_recent_revol_delinq', 'mths_since_last_delinq', 'mths_since_rcnt_il',
                  'sec_app_revol_util', 'revol_bal_joint', 'sec_app_fico_range_low', 'sec_app_fico_range_high',
                  'sec_app_mort_acc', 'sec_app_open_acc', 'sec_app_inq_last_6mths', 'sec_app_chargeoff_within_12_mths',
                  'sec_app_collections_12_mths_ex_med', 'sec_app_num_rev_accts'
                  ]

#   - columns that null values will be replaced by median values
data_clean_dict['fill_med'] = [ 'il_util', 'all_util', 'inq_fi', 'open_rv_24m', 'open_rv_12m', 'total_bal_il', 'open_il_24m', 'open_il_12m',
                  'total_cu_tl', 'open_act_il', 'open_acc_6m', 'max_bal_bc', 'inq_last_12m', 'mths_since_recent_inq', 'num_tl_120dpd_2m',
                  'mo_sin_old_il_acct', 'bc_util', 'percent_bc_gt_75', 'bc_open_to_buy', 'mths_since_recent_bc', 'pct_tl_nvr_dlq', 'avg_cur_bal',
                  'tot_coll_amt', 'tot_cur_bal', 'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_actv_rev_tl', 'num_op_rev_tl', 'num_il_tl',
                  'mo_sin_rcnt_rev_tl_op', 'num_rev_accts', 'num_rev_tl_bal_gt_0', 'num_tl_30dpd', 'num_tl_90g_dpd_24m', 'num_tl_op_past_12m',
                  'tot_hi_cred_lim', 'total_il_high_credit_limit', 'mo_sin_rcnt_tl', 'num_bc_tl', 'mo_sin_old_rev_tl_op', 'num_sats', 'num_bc_sats',
                  'total_bc_limit', 'acc_open_past_24mths', 'total_bal_ex_mort', 'mort_acc', 'dti', 'revol_util', 'pub_rec_bankruptcies',
                  'chargeoff_within_12_mths', 'collections_12_mths_ex_med', 'tax_liens', 'total_rev_hi_lim'
                  ]

# %%
missing_val = lending_club.select_dtypes('datetime64').isna().sum().sort_values(ascending=False)
missing_val = missing_val.to_frame()
missing_val = pd.concat([missing_val, lc_dict], axis=1, join='inner')
missing_val = missing_val[missing_val[0] != 0]
missing_val
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                               0  \
# hardship_start_date       95105
# hardship_end_date         95105
# payment_plan_start_date   95105
# sec_app_earliest_cr_line  93260
# next_pymnt_d              63573
# last_pymnt_d                191
# last_credit_pull_d            2
#
#                                                                                                                                                                                                                                                         Description
# hardship_start_date                                                                                                                                                                                                      The start date of the hardship plan period
# hardship_end_date                                                                                                                                                                                                          The end date of the hardship plan period
# payment_plan_start_date   The day the first hardship plan payment is due. For example, if a borrower has a hardship plan period of 3 months, the start date is the start of the three-month period in which the borrower is allowed to make interest-only payments.
# sec_app_earliest_cr_line                                                                                                                                                                    Earliest credit line at time of application for the secondary applicant
# next_pymnt_d                                                                                                                                                                                                                            Next scheduled payment date
# last_pymnt_d                                                                                                                                                                                                                        Last month payment was received
# last_credit_pull_d                                                                                                                                                                                             The most recent month LC pulled credit for this loan

# %% [markdown]
# These missing dates stands for a reason in our dataset, meaning that some event haven't happend. That's why I decided not to fill missing dates, althoug it could be filled by some far back date, say `pd.timestamp(0)` [1970-01-01], to distinghish them from the others.

# %%
# Print parameter list for 'parameters_data_clean.yml'
for key in data_clean_dict.keys():
    print(f"{key}:")
    for x in data_clean_dict[key]:
        print(f"  - {x}")
    print("")
# Out:
# drop_list:
#   - Unnamed: 0.1
#   - Unnamed: 0
#   - url
#   - emp_title
#   - title
#   - zip_code
#   - pymnt_plan
#
# none_list:
#   - hardship_reason
#   - hardship_loan_status
#   - hardship_type
#   - hardship_status
#   - verification_status_joint
#
# freq_list:
#   - emp_length
#
# fill_zero:
#   - hardship_dpd
#   - hardship_length
#   - deferral_term
#   - orig_projected_additional_accrued_interest
#   - hardship_last_payment_amount
#   - hardship_payoff_balance_amount
#   - hardship_amount
#   - sec_app_open_act_il
#   - dti_joint
#   - annual_inc_joint
#   - mths_since_last_record
#   - mths_since_recent_bc_dlq
#   - mths_since_last_major_derog
#   - mths_since_recent_revol_delinq
#   - mths_since_last_delinq
#   - mths_since_rcnt_il
#   - sec_app_revol_util
#   - revol_bal_joint
#   - sec_app_fico_range_low
#   - sec_app_fico_range_high
#   - sec_app_mort_acc
#   - sec_app_open_acc
#   - sec_app_inq_last_6mths
#   - sec_app_chargeoff_within_12_mths
#   - sec_app_collections_12_mths_ex_med
#   - sec_app_num_rev_accts
#
# fill_med:
#   - il_util
#   - all_util
#   - inq_fi
#   - open_rv_24m
#   - open_rv_12m
#   - total_bal_il
#   - open_il_24m
#   - open_il_12m
#   - total_cu_tl
#   - open_act_il
#   - open_acc_6m
#   - max_bal_bc
#   - inq_last_12m
#   - mths_since_recent_inq
#   - num_tl_120dpd_2m
#   - mo_sin_old_il_acct
#   - bc_util
#   - percent_bc_gt_75
#   - bc_open_to_buy
#   - mths_since_recent_bc
#   - pct_tl_nvr_dlq
#   - avg_cur_bal
#   - tot_coll_amt
#   - tot_cur_bal
#   - num_accts_ever_120_pd
#   - num_actv_bc_tl
#   - num_actv_rev_tl
#   - num_op_rev_tl
#   - num_il_tl
#   - mo_sin_rcnt_rev_tl_op
#   - num_rev_accts
#   - num_rev_tl_bal_gt_0
#   - num_tl_30dpd
#   - num_tl_90g_dpd_24m
#   - num_tl_op_past_12m
#   - tot_hi_cred_lim
#   - total_il_high_credit_limit
#   - mo_sin_rcnt_tl
#   - num_bc_tl
#   - mo_sin_old_rev_tl_op
#   - num_sats
#   - num_bc_sats
#   - total_bc_limit
#   - acc_open_past_24mths
#   - total_bal_ex_mort
#   - mort_acc
#   - dti
#   - revol_util
#   - pub_rec_bankruptcies
#   - chargeoff_within_12_mths
#   - collections_12_mths_ex_med
#   - tax_liens
#   - total_rev_hi_lim

# %%
# Define functions to clean data
from sklearn.impute import SimpleImputer

def _drop_features(df: pd.DataFrame, params: dict) -> pd.DataFrame:
    return df.drop(params['drop_list'], axis=1)

def _fill_data(df: pd.DataFrame, params: dict) -> pd.DataFrame:

    # Fill missing values by 'None'
    imp_none = SimpleImputer(missing_values=None, strategy='constant', fill_value='none')
    df[params['none_list']] = imp_none.fit_transform(df[params['none_list']])

    # Fill missing values by most frequent ones
    imp_mf = SimpleImputer(missing_values=None, strategy='most_frequent')
    df[params['freq_list']] = imp_mf.fit_transform(df[params['freq_list']])

    # Fill missing values by 0
    imp_zer = SimpleImputer(missing_values=np.nan, strategy='constant', fill_value=0)
    df[params['fill_zero']] = imp_zer.fit_transform(df[params['fill_zero']])

    # Fill missing values by median
    imp_med = SimpleImputer(missing_values=np.nan, strategy='median')
    df[params['fill_med']] = imp_med.fit_transform(df[params['fill_med']])
    return df

# %% [markdown]
# ### Test functions

# %%
lc = _drop_features(lending_club, data_clean_dict).head()
lc
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#            loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  \
# id
# 167338079     4000.0       4000.0           4000.0    36     13.08
# 71016917     24000.0      24000.0          24000.0    60      9.16
# 39589826      5000.0       5000.0           5000.0    36     10.49
# 134798709    24000.0      24000.0          24000.0    60     11.05
# 127097355    14000.0      14000.0          14000.0    60     13.59
#
#            installment grade sub_grade emp_length home_ownership  annual_inc  \
# id
# 167338079       134.93     B        B5  10+ years       MORTGAGE     48000.0
# 71016917        500.07     B        B2    6 years           RENT     57000.0
# 39589826        162.49     B        B3  10+ years       MORTGAGE     55000.0
# 134798709       522.42     B        B4       None       MORTGAGE     43500.0
# 127097355       322.79     C        C2  10+ years       MORTGAGE     48000.0
#
#           verification_status    issue_d loan_status             purpose  \
# id
# 167338079     Source Verified 2020-03-01     Current    home_improvement
# 71016917      Source Verified 2016-02-01     Current         credit_card
# 39589826         Not Verified 2015-01-01  Fully Paid         credit_card
# 134798709        Not Verified 2018-06-01     Current  debt_consolidation
# 127097355     Source Verified 2018-01-01  Fully Paid  debt_consolidation
#
#           addr_state    dti  delinq_2yrs earliest_cr_line  fico_range_low  \
# id
# 167338079         NY  20.25          1.0       2004-12-01           665.0
# 71016917          LA  25.33          0.0       2004-01-01           680.0
# 39589826          FL   7.22          0.0       2010-04-01           665.0
# 134798709         OH  24.55          0.0       2005-10-01           750.0
# 127097355         NE  24.30          0.0       2008-04-01           735.0
#
#            fico_range_high  inq_last_6mths  mths_since_last_delinq  \
# id
# 167338079            669.0             0.0                    19.0
# 71016917             684.0             0.0                     NaN
# 39589826             669.0             0.0                     NaN
# 134798709            754.0             0.0                     NaN
# 127097355            739.0             1.0                     NaN
#
#            mths_since_last_record  open_acc  pub_rec  revol_bal  revol_util  \
# id
# 167338079                   110.0       4.0      1.0     1988.0        82.8
# 71016917                      NaN      10.0      0.0    22697.0        64.5
# 39589826                     61.0       7.0      1.0     6001.0        52.6
# 134798709                     NaN      15.0      0.0     6573.0        12.1
# 127097355                     NaN      16.0      0.0    11894.0        27.1
#
#            total_acc initial_list_status  out_prncp  out_prncp_inv  \
# id
# 167338079       12.0                   w    3816.34        3816.34
# 71016917        24.0                   w    4333.29        4333.29
# 39589826         9.0                   f       0.00           0.00
# 134798709       23.0                   w   16317.69       16317.69
# 127097355       23.0                   w       0.00           0.00
#
#             total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  \
# id
# 167338079    266.950000           266.95           183.66          83.29
# 71016917   25496.160000         25496.16         19666.71        5829.45
# 39589826    5846.672836          5846.67          5000.00         846.67
# 134798709  12000.930000         12000.93          7682.31        4318.62
# 127097355  16605.680000         16605.68         14000.00        2605.68
#
#            total_rec_late_fee  recoveries  collection_recovery_fee  \
# id
# 167338079                 0.0         0.0                      0.0
# 71016917                  0.0         0.0                      0.0
# 39589826                  0.0         0.0                      0.0
# 134798709                 0.0         0.0                      0.0
# 127097355                 0.0         0.0                      0.0
#
#           last_pymnt_d  last_pymnt_amnt next_pymnt_d last_credit_pull_d  \
# id
# 167338079   2020-05-01           134.93   2020-06-01         2020-05-01
# 71016917    2020-05-01           500.07   2020-06-01         2020-05-01
# 39589826    2018-01-01           162.43          NaT         2020-05-01
# 134798709   2020-05-01           522.42   2020-06-01         2020-05-01
# 127097355   2019-07-01         11128.82          NaT         2020-02-01
#
#            last_fico_range_high  last_fico_range_low  \
# id
# 167338079                 669.0                665.0
# 71016917                  704.0                700.0
# 39589826                  789.0                785.0
# 134798709                 749.0                745.0
# 127097355                 779.0                775.0
#
#            collections_12_mths_ex_med  mths_since_last_major_derog  \
# id
# 167338079                         1.0                          NaN
# 71016917                          0.0                          NaN
# 39589826                          0.0                          NaN
# 134798709                         0.0                          NaN
# 127097355                         0.0                          NaN
#
#            policy_code application_type  annual_inc_joint  dti_joint  \
# id
# 167338079          1.0       Individual               NaN        NaN
# 71016917           1.0       Individual               NaN        NaN
# 39589826           1.0       Individual               NaN        NaN
# 134798709          1.0       Individual               NaN        NaN
# 127097355          1.0       Individual               NaN        NaN
#
#           verification_status_joint  acc_now_delinq  tot_coll_amt  \
# id
# 167338079                      None             0.0        3832.0
# 71016917                       None             0.0           0.0
# 39589826                       None             0.0           0.0
# 134798709                      None             0.0           0.0
# 127097355                      None             0.0           0.0
#
#            tot_cur_bal  open_acc_6m  open_act_il  open_il_12m  open_il_24m  \
# id
# 167338079     259024.0          0.0          1.0          0.0          1.0
# 71016917       61815.0          0.0          3.0          0.0          3.0
# 39589826      159131.0          NaN          NaN          NaN          NaN
# 134798709     104590.0          2.0          1.0          0.0          1.0
# 127097355      90253.0          2.0          2.0          1.0          1.0
#
#            mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# id
# 167338079                16.0        9960.0     56.0          0.0
# 71016917                 14.0       39118.0     72.0          1.0
# 39589826                  NaN           NaN      NaN          NaN
# 134798709                17.0       11947.0     60.0          2.0
# 127097355                 7.0       22953.0     60.0          3.0
#
#            open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  \
# id
# 167338079          0.0         0.0      59.0            2400.0     1.0
# 71016917           1.0      2137.0      67.0           35200.0     0.0
# 39589826           NaN         NaN       NaN           11400.0     NaN
# 134798709          3.0      2223.0      25.0           54500.0     2.0
# 127097355          4.0      3907.0      43.0           43900.0     1.0
#
#            total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  \
# id
# 167338079          0.0           0.0                   1.0      64756.0
# 71016917           7.0           0.0                   4.0       6182.0
# 39589826           NaN           NaN                   4.0      22733.0
# 134798709          0.0           2.0                   4.0       6973.0
# 127097355          0.0           2.0                   5.0       5641.0
#
#            bc_open_to_buy  bc_util  chargeoff_within_12_mths  delinq_amnt  \
# id
# 167338079             NaN      NaN                       0.0          0.0
# 71016917           7741.0     40.5                       0.0          0.0
# 39589826           4521.0     54.8                       0.0          0.0
# 134798709         43140.0     12.0                       0.0          0.0
# 127097355         17318.0     39.9                       0.0          0.0
#
#            mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  \
# id
# 167338079               179.0                  75.0                   38.0
# 71016917                145.0                 137.0                    7.0
# 39589826                 57.0                  57.0                   14.0
# 134798709                37.0                 132.0                    1.0
# 127097355                72.0                 117.0                    6.0
#
#            mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  \
# id
# 167338079            16.0       2.0                   NaN
# 71016917              7.0       0.0                   7.0
# 39589826              9.0       1.0                  14.0
# 134798709             1.0       2.0                   1.0
# 127097355             6.0       2.0                   6.0
#
#            mths_since_recent_bc_dlq  mths_since_recent_inq  \
# id
# 167338079                      19.0                   16.0
# 71016917                        NaN                   24.0
# 39589826                        NaN                    1.0
# 134798709                       NaN                    3.0
# 127097355                       NaN                    5.0
#
#            mths_since_recent_revol_delinq  num_accts_ever_120_pd  \
# id
# 167338079                            19.0                    1.0
# 71016917                              NaN                    0.0
# 39589826                              NaN                    0.0
# 134798709                             NaN                    1.0
# 127097355                             NaN                    0.0
#
#            num_actv_bc_tl  num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  \
# id
# 167338079             0.0              2.0          0.0        1.0        5.0
# 71016917              3.0              5.0          5.0        6.0       15.0
# 39589826              3.0              5.0          3.0        3.0        2.0
# 134798709             6.0              7.0         11.0       16.0        2.0
# 127097355             4.0              5.0          5.0        6.0        5.0
#
#            num_op_rev_tl  num_rev_accts  num_rev_tl_bal_gt_0  num_sats  \
# id
# 167338079            2.0            5.0                  2.0       4.0
# 71016917             7.0            9.0                  5.0      10.0
# 39589826             5.0            6.0                  5.0       7.0
# 134798709           13.0           19.0                  7.0      15.0
# 127097355           13.0           16.0                  5.0      16.0
#
#            num_tl_120dpd_2m  num_tl_30dpd  num_tl_90g_dpd_24m  \
# id
# 167338079               0.0           0.0                 0.0
# 71016917                0.0           0.0                 0.0
# 39589826                0.0           0.0                 0.0
# 134798709               0.0           0.0                 0.0
# 127097355               0.0           0.0                 0.0
#
#            num_tl_op_past_12m  pct_tl_nvr_dlq  percent_bc_gt_75  \
# id
# 167338079                 0.0            75.0               NaN
# 71016917                  1.0            95.8              60.0
# 39589826                  1.0           100.0              33.3
# 134798709                 2.0            95.7               0.0
# 127097355                 4.0           100.0               0.0
#
#            pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# id
# 167338079                   1.0        0.0         395328.0
# 71016917                    0.0        0.0          88154.0
# 39589826                    0.0        1.0         171118.0
# 134798709                   0.0        0.0         202606.0
# 127097355                   0.0        0.0         152081.0
#
#            total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# id
# 167338079            11948.0             0.0                     17928.0
# 71016917             61815.0         13000.0                     52954.0
# 39589826             13124.0         10000.0                      7526.0
# 134798709            18520.0         49000.0                     20000.0
# 127097355            34847.0         28800.0                     38181.0
#
#            revol_bal_joint  sec_app_fico_range_low  sec_app_fico_range_high  \
# id
# 167338079              NaN                     NaN                      NaN
# 71016917               NaN                     NaN                      NaN
# 39589826               NaN                     NaN                      NaN
# 134798709              NaN                     NaN                      NaN
# 127097355              NaN                     NaN                      NaN
#
#           sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# id
# 167338079                      NaT                     NaN               NaN
# 71016917                       NaT                     NaN               NaN
# 39589826                       NaT                     NaN               NaN
# 134798709                      NaT                     NaN               NaN
# 127097355                      NaT                     NaN               NaN
#
#            sec_app_open_acc  sec_app_revol_util  sec_app_open_act_il  \
# id
# 167338079               NaN                 NaN                  NaN
# 71016917                NaN                 NaN                  NaN
# 39589826                NaN                 NaN                  NaN
# 134798709               NaN                 NaN                  NaN
# 127097355               NaN                 NaN                  NaN
#
#            sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# id
# 167338079                    NaN                               NaN
# 71016917                     NaN                               NaN
# 39589826                     NaN                               NaN
# 134798709                    NaN                               NaN
# 127097355                    NaN                               NaN
#
#            sec_app_collections_12_mths_ex_med  hardship_flag hardship_type  \
# id
# 167338079                                 NaN          False          None
# 71016917                                  NaN          False          None
# 39589826                                  NaN          False          None
# 134798709                                 NaN          False          None
# 127097355                                 NaN          False          None
#
#           hardship_reason hardship_status  deferral_term  hardship_amount  \
# id
# 167338079            None            None            NaN              NaN
# 71016917             None            None            NaN              NaN
# 39589826             None            None            NaN              NaN
# 134798709            None            None            NaN              NaN
# 127097355            None            None            NaN              NaN
#
#           hardship_start_date hardship_end_date payment_plan_start_date  \
# id
# 167338079                 NaT               NaT                     NaT
# 71016917                  NaT               NaT                     NaT
# 39589826                  NaT               NaT                     NaT
# 134798709                 NaT               NaT                     NaT
# 127097355                 NaT               NaT                     NaT
#
#            hardship_length  hardship_dpd hardship_loan_status  \
# id
# 167338079              NaN           NaN                 None
# 71016917               NaN           NaN                 None
# 39589826               NaN           NaN                 None
# 134798709              NaN           NaN                 None
# 127097355              NaN           NaN                 None
#
#            orig_projected_additional_accrued_interest  \
# id
# 167338079                                         NaN
# 71016917                                          NaN
# 39589826                                          NaN
# 134798709                                         NaN
# 127097355                                         NaN
#
#            hardship_payoff_balance_amount  hardship_last_payment_amount  \
# id
# 167338079                             NaN                           NaN
# 71016917                              NaN                           NaN
# 39589826                              NaN                           NaN
# 134798709                             NaN                           NaN
# 127097355                             NaN                           NaN
#
#            debt_settlement_flag
# id
# 167338079                 False
# 71016917                  False
# 39589826                  False
# 134798709                 False
# 127097355                 False

# %%
_fill_data(
    lc[lc['hardship_reason'].isna()],
    data_clean_dict
)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#            loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  \
# id
# 167338079     4000.0       4000.0           4000.0    36     13.08
# 71016917     24000.0      24000.0          24000.0    60      9.16
# 39589826      5000.0       5000.0           5000.0    36     10.49
# 134798709    24000.0      24000.0          24000.0    60     11.05
# 127097355    14000.0      14000.0          14000.0    60     13.59
#
#            installment grade sub_grade emp_length home_ownership  annual_inc  \
# id
# 167338079       134.93     B        B5  10+ years       MORTGAGE     48000.0
# 71016917        500.07     B        B2    6 years           RENT     57000.0
# 39589826        162.49     B        B3  10+ years       MORTGAGE     55000.0
# 134798709       522.42     B        B4  10+ years       MORTGAGE     43500.0
# 127097355       322.79     C        C2  10+ years       MORTGAGE     48000.0
#
#           verification_status    issue_d loan_status             purpose  \
# id
# 167338079     Source Verified 2020-03-01     Current    home_improvement
# 71016917      Source Verified 2016-02-01     Current         credit_card
# 39589826         Not Verified 2015-01-01  Fully Paid         credit_card
# 134798709        Not Verified 2018-06-01     Current  debt_consolidation
# 127097355     Source Verified 2018-01-01  Fully Paid  debt_consolidation
#
#           addr_state    dti  delinq_2yrs earliest_cr_line  fico_range_low  \
# id
# 167338079         NY  20.25          1.0       2004-12-01           665.0
# 71016917          LA  25.33          0.0       2004-01-01           680.0
# 39589826          FL   7.22          0.0       2010-04-01           665.0
# 134798709         OH  24.55          0.0       2005-10-01           750.0
# 127097355         NE  24.30          0.0       2008-04-01           735.0
#
#            fico_range_high  inq_last_6mths  mths_since_last_delinq  \
# id
# 167338079            669.0             0.0                    19.0
# 71016917             684.0             0.0                     0.0
# 39589826             669.0             0.0                     0.0
# 134798709            754.0             0.0                     0.0
# 127097355            739.0             1.0                     0.0
#
#            mths_since_last_record  open_acc  pub_rec  revol_bal  revol_util  \
# id
# 167338079                   110.0       4.0      1.0     1988.0        82.8
# 71016917                      0.0      10.0      0.0    22697.0        64.5
# 39589826                     61.0       7.0      1.0     6001.0        52.6
# 134798709                     0.0      15.0      0.0     6573.0        12.1
# 127097355                     0.0      16.0      0.0    11894.0        27.1
#
#            total_acc initial_list_status  out_prncp  out_prncp_inv  \
# id
# 167338079       12.0                   w    3816.34        3816.34
# 71016917        24.0                   w    4333.29        4333.29
# 39589826         9.0                   f       0.00           0.00
# 134798709       23.0                   w   16317.69       16317.69
# 127097355       23.0                   w       0.00           0.00
#
#             total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  \
# id
# 167338079    266.950000           266.95           183.66          83.29
# 71016917   25496.160000         25496.16         19666.71        5829.45
# 39589826    5846.672836          5846.67          5000.00         846.67
# 134798709  12000.930000         12000.93          7682.31        4318.62
# 127097355  16605.680000         16605.68         14000.00        2605.68
#
#            total_rec_late_fee  recoveries  collection_recovery_fee  \
# id
# 167338079                 0.0         0.0                      0.0
# 71016917                  0.0         0.0                      0.0
# 39589826                  0.0         0.0                      0.0
# 134798709                 0.0         0.0                      0.0
# 127097355                 0.0         0.0                      0.0
#
#           last_pymnt_d  last_pymnt_amnt next_pymnt_d last_credit_pull_d  \
# id
# 167338079   2020-05-01           134.93   2020-06-01         2020-05-01
# 71016917    2020-05-01           500.07   2020-06-01         2020-05-01
# 39589826    2018-01-01           162.43          NaT         2020-05-01
# 134798709   2020-05-01           522.42   2020-06-01         2020-05-01
# 127097355   2019-07-01         11128.82          NaT         2020-02-01
#
#            last_fico_range_high  last_fico_range_low  \
# id
# 167338079                 669.0                665.0
# 71016917                  704.0                700.0
# 39589826                  789.0                785.0
# 134798709                 749.0                745.0
# 127097355                 779.0                775.0
#
#            collections_12_mths_ex_med  mths_since_last_major_derog  \
# id
# 167338079                         1.0                          0.0
# 71016917                          0.0                          0.0
# 39589826                          0.0                          0.0
# 134798709                         0.0                          0.0
# 127097355                         0.0                          0.0
#
#            policy_code application_type  annual_inc_joint  dti_joint  \
# id
# 167338079          1.0       Individual               0.0        0.0
# 71016917           1.0       Individual               0.0        0.0
# 39589826           1.0       Individual               0.0        0.0
# 134798709          1.0       Individual               0.0        0.0
# 127097355          1.0       Individual               0.0        0.0
#
#           verification_status_joint  acc_now_delinq  tot_coll_amt  \
# id
# 167338079                      none             0.0        3832.0
# 71016917                       none             0.0           0.0
# 39589826                       none             0.0           0.0
# 134798709                      none             0.0           0.0
# 127097355                      none             0.0           0.0
#
#            tot_cur_bal  open_acc_6m  open_act_il  open_il_12m  open_il_24m  \
# id
# 167338079     259024.0          0.0          1.0          0.0          1.0
# 71016917       61815.0          0.0          3.0          0.0          3.0
# 39589826      159131.0          1.0          1.5          0.0          1.0
# 134798709     104590.0          2.0          1.0          0.0          1.0
# 127097355      90253.0          2.0          2.0          1.0          1.0
#
#            mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# id
# 167338079                16.0        9960.0     56.0          0.0
# 71016917                 14.0       39118.0     72.0          1.0
# 39589826                  0.0       17450.0     60.0          1.5
# 134798709                17.0       11947.0     60.0          2.0
# 127097355                 7.0       22953.0     60.0          3.0
#
#            open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  \
# id
# 167338079          0.0         0.0      59.0            2400.0     1.0
# 71016917           1.0      2137.0      67.0           35200.0     0.0
# 39589826           2.0      2180.0      51.0           11400.0     1.0
# 134798709          3.0      2223.0      25.0           54500.0     2.0
# 127097355          4.0      3907.0      43.0           43900.0     1.0
#
#            total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  \
# id
# 167338079          0.0           0.0                   1.0      64756.0
# 71016917           7.0           0.0                   4.0       6182.0
# 39589826           0.0           1.0                   4.0      22733.0
# 134798709          0.0           2.0                   4.0       6973.0
# 127097355          0.0           2.0                   5.0       5641.0
#
#            bc_open_to_buy  bc_util  chargeoff_within_12_mths  delinq_amnt  \
# id
# 167338079         12529.5     40.2                       0.0          0.0
# 71016917           7741.0     40.5                       0.0          0.0
# 39589826           4521.0     54.8                       0.0          0.0
# 134798709         43140.0     12.0                       0.0          0.0
# 127097355         17318.0     39.9                       0.0          0.0
#
#            mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  \
# id
# 167338079               179.0                  75.0                   38.0
# 71016917                145.0                 137.0                    7.0
# 39589826                 57.0                  57.0                   14.0
# 134798709                37.0                 132.0                    1.0
# 127097355                72.0                 117.0                    6.0
#
#            mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  \
# id
# 167338079            16.0       2.0                   6.5
# 71016917              7.0       0.0                   7.0
# 39589826              9.0       1.0                  14.0
# 134798709             1.0       2.0                   1.0
# 127097355             6.0       2.0                   6.0
#
#            mths_since_recent_bc_dlq  mths_since_recent_inq  \
# id
# 167338079                      19.0                   16.0
# 71016917                        0.0                   24.0
# 39589826                        0.0                    1.0
# 134798709                       0.0                    3.0
# 127097355                       0.0                    5.0
#
#            mths_since_recent_revol_delinq  num_accts_ever_120_pd  \
# id
# 167338079                            19.0                    1.0
# 71016917                              0.0                    0.0
# 39589826                              0.0                    0.0
# 134798709                             0.0                    1.0
# 127097355                             0.0                    0.0
#
#            num_actv_bc_tl  num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  \
# id
# 167338079             0.0              2.0          0.0        1.0        5.0
# 71016917              3.0              5.0          5.0        6.0       15.0
# 39589826              3.0              5.0          3.0        3.0        2.0
# 134798709             6.0              7.0         11.0       16.0        2.0
# 127097355             4.0              5.0          5.0        6.0        5.0
#
#            num_op_rev_tl  num_rev_accts  num_rev_tl_bal_gt_0  num_sats  \
# id
# 167338079            2.0            5.0                  2.0       4.0
# 71016917             7.0            9.0                  5.0      10.0
# 39589826             5.0            6.0                  5.0       7.0
# 134798709           13.0           19.0                  7.0      15.0
# 127097355           13.0           16.0                  5.0      16.0
#
#            num_tl_120dpd_2m  num_tl_30dpd  num_tl_90g_dpd_24m  \
# id
# 167338079               0.0           0.0                 0.0
# 71016917                0.0           0.0                 0.0
# 39589826                0.0           0.0                 0.0
# 134798709               0.0           0.0                 0.0
# 127097355               0.0           0.0                 0.0
#
#            num_tl_op_past_12m  pct_tl_nvr_dlq  percent_bc_gt_75  \
# id
# 167338079                 0.0            75.0             16.65
# 71016917                  1.0            95.8             60.00
# 39589826                  1.0           100.0             33.30
# 134798709                 2.0            95.7              0.00
# 127097355                 4.0           100.0              0.00
#
#            pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# id
# 167338079                   1.0        0.0         395328.0
# 71016917                    0.0        0.0          88154.0
# 39589826                    0.0        1.0         171118.0
# 134798709                   0.0        0.0         202606.0
# 127097355                   0.0        0.0         152081.0
#
#            total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# id
# 167338079            11948.0             0.0                     17928.0
# 71016917             61815.0         13000.0                     52954.0
# 39589826             13124.0         10000.0                      7526.0
# 134798709            18520.0         49000.0                     20000.0
# 127097355            34847.0         28800.0                     38181.0
#
#            revol_bal_joint  sec_app_fico_range_low  sec_app_fico_range_high  \
# id
# 167338079              0.0                     0.0                      0.0
# 71016917               0.0                     0.0                      0.0
# 39589826               0.0                     0.0                      0.0
# 134798709              0.0                     0.0                      0.0
# 127097355              0.0                     0.0                      0.0
#
#           sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# id
# 167338079                      NaT                     0.0               0.0
# 71016917                       NaT                     0.0               0.0
# 39589826                       NaT                     0.0               0.0
# 134798709                      NaT                     0.0               0.0
# 127097355                      NaT                     0.0               0.0
#
#            sec_app_open_acc  sec_app_revol_util  sec_app_open_act_il  \
# id
# 167338079               0.0                 0.0                  0.0
# 71016917                0.0                 0.0                  0.0
# 39589826                0.0                 0.0                  0.0
# 134798709               0.0                 0.0                  0.0
# 127097355               0.0                 0.0                  0.0
#
#            sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# id
# 167338079                    0.0                               0.0
# 71016917                     0.0                               0.0
# 39589826                     0.0                               0.0
# 134798709                    0.0                               0.0
# 127097355                    0.0                               0.0
#
#            sec_app_collections_12_mths_ex_med  hardship_flag hardship_type  \
# id
# 167338079                                 0.0          False          none
# 71016917                                  0.0          False          none
# 39589826                                  0.0          False          none
# 134798709                                 0.0          False          none
# 127097355                                 0.0          False          none
#
#           hardship_reason hardship_status  deferral_term  hardship_amount  \
# id
# 167338079            none            none            0.0              0.0
# 71016917             none            none            0.0              0.0
# 39589826             none            none            0.0              0.0
# 134798709            none            none            0.0              0.0
# 127097355            none            none            0.0              0.0
#
#           hardship_start_date hardship_end_date payment_plan_start_date  \
# id
# 167338079                 NaT               NaT                     NaT
# 71016917                  NaT               NaT                     NaT
# 39589826                  NaT               NaT                     NaT
# 134798709                 NaT               NaT                     NaT
# 127097355                 NaT               NaT                     NaT
#
#            hardship_length  hardship_dpd hardship_loan_status  \
# id
# 167338079              0.0           0.0                 none
# 71016917               0.0           0.0                 none
# 39589826               0.0           0.0                 none
# 134798709              0.0           0.0                 none
# 127097355              0.0           0.0                 none
#
#            orig_projected_additional_accrued_interest  \
# id
# 167338079                                         0.0
# 71016917                                          0.0
# 39589826                                          0.0
# 134798709                                         0.0
# 127097355                                         0.0
#
#            hardship_payoff_balance_amount  hardship_last_payment_amount  \
# id
# 167338079                             0.0                           0.0
# 71016917                              0.0                           0.0
# 39589826                              0.0                           0.0
# 134798709                             0.0                           0.0
# 127097355                             0.0                           0.0
#
#            debt_settlement_flag
# id
# 167338079                 False
# 71016917                  False
# 39589826                  False
# 134798709                 False
# 127097355                 False

# %% [markdown]
# This functions works as expected and was used in pipeline to clean intermediate dataset (i.e. drop columns that will not be used in model and fill missed values) into primary dataset here:
# - `src\lending_club\pipelines\data_clean\nodes.py`
# - `src\lending_club\pipelines\data_clean\pipeline.py`
#
# Produce  primary dataset:

# %%
# !kedro run -p data_clean
# Out:
# [11/04/24 13:49:32] INFO     Using 'D:\Program                  __init__.py:270
#                              Files\Python\Python
#                              Venv\lc\lib\site-packages\kedro\fr
#                              amework\project\rich_logging.yml'
#                              as logging configuration.
# [11/04/24 13:49:34] INFO     Kedro project lending-club          session.py:329
# [11/04/24 13:49:38] WARNING  D:\Program Files\Python\Python     warnings.py:109
#                              Venv\lc\lib\site-packages\kedro\fr
#                              amework\project\__init__.py:347:
#                              UserWarning: The
#                              'lending_club.pipelines.outliers'
#                              module does not expose a
#                              'create_pipeline' function, so no
#                              pipelines defined therein will be
#                              returned by 'find_pipelines'.
#                                warnings.warn(
#
#                     INFO     Using synchronous mode for sequential_runner.py:67
#                              loading and saving data.
#                              Use the --async flag for
#                              potential performance
#                              gains.
#                              https://docs.kedro.org/en/
#                              stable/nodes_and_pipelines
#                              /run_a_pipeline.html#load-
#                              and-save-asynchronously
#                     INFO     Loading data from              data_catalog.py:389
#                              intermediate_lc_dataset
#                              (ParquetDataset)...
# [11/04/24 13:49:39] INFO     Loading data from parameters   data_catalog.py:389
#                              (MemoryDataset)...
# [11/04/24 13:49:40] INFO     Running node: clean_dataset_node:      node.py:367
#                              clean_dataset([intermediate_lc_dataset
#                              ;parameters]) ->
#                              [intermediate_lc_clean]
# [11/04/24 13:49:44] INFO     Saving data to                 data_catalog.py:431
#                              intermediate_lc_clean
#                              (ParquetDataset)...
# [11/04/24 13:49:46] INFO     Completed 1 out of 1 tasks sequential_runner.py:93
#                     INFO     Pipeline execution completed         runner.py:125
#                              successfully.

# %% [markdown]
# ## Outliers

# %%
# Load new dataset
lending_club = catalog.load('intermediate_lc_clean')
# Out:
# [11/04/24 13:49:47] INFO     Loading data from intermediate_lc_clean (ParquetDataset)...        data_catalog.py:389

# %% [markdown]
# **Z score** method will be used to detect and handle outliers

# %%
from scipy import stats

z_scores = np.abs(stats.zscore(lending_club.select_dtypes(np.number)))
outlier_volume = pd.DataFrame()
columns = []
# Threshold in range of 2.5 - 3.5
for threshold in range(250, 351, 25):
    thresh = threshold/100

    # How many outliers identified for each numerical columns?
    gt_thresh = z_scores > thresh
    columns += [f"tr: {thresh}, %"]
    outlier_volume[columns[-1]] = gt_thresh.sum() / z_scores.shape[0] * 100

print(f"Average outliers share:\n{outlier_volume.mean()}")
outlier_volume.sort_values(columns[-1], ascending=False)
# Out:
# Average outliers share:
# tr: 2.5, %     2.557789
# tr: 2.75, %    2.028624
# tr: 3.0, %     1.652422
# tr: 3.25, %    1.336339
# tr: 3.5, %     1.101688
# dtype: float64
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                             tr: 2.5, %  tr: 2.75, %  \
# sec_app_fico_range_high                          6.740        6.740
# sec_app_fico_range_low                           6.740        6.740
# deferral_term                                    4.893        4.893
# hardship_length                                  4.893        4.893
# sec_app_revol_util                               4.615        4.320
# dti_joint                                        4.938        4.457
# sec_app_open_acc                                 3.863        3.406
# hardship_payoff_balance_amount                   3.094        2.882
# sec_app_num_rev_accts                            3.529        3.201
# annual_inc_joint                                 4.312        3.698
# mths_since_rcnt_il                               3.024        2.723
# open_act_il                                      2.902        2.902
# last_fico_range_low                              1.790        1.790
# revol_bal_joint                                  2.824        2.511
# last_pymnt_amnt                                  4.116        3.336
# sec_app_mort_acc                                 2.785        2.785
# recoveries                                       2.613        2.326
# collections_12_mths_ex_med                       1.634        1.634
# total_cu_tl                                      2.903        2.903
# collection_recovery_fee                          2.501        2.224
# mo_sin_rcnt_rev_tl_op                            3.066        2.533
# inq_last_12m                                     3.502        2.305
# mths_since_recent_bc                             3.358        2.773
# out_prncp_inv                                    4.312        3.419
# out_prncp                                        4.311        3.419
# total_bal_il                                     2.758        2.319
# bc_open_to_buy                                   3.134        2.590
# num_accts_ever_120_pd                            3.371        2.204
# max_bal_bc                                       3.273        2.644
# total_rec_int                                    3.276        2.677
# inq_fi                                           2.466        2.466
# pct_tl_nvr_dlq                                   3.545        2.806
# total_bal_ex_mort                                2.747        2.256
# sec_app_open_act_il                              1.968        1.968
# open_rv_12m                                      2.596        2.596
# orig_projected_additional_accrued_interest       2.049        1.826
# mths_since_last_record                           6.319        4.951
# total_il_high_credit_limit                       2.728        2.253
# total_bc_limit                                   3.012        2.423
# avg_cur_bal                                      2.692        2.162
# hardship_amount                                  1.370        1.330
# total_rev_hi_lim                                 2.379        1.984
# mths_since_recent_bc_dlq                         5.355        4.311
# mo_sin_rcnt_tl                                   2.358        2.001
# num_tl_90g_dpd_24m                               1.145        1.145
# delinq_2yrs                                      2.346        2.346
# num_il_tl                                        3.101        2.410
# open_il_12m                                      3.490        3.490
# revol_bal                                        1.862        1.588
# open_rv_24m                                      3.493        2.317
# inq_last_6mths                                   3.783        3.783
# sec_app_inq_last_6mths                           2.665        2.665
# num_actv_bc_tl                                   2.490        1.606
# open_il_24m                                      3.858        1.907
# num_bc_sats                                      2.561        1.833
# mort_acc                                         1.844        1.844
# tot_cur_bal                                      2.531        1.929
# tot_hi_cred_lim                                  2.500        1.900
# num_op_rev_tl                                    2.281        1.842
# total_rec_late_fee                               1.473        1.335
# num_bc_tl                                        2.323        1.814
# open_acc_6m                                      2.356        2.356
# num_actv_rev_tl                                  2.131        2.131
# num_rev_accts                                    2.489        1.825
# open_acc                                         2.188        1.771
# il_util                                          3.602        2.529
# num_tl_op_past_12m                               2.538        1.356
# num_sats                                         2.655        1.745
# chargeoff_within_12_mths                         0.741        0.741
# num_rev_tl_bal_gt_0                              2.753        1.949
# acc_open_past_24mths                             2.147        1.468
# tax_liens                                        2.208        0.702
# tot_coll_amt                                     1.009        0.902
# pub_rec                                          1.807        1.807
# hardship_dpd                                     0.714        0.689
# mo_sin_old_rev_tl_op                             2.323        1.669
# pub_rec_bankruptcies                             0.481        0.481
# total_acc                                        2.062        1.428
# mo_sin_old_il_acct                               1.654        1.155
# annual_inc                                       0.910        0.666
# fico_range_high                                  2.399        1.899
# fico_range_low                                   2.399        1.899
# sec_app_collections_12_mths_ex_med               0.358        0.358
# total_pymnt                                      3.181        2.129
# total_pymnt_inv                                  3.178        2.128
# acc_now_delinq                                   0.323        0.323
# dti                                              0.503        0.421
# int_rate                                         2.226        1.176
# mths_since_recent_revol_delinq                   4.853        3.188
# num_tl_30dpd                                     0.213        0.213
# mths_since_last_major_derog                      4.652        3.059
# sec_app_chargeoff_within_12_mths                 0.181        0.181
# hardship_last_payment_amount                     0.211        0.199
# all_util                                         2.326        1.470
# installment                                      2.909        1.955
# mths_since_last_delinq                           2.443        0.776
# delinq_amnt                                      0.058        0.056
# num_tl_120dpd_2m                                 0.041        0.041
# last_fico_range_high                             1.790        0.009
# revol_util                                       0.019        0.009
# bc_util                                          0.019        0.010
# percent_bc_gt_75                                 0.000        0.000
# mths_since_recent_inq                            3.147        1.264
# funded_amnt                                      2.329        0.000
# policy_code                                      0.000        0.000
# total_rec_prncp                                  3.253        2.653
# term                                             0.000        0.000
# funded_amnt_inv                                  2.327        0.000
# loan_amnt                                        2.293        0.000
#
#                                             tr: 3.0, %  tr: 3.25, %  \
# sec_app_fico_range_high                          6.697        6.418
# sec_app_fico_range_low                           6.697        6.418
# deferral_term                                    4.893        4.893
# hardship_length                                  4.893        4.893
# sec_app_revol_util                               3.988        3.623
# dti_joint                                        3.976        3.524
# sec_app_open_acc                                 3.002        3.002
# hardship_payoff_balance_amount                   2.677        2.455
# sec_app_num_rev_accts                            2.834        2.530
# annual_inc_joint                                 3.148        2.673
# mths_since_rcnt_il                               2.413        2.152
# open_act_il                                      2.303        2.303
# last_fico_range_low                              1.790        1.790
# revol_bal_joint                                  2.266        2.006
# last_pymnt_amnt                                  2.707        2.208
# sec_app_mort_acc                                 2.785        1.727
# recoveries                                       2.068        1.831
# collections_12_mths_ex_med                       1.634        1.634
# total_cu_tl                                      2.127        2.127
# collection_recovery_fee                          1.982        1.773
# mo_sin_rcnt_rev_tl_op                            2.214        1.827
# inq_last_12m                                     2.305        1.569
# mths_since_recent_bc                             2.324        1.900
# out_prncp_inv                                    2.703        2.066
# out_prncp                                        2.704        2.066
# total_bal_il                                     2.000        1.721
# bc_open_to_buy                                   2.125        1.765
# num_accts_ever_120_pd                            2.204        2.204
# max_bal_bc                                       2.126        1.729
# total_rec_int                                    2.130        1.742
# inq_fi                                           2.466        1.347
# pct_tl_nvr_dlq                                   2.163        1.676
# total_bal_ex_mort                                1.884        1.573
# sec_app_open_act_il                              1.968        1.312
# open_rv_12m                                      2.596        1.302
# orig_projected_additional_accrued_interest       1.618        1.460
# mths_since_last_record                           3.590        2.408
# total_il_high_credit_limit                       1.832        1.504
# total_bc_limit                                   1.962        1.550
# avg_cur_bal                                      1.734        1.419
# hardship_amount                                  1.290        1.239
# total_rev_hi_lim                                 1.660        1.382
# mths_since_recent_bc_dlq                         3.397        2.285
# mo_sin_rcnt_tl                                   1.726        1.370
# num_tl_90g_dpd_24m                               1.145        1.145
# delinq_2yrs                                      2.346        2.346
# num_il_tl                                        1.848        1.450
# open_il_12m                                      1.089        1.089
# revol_bal                                        1.375        1.205
# open_rv_24m                                      2.317        1.548
# inq_last_6mths                                   1.009        1.009
# sec_app_inq_last_6mths                           2.665        0.995
# num_actv_bc_tl                                   1.606        0.982
# open_il_24m                                      1.907        1.907
# num_bc_sats                                      1.318        1.318
# mort_acc                                         0.967        0.967
# tot_cur_bal                                      1.494        1.160
# tot_hi_cred_lim                                  1.473        1.146
# num_op_rev_tl                                    1.455        1.166
# total_rec_late_fee                               1.186        0.991
# num_bc_tl                                        1.405        1.121
# open_acc_6m                                      2.356        0.865
# num_actv_rev_tl                                  1.544        1.164
# num_rev_accts                                    1.387        1.039
# open_acc                                         1.428        0.934
# il_util                                          1.773        1.193
# num_tl_op_past_12m                               1.356        1.356
# num_sats                                         1.409        0.915
# chargeoff_within_12_mths                         0.741        0.741
# num_rev_tl_bal_gt_0                              1.379        1.015
# acc_open_past_24mths                             1.468        1.039
# tax_liens                                        0.702        0.702
# tot_coll_amt                                     0.813        0.737
# pub_rec                                          1.807        1.807
# hardship_dpd                                     0.689        0.689
# mo_sin_old_rev_tl_op                             1.129        0.763
# pub_rec_bankruptcies                             0.481        0.481
# total_acc                                        0.998        0.657
# mo_sin_old_il_acct                               0.794        0.560
# annual_inc                                       0.567        0.454
# fico_range_high                                  1.107        0.576
# fico_range_low                                   1.107        0.576
# sec_app_collections_12_mths_ex_med               0.358        0.358
# total_pymnt                                      1.189        0.615
# total_pymnt_inv                                  1.184        0.625
# acc_now_delinq                                   0.323        0.323
# dti                                              0.365        0.328
# int_rate                                         0.873        0.396
# mths_since_recent_revol_delinq                   1.885        0.719
# num_tl_30dpd                                     0.213        0.213
# mths_since_last_major_derog                      1.224        0.314
# sec_app_chargeoff_within_12_mths                 0.181        0.181
# hardship_last_payment_amount                     0.189        0.185
# all_util                                         0.849        0.206
# installment                                      0.682        0.244
# mths_since_last_delinq                           0.111        0.081
# delinq_amnt                                      0.053        0.052
# num_tl_120dpd_2m                                 0.041        0.041
# last_fico_range_high                             0.009        0.009
# revol_util                                       0.007        0.005
# bc_util                                          0.009        0.006
# percent_bc_gt_75                                 0.000        0.000
# mths_since_recent_inq                            0.419        0.000
# funded_amnt                                      0.000        0.000
# policy_code                                      0.000        0.000
# total_rec_prncp                                  0.709        0.556
# term                                             0.000        0.000
# funded_amnt_inv                                  0.000        0.000
# loan_amnt                                        0.000        0.000
#
#                                             tr: 3.5, %
# sec_app_fico_range_high                          5.517
# sec_app_fico_range_low                           5.517
# deferral_term                                    4.893
# hardship_length                                  4.893
# sec_app_revol_util                               3.303
# dti_joint                                        3.087
# sec_app_open_acc                                 2.583
# hardship_payoff_balance_amount                   2.273
# sec_app_num_rev_accts                            2.239
# annual_inc_joint                                 2.203
# mths_since_rcnt_il                               1.909
# open_act_il                                      1.839
# last_fico_range_low                              1.790
# revol_bal_joint                                  1.777
# last_pymnt_amnt                                  1.742
# sec_app_mort_acc                                 1.727
# recoveries                                       1.654
# collections_12_mths_ex_med                       1.634
# total_cu_tl                                      1.622
# collection_recovery_fee                          1.602
# mo_sin_rcnt_rev_tl_op                            1.575
# inq_last_12m                                     1.569
# mths_since_recent_bc                             1.536
# out_prncp_inv                                    1.487
# out_prncp                                        1.485
# total_bal_il                                     1.463
# bc_open_to_buy                                   1.461
# num_accts_ever_120_pd                            1.449
# max_bal_bc                                       1.444
# total_rec_int                                    1.412
# inq_fi                                           1.347
# pct_tl_nvr_dlq                                   1.340
# total_bal_ex_mort                                1.340
# sec_app_open_act_il                              1.312
# open_rv_12m                                      1.302
# orig_projected_additional_accrued_interest       1.295
# mths_since_last_record                           1.282
# total_il_high_credit_limit                       1.246
# total_bc_limit                                   1.227
# avg_cur_bal                                      1.207
# hardship_amount                                  1.194
# total_rev_hi_lim                                 1.183
# mths_since_recent_bc_dlq                         1.181
# mo_sin_rcnt_tl                                   1.173
# num_tl_90g_dpd_24m                               1.145
# delinq_2yrs                                      1.142
# num_il_tl                                        1.122
# open_il_12m                                      1.089
# revol_bal                                        1.064
# open_rv_24m                                      1.051
# inq_last_6mths                                   1.009
# sec_app_inq_last_6mths                           0.995
# num_actv_bc_tl                                   0.982
# open_il_24m                                      0.981
# num_bc_sats                                      0.968
# mort_acc                                         0.967
# tot_cur_bal                                      0.936
# tot_hi_cred_lim                                  0.908
# num_op_rev_tl                                    0.907
# total_rec_late_fee                               0.893
# num_bc_tl                                        0.877
# open_acc_6m                                      0.865
# num_actv_rev_tl                                  0.853
# num_rev_accts                                    0.771
# open_acc                                         0.759
# il_util                                          0.754
# num_tl_op_past_12m                               0.746
# num_sats                                         0.744
# chargeoff_within_12_mths                         0.741
# num_rev_tl_bal_gt_0                              0.733
# acc_open_past_24mths                             0.718
# tax_liens                                        0.702
# tot_coll_amt                                     0.678
# pub_rec                                          0.660
# hardship_dpd                                     0.650
# mo_sin_old_rev_tl_op                             0.538
# pub_rec_bankruptcies                             0.481
# total_acc                                        0.451
# mo_sin_old_il_acct                               0.410
# annual_inc                                       0.394
# fico_range_high                                  0.393
# fico_range_low                                   0.393
# sec_app_collections_12_mths_ex_med               0.358
# total_pymnt                                      0.330
# total_pymnt_inv                                  0.327
# acc_now_delinq                                   0.323
# dti                                              0.290
# int_rate                                         0.285
# mths_since_recent_revol_delinq                   0.225
# num_tl_30dpd                                     0.213
# mths_since_last_major_derog                      0.202
# sec_app_chargeoff_within_12_mths                 0.181
# hardship_last_payment_amount                     0.179
# all_util                                         0.130
# installment                                      0.091
# mths_since_last_delinq                           0.060
# delinq_amnt                                      0.050
# num_tl_120dpd_2m                                 0.041
# last_fico_range_high                             0.009
# revol_util                                       0.004
# bc_util                                          0.002
# percent_bc_gt_75                                 0.000
# mths_since_recent_inq                            0.000
# funded_amnt                                      0.000
# policy_code                                      0.000
# total_rec_prncp                                  0.000
# term                                             0.000
# funded_amnt_inv                                  0.000
# loan_amnt                                        0.000

# %% [markdown]
# **Z-score** treshold at **3.5** suits best for handling outliers since the average share of outliers in this case is `1.1%`.
# However, I prefer to address outliers later on by normalizing or standardizing datasets after splitting it to train/test sets - to avoid data leakage in my model.

# %% [markdown]
# ## Encoding

# %%
# Load 'intermediate clean' dataset
lending_club: pd.DataFrame = catalog.load('intermediate_lc_clean')
# Out:
# [11/04/24 13:49:49] INFO     Loading data from intermediate_lc_clean (ParquetDataset)...        data_catalog.py:389

# %%
# Select all 'object' features and split it to three dictionary records
# that will be encoded in different way:
# - loan status:        target  default status (true/false)
# - employment length:  parse to range (0-10) as dataset's dictionary mention
# - rest of features:   one-hot encoding
encode_dict = {
    "default": 'loan_status',
    "emp_len":  'emp_length',
    "category": list(set(lending_club.select_dtypes(object).columns.to_list())
                     - set(['emp_length', 'loan_status']))
}
# Print dictionary to paste in 'parameters_encode.yml'
for key in encode_dict.keys():
    value = encode_dict[key]
    if isinstance(value, str):
        print(f"{key}: {value}")
    else:
        print(f"{key}:")
        for val in value:
            print(f"  - {val}")
# Out:
# default: loan_status
# emp_len: emp_length
# category:
#   - grade
#   - verification_status_joint
#   - hardship_reason
#   - home_ownership
#   - hardship_status
#   - application_type
#   - hardship_type
#   - purpose
#   - verification_status
#   - addr_state
#   - sub_grade
#   - hardship_loan_status
#   - pymnt_plan
#   - initial_list_status

# %%
# Identify loan status to pick up defaults ones
lending_club.loan_status.value_counts()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# loan_status
# Fully Paid                                             51189
# Current                                                35294
# Charged Off                                            12384
# Late (31-120 days)                                       535
# In Grace Period                                          329
# Late (16-30 days)                                         90
# Does not meet the credit policy. Status:Fully Paid        69
# Issued                                                    63
# Does not meet the credit policy. Status:Charged Off       33
# Default                                                   14
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import OrdinalEncoder

# Function to encode emp_length to number
def _parse_emp_len(df: pd.DataFrame, params: dict) -> pd.DataFrame:
    return df[params['emp_len']].str.split(" ").str[0].str.replace("+", "").str.replace("<", "0").astype(int)

# Function to encode default_status from loan_status
def _default_status(df: pd.DataFrame, params: dict) -> pd.DataFrame:
    df['default_status'] = (
            (df[params['default']] == 'Charged Off') |
            (df[params['default']] == 'Does not meet the credit policy. Status:Charged Off') |
            (df[params['default']] == 'Default')
    )
    return df

# Function encodes object values to numbers
def _encode(df: pd.DataFrame, params: dict) -> pd.DataFrame:
    encoder = OrdinalEncoder()
    df[params['category']] = encoder.fit_transform(df[params['category']])
    return df

# %% [markdown]
# ## Test functions

# %%
# Test _parse_emp_len function
df = lending_club[['emp_length']].value_counts().reset_index()
df['emp_len_num'] = _parse_emp_len(df, encode_dict)
df.sort_values('emp_len_num')
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#    emp_length  count  emp_len_num
# 1    < 1 year   9306            0
# 4      1 year   6714            1
# 2     2 years   9014            2
# 3     3 years   7862            3
# 6     4 years   6009            4
# 5     5 years   6158            5
# 7     6 years   4496            6
# 8     7 years   4051            7
# 9     8 years   3919            8
# 10    9 years   3314            9
# 0   10+ years  39157           10

# %%
# Test _default_status function
df = lending_club[['loan_status']]
df = _default_status(df, encode_dict)

pd.pivot_table(data=df,
               index=['loan_status', 'default_status'],
               aggfunc='count')
# Out:
# [11/04/24 13:49:50] WARNING  C:\Users\chemerys\AppData\Local\Temp\ipykernel_23872\27471672.py:9:    ]8;id=637693;file://C:\Users\chemerys\AppData\Roaming\uv\python\cpython-3.10.15-windows-x86_64-none\lib\warnings.py\warnings.py]8;;\:]8;id=128488;file://C:\Users\chemerys\AppData\Roaming\uv\python\cpython-3.10.15-windows-x86_64-none\lib\warnings.py#109\109]8;;\
#                              SettingWithCopyWarning:
#                              A value is trying to be set on a copy of a slice from a DataFrame.
#                              Try using .loc[row_indexer,col_indexer] = value instead
#
#                              See the caveats in the documentation:
#                              https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#
#                              returning-a-view-versus-a-copy
#                                df['default_status'] = (
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Empty DataFrame
# Columns: []
# Index: [(Charged Off, True), (Current, False), (Default, True), (Does not meet the credit policy. Status:Charged Off, True), (Does not meet the credit policy. Status:Fully Paid, False), (Fully Paid, False), (In Grace Period, False), (Issued, False), (Late (16-30 days), False), (Late (31-120 days), False)]

# %%
# Test encode function
df = lending_club[encode_dict['category']].head(100)
_encode(df, encode_dict).head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#            grade  verification_status_joint  hardship_reason  home_ownership  \
# id
# 167338079    1.0                        3.0              5.0             0.0
# 71016917     1.0                        3.0              5.0             2.0
# 39589826     1.0                        3.0              5.0             0.0
# 134798709    1.0                        3.0              5.0             0.0
# 127097355    2.0                        3.0              5.0             0.0
#
#            hardship_status  application_type  hardship_type  purpose  \
# id
# 167338079              3.0               0.0            2.0      3.0
# 71016917               3.0               0.0            2.0      1.0
# 39589826               3.0               0.0            2.0      1.0
# 134798709              3.0               0.0            2.0      2.0
# 127097355              3.0               0.0            2.0      2.0
#
#            verification_status  addr_state  sub_grade  hardship_loan_status  \
# id
# 167338079                  1.0        18.0        9.0                   3.0
# 71016917                   1.0         9.0        6.0                   3.0
# 39589826                   0.0         5.0        7.0                   3.0
# 134798709                  0.0        19.0        8.0                   3.0
# 127097355                  1.0        15.0       11.0                   3.0
#
#            pymnt_plan  initial_list_status
# id
# 167338079         0.0                  1.0
# 71016917          0.0                  1.0
# 39589826          0.0                  0.0
# 134798709         0.0                  1.0
# 127097355         0.0                  1.0

# %% [markdown]
# Functions works as expected. Therefore they used for encoding categorical values to integers in `intermedian clean` dataset transformation in `encode` pipeline:
# - `src/lending_club/pipelines/encode/nodes.py`
# - `src/lending_club/pipelines/encode/pipeline.py`
#
# Run this transformation to create new `encoded` dataset that contains only encoded categorical values:

# %%
# !kedro run -p encode
# Out:
# [11/04/24 13:49:52] INFO     Using 'D:\Program                  __init__.py:270
#                              Files\Python\Python
#                              Venv\lc\lib\site-packages\kedro\fr
#                              amework\project\rich_logging.yml'
#                              as logging configuration.
# [11/04/24 13:49:54] INFO     Kedro project lending-club          session.py:329
# [11/04/24 13:49:57] WARNING  D:\Program Files\Python\Python     warnings.py:109
#                              Venv\lc\lib\site-packages\kedro\fr
#                              amework\project\__init__.py:347:
#                              UserWarning: The
#                              'lending_club.pipelines.outliers'
#                              module does not expose a
#                              'create_pipeline' function, so no
#                              pipelines defined therein will be
#                              returned by 'find_pipelines'.
#                                warnings.warn(
#
# [11/04/24 13:49:58] INFO     Using synchronous mode for sequential_runner.py:67
#                              loading and saving data.
#                              Use the --async flag for
#                              potential performance
#                              gains.
#                              https://docs.kedro.org/en/
#                              stable/nodes_and_pipelines
#                              /run_a_pipeline.html#load-
#                              and-save-asynchronously
#                     INFO     Loading data from              data_catalog.py:389
#                              intermediate_lc_clean
#                              (ParquetDataset)...
#                     INFO     Loading data from parameters   data_catalog.py:389
#                              (MemoryDataset)...
# [11/04/24 13:49:59] INFO     Running node: encode_dataset_node:     node.py:367
#                              encode_dataset([intermediate_lc_clean;
#                              parameters]) -> [intermediate_encoded]
# [11/04/24 13:50:00] INFO     Saving data to                 data_catalog.py:431
#                              intermediate_encoded
#                              (ParquetDataset)...
#                     INFO     Completed 1 out of 1 tasks sequential_runner.py:93
#                     INFO     Pipeline execution completed         runner.py:125
#                              successfully.

# %% [markdown]
# # Features engineering

# %%
# Load cleaned data
lending_club = catalog.load('intermediate_lc_clean')
# Out:
# [11/04/24 13:50:01] INFO     Loading data from intermediate_lc_clean (ParquetDataset)...        data_catalog.py:389

# %% [markdown]
# ## Date features

# %%
# Look at date features to choose what could be used for new features
date_val = lending_club.select_dtypes('datetime64').columns
date_val = date_val.to_frame()
date_val = pd.concat([date_val, lc_dict], axis=1, join='inner').drop(0, axis=1)
date_val
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                                                                                                                                                                                                                         Description
# issue_d                                                                                                                                                                                                                         The month which the loan was funded
# earliest_cr_line                                                                                                                                                                                  The month the borrower's earliest reported credit line was opened
# last_pymnt_d                                                                                                                                                                                                                        Last month payment was received
# next_pymnt_d                                                                                                                                                                                                                            Next scheduled payment date
# last_credit_pull_d                                                                                                                                                                                             The most recent month LC pulled credit for this loan
# sec_app_earliest_cr_line                                                                                                                                                                    Earliest credit line at time of application for the secondary applicant
# hardship_start_date                                                                                                                                                                                                      The start date of the hardship plan period
# hardship_end_date                                                                                                                                                                                                          The end date of the hardship plan period
# payment_plan_start_date   The day the first hardship plan payment is due. For example, if a borrower has a hardship plan period of 3 months, the start date is the start of the three-month period in which the borrower is allowed to make interest-only payments.

# %%
# Define dates feature engineering function
def _dates_fe(df: pd.DataFrame, params: dict) -> pd.DataFrame:
    # Feature engineering dataset will be new dataframe
    fe_df = pd.DataFrame()
    # Calculate how many months ago the earliest credit line was open
    fe_df['mo_since_earliest_cr_line'] = (
        (params['cur_date'] - df.earliest_cr_line) / pd.Timedelta(30, 'D')
    ).astype(int)
    fe_df['issue_y'] = df.issue_d.dt.year
    return fe_df

# %% [markdown]
# ### Testing functions

# %%
# Assume the last date of pulling credit history is
# in our current period and it will pass as parameter
params = {'cur_date': lending_club['last_credit_pull_d'].max()}
print(params)

# Test data feature engineering function
pd.concat([lending_club[['earliest_cr_line', 'issue_d']],
        _dates_fe(lending_club.select_dtypes('datetime64'), params)], axis=1).head()
# Out:
# {'cur_date': Timestamp('2020-10-01 00:00:00')}
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#           earliest_cr_line    issue_d  mo_since_earliest_cr_line  issue_y
# id
# 167338079       2004-12-01 2020-03-01                        192     2020
# 71016917        2004-01-01 2016-02-01                        203     2016
# 39589826        2010-04-01 2015-01-01                        127     2015
# 134798709       2005-10-01 2018-06-01                        182     2018
# 127097355       2008-04-01 2018-01-01                        152     2018

# %% [markdown]
# ## Other features

# %%
# Considering joint applications let's use new 'adjusted' features for annual income, dti and revol_bal
# that takes joint features where it is the case or individual features otherwise
def _adjusted_feat(df: pd.DataFrame, df_fe: pd.DataFrame) -> pd.DataFrame:
    df_fe['dti_adj'] = df.dti_joint.where(df.application_type == "Joint App", df.dti)
    df_fe['revol_bal_adj'] = df.revol_bal_joint.where(df.application_type == "Joint App", df.revol_bal)
    df_fe['annual_inc_adj'] = df.annual_inc_joint.where(df.application_type == "Joint App", df.annual_inc)

    # List of features of second applicant and aggregation function
    # that will be used to produce adjusted feature
    sec_extra_features=[
        ['sec_app_chargeoff_within_12_mths', 'sum'],
        ['sec_app_fico_range_high','max'],
        ['sec_app_inq_last_6mths', 'sum'],
        ['sec_app_mort_acc', 'sum'],
        ['sec_app_num_rev_accts','sum'],
        ['sec_app_open_acc','sum'],
        ['sec_app_open_act_il','sum'],
        ['sec_app_revol_util','avg']
        ]
    # Iterate trough sec_extra_feature list to make new features and remove original
    # features from model's features list
    for sec_feat, func in sec_extra_features:
        feat = sec_feat[8:]                                     # individual's feature name
        feat_adj = feat + "_adj"                                # new feature name
        if func == 'max':
            df_fe[feat_adj] = df[[feat, sec_feat]].max(axis=1)
        elif func == 'sum':
            df_fe[feat_adj] = df[[feat, sec_feat]].sum(axis=1)
        elif func == 'avg':
            df_fe[feat_adj] = df[[feat, sec_feat]].mean(axis=1)
    return df_fe

# %% [markdown]
# ### Testing function

# %%
# Test function output
_adjusted_feat(lending_club, pd.DataFrame()).head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#            dti_adj  revol_bal_adj  annual_inc_adj  \
# id
# 167338079    20.25         1988.0         48000.0
# 71016917     25.33        22697.0         57000.0
# 39589826      7.22         6001.0         55000.0
# 134798709    24.55         6573.0         43500.0
# 127097355    24.30        11894.0         48000.0
#
#            chargeoff_within_12_mths_adj  fico_range_high_adj  \
# id
# 167338079                           0.0                669.0
# 71016917                            0.0                684.0
# 39589826                            0.0                669.0
# 134798709                           0.0                754.0
# 127097355                           0.0                739.0
#
#            inq_last_6mths_adj  mort_acc_adj  num_rev_accts_adj  open_acc_adj  \
# id
# 167338079                 0.0           2.0                5.0           4.0
# 71016917                  0.0           0.0                9.0          10.0
# 39589826                  0.0           1.0                6.0           7.0
# 134798709                 0.0           2.0               19.0          15.0
# 127097355                 1.0           2.0               16.0          16.0
#
#            open_act_il_adj  revol_util_adj
# id
# 167338079              1.0           41.40
# 71016917               3.0           32.25
# 39589826               2.0           26.30
# 134798709              1.0            6.05
# 127097355              2.0           13.55

# %% [markdown]
# These functions will be used in `features_eng` node in `analysis` pipeline to get new features and evaluate along with other ones its correlation to target value:
# - `src\lending_club\pipelines\analysis\nodes.py`
# - `src\lending_club\pipelines\analysis\pipeline.py`

# %%
# !kedro run -p analysis -n features_eng_node
# Out:
# [11/04/24 14:16:51] INFO     Using 'D:\Program                  __init__.py:270
#                              Files\Python\Python
#                              Venv\lc\lib\site-packages\kedro\fr
#                              amework\project\rich_logging.yml'
#                              as logging configuration.
# [11/04/24 14:16:53] INFO     Kedro project lending-club          session.py:329
# [11/04/24 14:16:57] INFO     Using synchronous mode for sequential_runner.py:67
#                              loading and saving data.
#                              Use the --async flag for
#                              potential performance
#                              gains.
#                              https://docs.kedro.org/en/
#                              stable/nodes_and_pipelines
#                              /run_a_pipeline.html#load-
#                              and-save-asynchronously
#                     INFO     Loading data from              data_catalog.py:389
#                              intermediate_lc_clean
#                              (ParquetDataset)...
# [11/04/24 14:16:58] INFO     Loading data from parameters   data_catalog.py:389
#                              (MemoryDataset)...
#                     INFO     Running node: features_eng_node:       node.py:367
#                              features_eng([intermediate_lc_clean;pa
#                              rameters]) -> [features_new]
#                     INFO     Saving data to features_new    data_catalog.py:431
#                              (ParquetDataset)...
# [11/04/24 14:17:00] INFO     Completed 1 out of 1 tasks sequential_runner.py:93
#                     INFO     Pipeline execution completed         runner.py:125
#                              successfully.

# %% [markdown]
# # Exploring data

# %%
# Load cleaned, encoded data and new features
lending_club:       pd.DataFrame = catalog.load('intermediate_lc_clean')
lending_club_enc:   pd.DataFrame = catalog.load('intermediate_encoded')
lending_club_nf:    pd.DataFrame = catalog.load('features_new')
# Out:
# [11/04/24 14:17:07] INFO     Loading data from intermediate_lc_clean (ParquetDataset)...        data_catalog.py:389
# [11/04/24 14:17:08] INFO     Loading data from intermediate_encoded (ParquetDataset)...         data_catalog.py:389
#                     INFO     Loading data from features_new (ParquetDataset)...                 data_catalog.py:389

# %% [markdown]
# ## Preparing dataset for EDA

# %%
# Identify features that might be available at loan application time.
# For correlation analysis I will merge both datasets in the way,
# that encoded features will replace original categorical ones.
descr = pd.concat([lending_club.columns.to_frame(name='lc'),
           lending_club_enc.columns.to_frame(name='lc_enc'),
           lending_club_nf.columns.to_frame(name='lc_nf').assign(lc=lambda x: x.lc_nf.str.rstrip("_adj")).set_index('lc', drop=True),
           lc_dict], axis=1).reset_index()
descr
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                           index  \
# 0                                     loan_amnt
# 1                                   funded_amnt
# 2                               funded_amnt_inv
# 3                                          term
# 4                                      int_rate
# 5                                   installment
# 6                                         grade
# 7                                     sub_grade
# 8                                    emp_length
# 9                                home_ownership
# 10                                   annual_inc
# 11                          verification_status
# 12                                      issue_d
# 13                                  loan_status
# 14                                   pymnt_plan
# 15                                      purpose
# 16                                   addr_state
# 17                                          dti
# 18                                  delinq_2yrs
# 19                             earliest_cr_line
# 20                               fico_range_low
# 21                              fico_range_high
# 22                               inq_last_6mths
# 23                       mths_since_last_delinq
# 24                       mths_since_last_record
# 25                                     open_acc
# 26                                      pub_rec
# 27                                    revol_bal
# 28                                   revol_util
# 29                                    total_acc
# 30                          initial_list_status
# 31                                    out_prncp
# 32                                out_prncp_inv
# 33                                  total_pymnt
# 34                              total_pymnt_inv
# 35                              total_rec_prncp
# 36                                total_rec_int
# 37                           total_rec_late_fee
# 38                                   recoveries
# 39                      collection_recovery_fee
# 40                                 last_pymnt_d
# 41                              last_pymnt_amnt
# 42                                 next_pymnt_d
# 43                           last_credit_pull_d
# 44                         last_fico_range_high
# 45                          last_fico_range_low
# 46                   collections_12_mths_ex_med
# 47                  mths_since_last_major_derog
# 48                                  policy_code
# 49                             application_type
# 50                             annual_inc_joint
# 51                                    dti_joint
# 52                    verification_status_joint
# 53                               acc_now_delinq
# 54                                 tot_coll_amt
# 55                                  tot_cur_bal
# 56                                  open_acc_6m
# 57                                  open_act_il
# 58                                  open_il_12m
# 59                                  open_il_24m
# 60                           mths_since_rcnt_il
# 61                                 total_bal_il
# 62                                      il_util
# 63                                  open_rv_12m
# 64                                  open_rv_24m
# 65                                   max_bal_bc
# 66                                     all_util
# 67                             total_rev_hi_lim
# 68                                       inq_fi
# 69                                  total_cu_tl
# 70                                 inq_last_12m
# 71                         acc_open_past_24mths
# 72                                  avg_cur_bal
# 73                               bc_open_to_buy
# 74                                      bc_util
# 75                     chargeoff_within_12_mths
# 76                                  delinq_amnt
# 77                           mo_sin_old_il_acct
# 78                         mo_sin_old_rev_tl_op
# 79                        mo_sin_rcnt_rev_tl_op
# 80                               mo_sin_rcnt_tl
# 81                                     mort_acc
# 82                         mths_since_recent_bc
# 83                     mths_since_recent_bc_dlq
# 84                        mths_since_recent_inq
# 85               mths_since_recent_revol_delinq
# 86                        num_accts_ever_120_pd
# 87                               num_actv_bc_tl
# 88                              num_actv_rev_tl
# 89                                  num_bc_sats
# 90                                    num_bc_tl
# 91                                    num_il_tl
# 92                                num_op_rev_tl
# 93                                num_rev_accts
# 94                          num_rev_tl_bal_gt_0
# 95                                     num_sats
# 96                             num_tl_120dpd_2m
# 97                                 num_tl_30dpd
# 98                           num_tl_90g_dpd_24m
# 99                           num_tl_op_past_12m
# 100                              pct_tl_nvr_dlq
# 101                            percent_bc_gt_75
# 102                        pub_rec_bankruptcies
# 103                                   tax_liens
# 104                             tot_hi_cred_lim
# 105                           total_bal_ex_mort
# 106                              total_bc_limit
# 107                  total_il_high_credit_limit
# 108                             revol_bal_joint
# 109                      sec_app_fico_range_low
# 110                     sec_app_fico_range_high
# 111                    sec_app_earliest_cr_line
# 112                      sec_app_inq_last_6mths
# 113                            sec_app_mort_acc
# 114                            sec_app_open_acc
# 115                          sec_app_revol_util
# 116                         sec_app_open_act_il
# 117                       sec_app_num_rev_accts
# 118            sec_app_chargeoff_within_12_mths
# 119          sec_app_collections_12_mths_ex_med
# 120                               hardship_flag
# 121                               hardship_type
# 122                             hardship_reason
# 123                             hardship_status
# 124                               deferral_term
# 125                             hardship_amount
# 126                         hardship_start_date
# 127                           hardship_end_date
# 128                     payment_plan_start_date
# 129                             hardship_length
# 130                                hardship_dpd
# 131                        hardship_loan_status
# 132  orig_projected_additional_accrued_interest
# 133              hardship_payoff_balance_amount
# 134                hardship_last_payment_amount
# 135                        debt_settlement_flag
# 136                              default_status
# 137                                     issue_y
# 138                   mo_since_earliest_cr_line
# 139                   debt_settlement_flag_date
# 140                                        desc
# 141                         disbursement_method
# 142                                   emp_title
# 143                                          id
# 144                                   member_id
# 145         sec_app_mths_since_last_major_derog
# 146                           settlement_amount
# 147                             settlement_date
# 148                       settlement_percentage
# 149                           settlement_status
# 150                             settlement_term
# 151                                       title
# 152                                         url
# 153                       verified_status_joint
# 154                                    zip_code
#
#                                              lc                     lc_enc  \
# 0                                     loan_amnt                        NaN
# 1                                   funded_amnt                        NaN
# 2                               funded_amnt_inv                        NaN
# 3                                          term                        NaN
# 4                                      int_rate                        NaN
# 5                                   installment                        NaN
# 6                                         grade                      grade
# 7                                     sub_grade                  sub_grade
# 8                                    emp_length                 emp_length
# 9                                home_ownership             home_ownership
# 10                                   annual_inc                        NaN
# 11                          verification_status        verification_status
# 12                                      issue_d                        NaN
# 13                                  loan_status                        NaN
# 14                                   pymnt_plan                 pymnt_plan
# 15                                      purpose                    purpose
# 16                                   addr_state                 addr_state
# 17                                          dti                        NaN
# 18                                  delinq_2yrs                        NaN
# 19                             earliest_cr_line                        NaN
# 20                               fico_range_low                        NaN
# 21                              fico_range_high                        NaN
# 22                               inq_last_6mths                        NaN
# 23                       mths_since_last_delinq                        NaN
# 24                       mths_since_last_record                        NaN
# 25                                     open_acc                        NaN
# 26                                      pub_rec                        NaN
# 27                                    revol_bal                        NaN
# 28                                   revol_util                        NaN
# 29                                    total_acc                        NaN
# 30                          initial_list_status        initial_list_status
# 31                                    out_prncp                        NaN
# 32                                out_prncp_inv                        NaN
# 33                                  total_pymnt                        NaN
# 34                              total_pymnt_inv                        NaN
# 35                              total_rec_prncp                        NaN
# 36                                total_rec_int                        NaN
# 37                           total_rec_late_fee                        NaN
# 38                                   recoveries                        NaN
# 39                      collection_recovery_fee                        NaN
# 40                                 last_pymnt_d                        NaN
# 41                              last_pymnt_amnt                        NaN
# 42                                 next_pymnt_d                        NaN
# 43                           last_credit_pull_d                        NaN
# 44                         last_fico_range_high                        NaN
# 45                          last_fico_range_low                        NaN
# 46                   collections_12_mths_ex_med                        NaN
# 47                  mths_since_last_major_derog                        NaN
# 48                                  policy_code                        NaN
# 49                             application_type           application_type
# 50                             annual_inc_joint                        NaN
# 51                                    dti_joint                        NaN
# 52                    verification_status_joint  verification_status_joint
# 53                               acc_now_delinq                        NaN
# 54                                 tot_coll_amt                        NaN
# 55                                  tot_cur_bal                        NaN
# 56                                  open_acc_6m                        NaN
# 57                                  open_act_il                        NaN
# 58                                  open_il_12m                        NaN
# 59                                  open_il_24m                        NaN
# 60                           mths_since_rcnt_il                        NaN
# 61                                 total_bal_il                        NaN
# 62                                      il_util                        NaN
# 63                                  open_rv_12m                        NaN
# 64                                  open_rv_24m                        NaN
# 65                                   max_bal_bc                        NaN
# 66                                     all_util                        NaN
# 67                             total_rev_hi_lim                        NaN
# 68                                       inq_fi                        NaN
# 69                                  total_cu_tl                        NaN
# 70                                 inq_last_12m                        NaN
# 71                         acc_open_past_24mths                        NaN
# 72                                  avg_cur_bal                        NaN
# 73                               bc_open_to_buy                        NaN
# 74                                      bc_util                        NaN
# 75                     chargeoff_within_12_mths                        NaN
# 76                                  delinq_amnt                        NaN
# 77                           mo_sin_old_il_acct                        NaN
# 78                         mo_sin_old_rev_tl_op                        NaN
# 79                        mo_sin_rcnt_rev_tl_op                        NaN
# 80                               mo_sin_rcnt_tl                        NaN
# 81                                     mort_acc                        NaN
# 82                         mths_since_recent_bc                        NaN
# 83                     mths_since_recent_bc_dlq                        NaN
# 84                        mths_since_recent_inq                        NaN
# 85               mths_since_recent_revol_delinq                        NaN
# 86                        num_accts_ever_120_pd                        NaN
# 87                               num_actv_bc_tl                        NaN
# 88                              num_actv_rev_tl                        NaN
# 89                                  num_bc_sats                        NaN
# 90                                    num_bc_tl                        NaN
# 91                                    num_il_tl                        NaN
# 92                                num_op_rev_tl                        NaN
# 93                                num_rev_accts                        NaN
# 94                          num_rev_tl_bal_gt_0                        NaN
# 95                                     num_sats                        NaN
# 96                             num_tl_120dpd_2m                        NaN
# 97                                 num_tl_30dpd                        NaN
# 98                           num_tl_90g_dpd_24m                        NaN
# 99                           num_tl_op_past_12m                        NaN
# 100                              pct_tl_nvr_dlq                        NaN
# 101                            percent_bc_gt_75                        NaN
# 102                        pub_rec_bankruptcies                        NaN
# 103                                   tax_liens                        NaN
# 104                             tot_hi_cred_lim                        NaN
# 105                           total_bal_ex_mort                        NaN
# 106                              total_bc_limit                        NaN
# 107                  total_il_high_credit_limit                        NaN
# 108                             revol_bal_joint                        NaN
# 109                      sec_app_fico_range_low                        NaN
# 110                     sec_app_fico_range_high                        NaN
# 111                    sec_app_earliest_cr_line                        NaN
# 112                      sec_app_inq_last_6mths                        NaN
# 113                            sec_app_mort_acc                        NaN
# 114                            sec_app_open_acc                        NaN
# 115                          sec_app_revol_util                        NaN
# 116                         sec_app_open_act_il                        NaN
# 117                       sec_app_num_rev_accts                        NaN
# 118            sec_app_chargeoff_within_12_mths                        NaN
# 119          sec_app_collections_12_mths_ex_med                        NaN
# 120                               hardship_flag                        NaN
# 121                               hardship_type              hardship_type
# 122                             hardship_reason            hardship_reason
# 123                             hardship_status            hardship_status
# 124                               deferral_term                        NaN
# 125                             hardship_amount                        NaN
# 126                         hardship_start_date                        NaN
# 127                           hardship_end_date                        NaN
# 128                     payment_plan_start_date                        NaN
# 129                             hardship_length                        NaN
# 130                                hardship_dpd                        NaN
# 131                        hardship_loan_status       hardship_loan_status
# 132  orig_projected_additional_accrued_interest                        NaN
# 133              hardship_payoff_balance_amount                        NaN
# 134                hardship_last_payment_amount                        NaN
# 135                        debt_settlement_flag                        NaN
# 136                                         NaN             default_status
# 137                                         NaN                        NaN
# 138                                         NaN                        NaN
# 139                                         NaN                        NaN
# 140                                         NaN                        NaN
# 141                                         NaN                        NaN
# 142                                         NaN                        NaN
# 143                                         NaN                        NaN
# 144                                         NaN                        NaN
# 145                                         NaN                        NaN
# 146                                         NaN                        NaN
# 147                                         NaN                        NaN
# 148                                         NaN                        NaN
# 149                                         NaN                        NaN
# 150                                         NaN                        NaN
# 151                                         NaN                        NaN
# 152                                         NaN                        NaN
# 153                                         NaN                        NaN
# 154                                         NaN                        NaN
#
#                             lc_nf  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# 5                             NaN
# 6                             NaN
# 7                             NaN
# 8                             NaN
# 9                             NaN
# 10                 annual_inc_adj
# 11                            NaN
# 12                            NaN
# 13                            NaN
# 14                            NaN
# 15                            NaN
# 16                            NaN
# 17                        dti_adj
# 18                            NaN
# 19                            NaN
# 20                            NaN
# 21            fico_range_high_adj
# 22             inq_last_6mths_adj
# 23                            NaN
# 24                            NaN
# 25                   open_acc_adj
# 26                            NaN
# 27                  revol_bal_adj
# 28                 revol_util_adj
# 29                            NaN
# 30                            NaN
# 31                            NaN
# 32                            NaN
# 33                            NaN
# 34                            NaN
# 35                            NaN
# 36                            NaN
# 37                            NaN
# 38                            NaN
# 39                            NaN
# 40                            NaN
# 41                            NaN
# 42                            NaN
# 43                            NaN
# 44                            NaN
# 45                            NaN
# 46                            NaN
# 47                            NaN
# 48                            NaN
# 49                            NaN
# 50                            NaN
# 51                            NaN
# 52                            NaN
# 53                            NaN
# 54                            NaN
# 55                            NaN
# 56                            NaN
# 57                open_act_il_adj
# 58                            NaN
# 59                            NaN
# 60                            NaN
# 61                            NaN
# 62                            NaN
# 63                            NaN
# 64                            NaN
# 65                            NaN
# 66                            NaN
# 67                            NaN
# 68                            NaN
# 69                            NaN
# 70                            NaN
# 71                            NaN
# 72                            NaN
# 73                            NaN
# 74                            NaN
# 75   chargeoff_within_12_mths_adj
# 76                            NaN
# 77                            NaN
# 78                            NaN
# 79                            NaN
# 80                            NaN
# 81                   mort_acc_adj
# 82                            NaN
# 83                            NaN
# 84                            NaN
# 85                            NaN
# 86                            NaN
# 87                            NaN
# 88                            NaN
# 89                            NaN
# 90                            NaN
# 91                            NaN
# 92                            NaN
# 93              num_rev_accts_adj
# 94                            NaN
# 95                            NaN
# 96                            NaN
# 97                            NaN
# 98                            NaN
# 99                            NaN
# 100                           NaN
# 101                           NaN
# 102                           NaN
# 103                           NaN
# 104                           NaN
# 105                           NaN
# 106                           NaN
# 107                           NaN
# 108                           NaN
# 109                           NaN
# 110                           NaN
# 111                           NaN
# 112                           NaN
# 113                           NaN
# 114                           NaN
# 115                           NaN
# 116                           NaN
# 117                           NaN
# 118                           NaN
# 119                           NaN
# 120                           NaN
# 121                           NaN
# 122                           NaN
# 123                           NaN
# 124                           NaN
# 125                           NaN
# 126                           NaN
# 127                           NaN
# 128                           NaN
# 129                           NaN
# 130                           NaN
# 131                           NaN
# 132                           NaN
# 133                           NaN
# 134                           NaN
# 135                           NaN
# 136                           NaN
# 137                       issue_y
# 138     mo_since_earliest_cr_line
# 139                           NaN
# 140                           NaN
# 141                           NaN
# 142                           NaN
# 143                           NaN
# 144                           NaN
# 145                           NaN
# 146                           NaN
# 147                           NaN
# 148                           NaN
# 149                           NaN
# 150                           NaN
# 151                           NaN
# 152                           NaN
# 153                           NaN
# 154                           NaN
#
#                                                                                                                                                                                                                                    Description
# 0                                                                 The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value.
# 1                                                                                                                                                                               The total amount committed to that loan at that point in time.
# 2                                                                                                                                                                 The total amount committed by investors for that loan at that point in time.
# 3                                                                                                                                                         The number of payments on the loan. Values are in months and can be either 36 or 60.
# 4                                                                                                                                                                                                                    Interest Rate on the loan
# 5                                                                                                                                                                             The monthly payment owed by the borrower if the loan originates.
# 6                                                                                                                                                                                                                       LC assigned loan grade
# 7                                                                                                                                                                                                                    LC assigned loan subgrade
# 8                                                                                                           Employment length in years. Possible values are between 0 and 10 where 0 means less than one year and 10 means ten or more years.
# 9                                                                                        The home ownership status provided by the borrower during registration or obtained from the credit report. Our values are: RENT, OWN, MORTGAGE, OTHER
# 10                                                                                                                                                               The self-reported annual income provided by the borrower during registration.
# 11                                                                                                                                                  Indicates if income was verified by LC, not verified, or if the income source was verified
# 12                                                                                                                                                                                                         The month which the loan was funded
# 13                                                                                                                                                                                                                  Current status of the loan
# 14                                                                                                                                                                              Indicates if a payment plan has been put in place for the loan
# 15                                                                                                                                                                                  A category provided by the borrower for the loan request.
# 16                                                                                                                                                                                  The state provided by the borrower in the loan application
# 17                                    A ratio calculated using the borrower’s total monthly debt payments on the total debt obligations, excluding mortgage and the requested LC loan, divided by the borrower’s self-reported monthly income.
# 18                                                                                                                                The number of 30+ days past-due incidences of delinquency in the borrower's credit file for the past 2 years
# 19                                                                                                                                                                           The month the borrower's earliest reported credit line was opened
# 20                                                                                                                                                                The lower boundary range the borrower’s FICO at loan origination belongs to.
# 21                                                                                                                                                                The upper boundary range the borrower’s FICO at loan origination belongs to.
# 22                                                                                                                                                            The number of inquiries in past 6 months (excluding auto and mortgage inquiries)
# 23                                                                                                                                                                                 The number of months since the borrower's last delinquency.
# 24                                                                                                                                                                                          The number of months since the last public record.
# 25                                                                                                                                                                              The number of open credit lines in the borrower's credit file.
# 26                                                                                                                                                                                                         Number of derogatory public records
# 27                                                                                                                                                                                                              Total credit revolving balance
# 28                                                                                                                  Revolving line utilization rate, or the amount of credit the borrower is using relative to all available revolving credit.
# 29                                                                                                                                                                    The total number of credit lines currently in the borrower's credit file
# 30                                                                                                                                                                          The initial listing status of the loan. Possible values are – W, F
# 31                                                                                                                                                                                     Remaining outstanding principal for total amount funded
# 32                                                                                                                                                             Remaining outstanding principal for portion of total amount funded by investors
# 33                                                                                                                                                                                           Payments received to date for total amount funded
# 34                                                                                                                                                                   Payments received to date for portion of total amount funded by investors
# 35                                                                                                                                                                                                                  Principal received to date
# 36                                                                                                                                                                                                                   Interest received to date
# 37                                                                                                                                                                                                                  Late fees received to date
# 38                                                                                                                                                                                                              post charge off gross recovery
# 39                                                                                                                                                                                                              post charge off collection fee
# 40                                                                                                                                                                                                             Last month payment was received
# 41                                                                                                                                                                                                          Last total payment amount received
# 42                                                                                                                                                                                                                 Next scheduled payment date
# 43                                                                                                                                                                                        The most recent month LC pulled credit for this loan
# 44                                                                                                                                                                        The upper boundary range the borrower’s last FICO pulled belongs to.
# 45                                                                                                                                                                        The lower boundary range the borrower’s last FICO pulled belongs to.
# 46                                                                                                                                                                            Number of collections in 12 months excluding medical collections
# 47                                                                                                                                                                                             Months since most recent 90-day or worse rating
# 48                                                                                                                                                         publicly available policy_code=1\nnew products not publicly available policy_code=2
# 49                                                                                                                                        Indicates whether the loan is an individual application or a joint application with two co-borrowers
# 50                                                                                                                                                   The combined self-reported annual income provided by the co-borrowers during registration
# 51                          A ratio calculated using the co-borrowers' total monthly payments on the total debt obligations, excluding mortgages and the requested LC loan, divided by the co-borrowers' combined self-reported monthly income
# 52                                                                                                                                                                                                                                         NaN
# 53                                                                                                                                                                             The number of accounts on which the borrower is now delinquent.
# 54                                                                                                                                                                                                          Total collection amounts ever owed
# 55                                                                                                                                                                                                       Total current balance of all accounts
# 56                                                                                                                                                                                                      Number of open trades in last 6 months
# 57                                                                                                                                                                                               Number of currently active installment trades
# 58                                                                                                                                                                                     Number of installment accounts opened in past 12 months
# 59                                                                                                                                                                                     Number of installment accounts opened in past 24 months
# 60                                                                                                                                                                                        Months since most recent installment accounts opened
# 61                                                                                                                                                                                           Total current balance of all installment accounts
# 62                                                                                                                                                              Ratio of total current balance to high credit/credit limit on all install acct
# 63                                                                                                                                                                                         Number of revolving trades opened in past 12 months
# 64                                                                                                                                                                                         Number of revolving trades opened in past 24 months
# 65                                                                                                                                                                                      Maximum current balance owed on all revolving accounts
# 66                                                                                                                                                                                                       Balance to credit limit on all trades
# 67                                                                                                                                                                                                    Total revolving high credit/credit limit
# 68                                                                                                                                                                                                        Number of personal finance inquiries
# 69                                                                                                                                                                                                                    Number of finance trades
# 70                                                                                                                                                                                                Number of credit inquiries in past 12 months
# 71                                                                                                                                                                                                  Number of trades opened in past 24 months.
# 72                                                                                                                                                                                                     Average current balance of all accounts
# 73                                                                                                                                                                                                   Total open to buy on revolving bankcards.
# 74                                                                                                                                                       Ratio of total current balance to high credit/credit limit for all bankcard accounts.
# 75                                                                                                                                                                                                      Number of charge-offs within 12 months
# 76                                                                                                                                                          The past-due amount owed for the accounts on which the borrower is now delinquent.
# 77                                                                                                                                                                                         Months since oldest bank installment account opened
# 78                                                                                                                                                                                                Months since oldest revolving account opened
# 79                                                                                                                                                                                           Months since most recent revolving account opened
# 80                                                                                                                                                                                                     Months since most recent account opened
# 81                                                                                                                                                                                                                Number of mortgage accounts.
# 82                                                                                                                                                                                           Months since most recent bankcard account opened.
# 83                                                                                                                                                                                               Months since most recent bankcard delinquency
# 84                                                                                                                                                                                                           Months since most recent inquiry.
# 85                                                                                                                                                                                             Months since most recent revolving delinquency.
# 86                                                                                                                                                                                           Number of accounts ever 120 or more days past due
# 87                                                                                                                                                                                                Number of currently active bankcard accounts
# 88                                                                                                                                                                                                 Number of currently active revolving trades
# 89                                                                                                                                                                                                    Number of satisfactory bankcard accounts
# 90                                                                                                                                                                                                                 Number of bankcard accounts
# 91                                                                                                                                                                                                              Number of installment accounts
# 92                                                                                                                                                                                                           Number of open revolving accounts
# 93                                                                                                                                                                                                                Number of revolving accounts
# 94                                                                                                                                                                                                  Number of revolving trades with balance >0
# 95                                                                                                                                                                                                             Number of satisfactory accounts
# 96                                                                                                                                                                   Number of accounts currently 120 days past due (updated in past 2 months)
# 97                                                                                                                                                                    Number of accounts currently 30 days past due (updated in past 2 months)
# 98                                                                                                                                                                               Number of accounts 90 or more days past due in last 24 months
# 99                                                                                                                                                                                                 Number of accounts opened in past 12 months
# 100                                                                                                                                                                                                         Percent of trades never delinquent
# 101                                                                                                                                                                                        Percentage of all bankcard accounts > 75% of limit.
# 102                                                                                                                                                                                                       Number of public record bankruptcies
# 103                                                                                                                                                                                                                        Number of tax liens
# 104                                                                                                                                                                                                             Total high credit/credit limit
# 105                                                                                                                                                                                                    Total credit balance excluding mortgage
# 106                                                                                                                                                                                                    Total bankcard high credit/credit limit
# 107                                                                                                                                                                                                 Total installment high credit/credit limit
# 108                                                                                                                                                             Sum of revolving credit balance of the co-borrowers, net of duplicate balances
# 109                                                                                                                                                                                              FICO range (high) for the secondary applicant
# 110                                                                                                                                                                                               FICO range (low) for the secondary applicant
# 111                                                                                                                                                                    Earliest credit line at time of application for the secondary applicant
# 112                                                                                                                                                   Credit inquiries in the last 6 months at time of application for the secondary applicant
# 113                                                                                                                                                             Number of mortgage accounts at time of application for the secondary applicant
# 114                                                                                                                                                                   Number of open trades at time of application for the secondary applicant
# 115                                                                                                                                                      Ratio of total current balance to high credit/credit limit for all revolving accounts
# 116                                                                                                                                           Number of currently active installment trades at time of application for the secondary applicant
# 117                                                                                                                                                            Number of revolving accounts at time of application for the secondary applicant
# 118                                                                                                                                             Number of charge-offs within last 12 months at time of application for the secondary applicant
# 119                                                                                                               Number of collections within last 12 months excluding medical collections at time of application for the secondary applicant
# 120                                                                                                                                                                                    Flags whether or not the borrower is on a hardship plan
# 121                                                                                                                                                                                                       Describes the hardship plan offering
# 122                                                                                                                                                                                         Describes the reason the hardship plan was offered
# 123                                                                                                                                                          Describes if the hardship plan is active, pending, canceled, completed, or broken
# 124                                                                                                              Amount of months that the borrower is expected to pay less than the contractual monthly payment amount due to a hardship plan
# 125                                                                                                                                  The interest payment that the borrower has committed to make each month while they are on a hardship plan
# 126                                                                                                                                                                                                 The start date of the hardship plan period
# 127                                                                                                                                                                                                   The end date of the hardship plan period
# 128  The day the first hardship plan payment is due. For example, if a borrower has a hardship plan period of 3 months, the start date is the start of the three-month period in which the borrower is allowed to make interest-only payments.
# 129                                                                                                                                The number of months the borrower will make smaller payments than normally obligated due to a hardship plan
# 130                                                                                                                                                                                   Account days past due as of the hardship plan start date
# 131                                                                                                                                                                                             Loan Status as of the hardship plan start date
# 132                      The original projected additional interest amount that will accrue for the given hardship payment plan as of the Hardship Start Date. This field will be null if the borrower has broken their hardship payment plan.
# 133                                                                                                                                                                               The payoff balance amount as of the hardship plan start date
# 134                                                                                                                                                                                 The last payment amount as of the hardship plan start date
# 135                                                                                                                                         Flags whether or not the borrower, who has charged-off, is working with a debt-settlement company.
# 136                                                                                                                                                                                                                                        NaN
# 137                                                                                                                                                                                                                                        NaN
# 138                                                                                                                                                                                                                                        NaN
# 139                                                                                                                                                                          The most recent date that the Debt_Settlement_Flag has been set
# 140                                                                                                                                                                                                  Loan description provided by the borrower
# 141                                                                                                                                                The method by which the borrower receives their loan. Possible values are: CASH, DIRECT_PAY
# 142                                                                                                                                                                        The job title supplied by the Borrower when applying for the loan.*
# 143                                                                                                                                                                                              A unique LC assigned ID for the loan listing.
# 144                                                                                                                                                                                           A unique LC assigned Id for the borrower member.
# 145                                                                                                                                         Months since most recent 90-day or worse rating at time of application for the secondary applicant
# 146                                                                                                                                                                                 The loan amount that the borrower has agreed to settle for
# 147                                                                                                                                                                                   The date that the borrower agrees to the settlement plan
# 148                                                                                                                                                             The settlement amount as a percentage of the payoff balance amount on the loan
# 149                                                                                                                      The status of the borrower’s settlement plan. Possible values are: COMPLETE, ACTIVE, BROKEN, CANCELLED, DENIED, DRAFT
# 150                                                                                                                                                                      The number of months that the borrower will be on the settlement plan
# 151                                                                                                                                                                                                    The loan title provided by the borrower
# 152                                                                                                                                                                                                     URL for the LC page with listing data.
# 153                                                                                                                         Indicates if the co-borrowers' joint income was verified by LC, not verified, or if the income source was verified
# 154                                                                                                                                                      The first 3 numbers of the zip code provided by the borrower in the loan application.

# %%
# The following indices seems to represent features that might be available at
# loan application time: [0:11], [15:18], [20:29], [46:47], [49:108], [109:119] (the last I will skip as it is replaced by adjusted features)
# Target (default_status): [136]

analysis_frame = pd.concat([descr.loc[0:11], descr.loc[15:18], descr.loc[20:29], descr.loc[46:47],
                            descr.loc[49:108], descr.loc[136:136]], axis=0)
print('No. of features: ', analysis_frame.shape[0])
analysis_frame
# Out:
# No. of features:  89
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                               index                              lc  \
# 0                         loan_amnt                       loan_amnt
# 1                       funded_amnt                     funded_amnt
# 2                   funded_amnt_inv                 funded_amnt_inv
# 3                              term                            term
# 4                          int_rate                        int_rate
# 5                       installment                     installment
# 6                             grade                           grade
# 7                         sub_grade                       sub_grade
# 8                        emp_length                      emp_length
# 9                    home_ownership                  home_ownership
# 10                       annual_inc                      annual_inc
# 11              verification_status             verification_status
# 15                          purpose                         purpose
# 16                       addr_state                      addr_state
# 17                              dti                             dti
# 18                      delinq_2yrs                     delinq_2yrs
# 20                   fico_range_low                  fico_range_low
# 21                  fico_range_high                 fico_range_high
# 22                   inq_last_6mths                  inq_last_6mths
# 23           mths_since_last_delinq          mths_since_last_delinq
# 24           mths_since_last_record          mths_since_last_record
# 25                         open_acc                        open_acc
# 26                          pub_rec                         pub_rec
# 27                        revol_bal                       revol_bal
# 28                       revol_util                      revol_util
# 29                        total_acc                       total_acc
# 46       collections_12_mths_ex_med      collections_12_mths_ex_med
# 47      mths_since_last_major_derog     mths_since_last_major_derog
# 49                 application_type                application_type
# 50                 annual_inc_joint                annual_inc_joint
# 51                        dti_joint                       dti_joint
# 52        verification_status_joint       verification_status_joint
# 53                   acc_now_delinq                  acc_now_delinq
# 54                     tot_coll_amt                    tot_coll_amt
# 55                      tot_cur_bal                     tot_cur_bal
# 56                      open_acc_6m                     open_acc_6m
# 57                      open_act_il                     open_act_il
# 58                      open_il_12m                     open_il_12m
# 59                      open_il_24m                     open_il_24m
# 60               mths_since_rcnt_il              mths_since_rcnt_il
# 61                     total_bal_il                    total_bal_il
# 62                          il_util                         il_util
# 63                      open_rv_12m                     open_rv_12m
# 64                      open_rv_24m                     open_rv_24m
# 65                       max_bal_bc                      max_bal_bc
# 66                         all_util                        all_util
# 67                 total_rev_hi_lim                total_rev_hi_lim
# 68                           inq_fi                          inq_fi
# 69                      total_cu_tl                     total_cu_tl
# 70                     inq_last_12m                    inq_last_12m
# 71             acc_open_past_24mths            acc_open_past_24mths
# 72                      avg_cur_bal                     avg_cur_bal
# 73                   bc_open_to_buy                  bc_open_to_buy
# 74                          bc_util                         bc_util
# 75         chargeoff_within_12_mths        chargeoff_within_12_mths
# 76                      delinq_amnt                     delinq_amnt
# 77               mo_sin_old_il_acct              mo_sin_old_il_acct
# 78             mo_sin_old_rev_tl_op            mo_sin_old_rev_tl_op
# 79            mo_sin_rcnt_rev_tl_op           mo_sin_rcnt_rev_tl_op
# 80                   mo_sin_rcnt_tl                  mo_sin_rcnt_tl
# 81                         mort_acc                        mort_acc
# 82             mths_since_recent_bc            mths_since_recent_bc
# 83         mths_since_recent_bc_dlq        mths_since_recent_bc_dlq
# 84            mths_since_recent_inq           mths_since_recent_inq
# 85   mths_since_recent_revol_delinq  mths_since_recent_revol_delinq
# 86            num_accts_ever_120_pd           num_accts_ever_120_pd
# 87                   num_actv_bc_tl                  num_actv_bc_tl
# 88                  num_actv_rev_tl                 num_actv_rev_tl
# 89                      num_bc_sats                     num_bc_sats
# 90                        num_bc_tl                       num_bc_tl
# 91                        num_il_tl                       num_il_tl
# 92                    num_op_rev_tl                   num_op_rev_tl
# 93                    num_rev_accts                   num_rev_accts
# 94              num_rev_tl_bal_gt_0             num_rev_tl_bal_gt_0
# 95                         num_sats                        num_sats
# 96                 num_tl_120dpd_2m                num_tl_120dpd_2m
# 97                     num_tl_30dpd                    num_tl_30dpd
# 98               num_tl_90g_dpd_24m              num_tl_90g_dpd_24m
# 99               num_tl_op_past_12m              num_tl_op_past_12m
# 100                  pct_tl_nvr_dlq                  pct_tl_nvr_dlq
# 101                percent_bc_gt_75                percent_bc_gt_75
# 102            pub_rec_bankruptcies            pub_rec_bankruptcies
# 103                       tax_liens                       tax_liens
# 104                 tot_hi_cred_lim                 tot_hi_cred_lim
# 105               total_bal_ex_mort               total_bal_ex_mort
# 106                  total_bc_limit                  total_bc_limit
# 107      total_il_high_credit_limit      total_il_high_credit_limit
# 108                 revol_bal_joint                 revol_bal_joint
# 136                  default_status                             NaN
#
#                         lc_enc                         lc_nf  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
# 5                          NaN                           NaN
# 6                        grade                           NaN
# 7                    sub_grade                           NaN
# 8                   emp_length                           NaN
# 9               home_ownership                           NaN
# 10                         NaN                annual_inc_adj
# 11         verification_status                           NaN
# 15                     purpose                           NaN
# 16                  addr_state                           NaN
# 17                         NaN                       dti_adj
# 18                         NaN                           NaN
# 20                         NaN                           NaN
# 21                         NaN           fico_range_high_adj
# 22                         NaN            inq_last_6mths_adj
# 23                         NaN                           NaN
# 24                         NaN                           NaN
# 25                         NaN                  open_acc_adj
# 26                         NaN                           NaN
# 27                         NaN                 revol_bal_adj
# 28                         NaN                revol_util_adj
# 29                         NaN                           NaN
# 46                         NaN                           NaN
# 47                         NaN                           NaN
# 49            application_type                           NaN
# 50                         NaN                           NaN
# 51                         NaN                           NaN
# 52   verification_status_joint                           NaN
# 53                         NaN                           NaN
# 54                         NaN                           NaN
# 55                         NaN                           NaN
# 56                         NaN                           NaN
# 57                         NaN               open_act_il_adj
# 58                         NaN                           NaN
# 59                         NaN                           NaN
# 60                         NaN                           NaN
# 61                         NaN                           NaN
# 62                         NaN                           NaN
# 63                         NaN                           NaN
# 64                         NaN                           NaN
# 65                         NaN                           NaN
# 66                         NaN                           NaN
# 67                         NaN                           NaN
# 68                         NaN                           NaN
# 69                         NaN                           NaN
# 70                         NaN                           NaN
# 71                         NaN                           NaN
# 72                         NaN                           NaN
# 73                         NaN                           NaN
# 74                         NaN                           NaN
# 75                         NaN  chargeoff_within_12_mths_adj
# 76                         NaN                           NaN
# 77                         NaN                           NaN
# 78                         NaN                           NaN
# 79                         NaN                           NaN
# 80                         NaN                           NaN
# 81                         NaN                  mort_acc_adj
# 82                         NaN                           NaN
# 83                         NaN                           NaN
# 84                         NaN                           NaN
# 85                         NaN                           NaN
# 86                         NaN                           NaN
# 87                         NaN                           NaN
# 88                         NaN                           NaN
# 89                         NaN                           NaN
# 90                         NaN                           NaN
# 91                         NaN                           NaN
# 92                         NaN                           NaN
# 93                         NaN             num_rev_accts_adj
# 94                         NaN                           NaN
# 95                         NaN                           NaN
# 96                         NaN                           NaN
# 97                         NaN                           NaN
# 98                         NaN                           NaN
# 99                         NaN                           NaN
# 100                        NaN                           NaN
# 101                        NaN                           NaN
# 102                        NaN                           NaN
# 103                        NaN                           NaN
# 104                        NaN                           NaN
# 105                        NaN                           NaN
# 106                        NaN                           NaN
# 107                        NaN                           NaN
# 108                        NaN                           NaN
# 136             default_status                           NaN
#
#                                                                                                                                                                                                             Description
# 0                                          The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value.
# 1                                                                                                                                                        The total amount committed to that loan at that point in time.
# 2                                                                                                                                          The total amount committed by investors for that loan at that point in time.
# 3                                                                                                                                  The number of payments on the loan. Values are in months and can be either 36 or 60.
# 4                                                                                                                                                                                             Interest Rate on the loan
# 5                                                                                                                                                      The monthly payment owed by the borrower if the loan originates.
# 6                                                                                                                                                                                                LC assigned loan grade
# 7                                                                                                                                                                                             LC assigned loan subgrade
# 8                                                                                    Employment length in years. Possible values are between 0 and 10 where 0 means less than one year and 10 means ten or more years.
# 9                                                                 The home ownership status provided by the borrower during registration or obtained from the credit report. Our values are: RENT, OWN, MORTGAGE, OTHER
# 10                                                                                                                                        The self-reported annual income provided by the borrower during registration.
# 11                                                                                                                           Indicates if income was verified by LC, not verified, or if the income source was verified
# 15                                                                                                                                                           A category provided by the borrower for the loan request.
# 16                                                                                                                                                           The state provided by the borrower in the loan application
# 17             A ratio calculated using the borrower’s total monthly debt payments on the total debt obligations, excluding mortgage and the requested LC loan, divided by the borrower’s self-reported monthly income.
# 18                                                                                                         The number of 30+ days past-due incidences of delinquency in the borrower's credit file for the past 2 years
# 20                                                                                                                                         The lower boundary range the borrower’s FICO at loan origination belongs to.
# 21                                                                                                                                         The upper boundary range the borrower’s FICO at loan origination belongs to.
# 22                                                                                                                                     The number of inquiries in past 6 months (excluding auto and mortgage inquiries)
# 23                                                                                                                                                          The number of months since the borrower's last delinquency.
# 24                                                                                                                                                                   The number of months since the last public record.
# 25                                                                                                                                                       The number of open credit lines in the borrower's credit file.
# 26                                                                                                                                                                                  Number of derogatory public records
# 27                                                                                                                                                                                       Total credit revolving balance
# 28                                                                                           Revolving line utilization rate, or the amount of credit the borrower is using relative to all available revolving credit.
# 29                                                                                                                                             The total number of credit lines currently in the borrower's credit file
# 46                                                                                                                                                     Number of collections in 12 months excluding medical collections
# 47                                                                                                                                                                      Months since most recent 90-day or worse rating
# 49                                                                                                                 Indicates whether the loan is an individual application or a joint application with two co-borrowers
# 50                                                                                                                            The combined self-reported annual income provided by the co-borrowers during registration
# 51   A ratio calculated using the co-borrowers' total monthly payments on the total debt obligations, excluding mortgages and the requested LC loan, divided by the co-borrowers' combined self-reported monthly income
# 52                                                                                                                                                                                                                  NaN
# 53                                                                                                                                                      The number of accounts on which the borrower is now delinquent.
# 54                                                                                                                                                                                   Total collection amounts ever owed
# 55                                                                                                                                                                                Total current balance of all accounts
# 56                                                                                                                                                                               Number of open trades in last 6 months
# 57                                                                                                                                                                        Number of currently active installment trades
# 58                                                                                                                                                              Number of installment accounts opened in past 12 months
# 59                                                                                                                                                              Number of installment accounts opened in past 24 months
# 60                                                                                                                                                                 Months since most recent installment accounts opened
# 61                                                                                                                                                                    Total current balance of all installment accounts
# 62                                                                                                                                       Ratio of total current balance to high credit/credit limit on all install acct
# 63                                                                                                                                                                  Number of revolving trades opened in past 12 months
# 64                                                                                                                                                                  Number of revolving trades opened in past 24 months
# 65                                                                                                                                                               Maximum current balance owed on all revolving accounts
# 66                                                                                                                                                                                Balance to credit limit on all trades
# 67                                                                                                                                                                             Total revolving high credit/credit limit
# 68                                                                                                                                                                                 Number of personal finance inquiries
# 69                                                                                                                                                                                             Number of finance trades
# 70                                                                                                                                                                         Number of credit inquiries in past 12 months
# 71                                                                                                                                                                           Number of trades opened in past 24 months.
# 72                                                                                                                                                                              Average current balance of all accounts
# 73                                                                                                                                                                            Total open to buy on revolving bankcards.
# 74                                                                                                                                Ratio of total current balance to high credit/credit limit for all bankcard accounts.
# 75                                                                                                                                                                               Number of charge-offs within 12 months
# 76                                                                                                                                   The past-due amount owed for the accounts on which the borrower is now delinquent.
# 77                                                                                                                                                                  Months since oldest bank installment account opened
# 78                                                                                                                                                                         Months since oldest revolving account opened
# 79                                                                                                                                                                    Months since most recent revolving account opened
# 80                                                                                                                                                                              Months since most recent account opened
# 81                                                                                                                                                                                         Number of mortgage accounts.
# 82                                                                                                                                                                    Months since most recent bankcard account opened.
# 83                                                                                                                                                                        Months since most recent bankcard delinquency
# 84                                                                                                                                                                                    Months since most recent inquiry.
# 85                                                                                                                                                                      Months since most recent revolving delinquency.
# 86                                                                                                                                                                    Number of accounts ever 120 or more days past due
# 87                                                                                                                                                                         Number of currently active bankcard accounts
# 88                                                                                                                                                                          Number of currently active revolving trades
# 89                                                                                                                                                                             Number of satisfactory bankcard accounts
# 90                                                                                                                                                                                          Number of bankcard accounts
# 91                                                                                                                                                                                       Number of installment accounts
# 92                                                                                                                                                                                    Number of open revolving accounts
# 93                                                                                                                                                                                         Number of revolving accounts
# 94                                                                                                                                                                           Number of revolving trades with balance >0
# 95                                                                                                                                                                                      Number of satisfactory accounts
# 96                                                                                                                                            Number of accounts currently 120 days past due (updated in past 2 months)
# 97                                                                                                                                             Number of accounts currently 30 days past due (updated in past 2 months)
# 98                                                                                                                                                        Number of accounts 90 or more days past due in last 24 months
# 99                                                                                                                                                                          Number of accounts opened in past 12 months
# 100                                                                                                                                                                                  Percent of trades never delinquent
# 101                                                                                                                                                                 Percentage of all bankcard accounts > 75% of limit.
# 102                                                                                                                                                                                Number of public record bankruptcies
# 103                                                                                                                                                                                                 Number of tax liens
# 104                                                                                                                                                                                      Total high credit/credit limit
# 105                                                                                                                                                                             Total credit balance excluding mortgage
# 106                                                                                                                                                                             Total bankcard high credit/credit limit
# 107                                                                                                                                                                          Total installment high credit/credit limit
# 108                                                                                                                                      Sum of revolving credit balance of the co-borrowers, net of duplicate balances
# 136                                                                                                                                                                                                                 NaN

# %%
# Drop '..._joint" features as it was replaced by adjusted features
analysis_frame = analysis_frame[~analysis_frame['index'].str.endswith("joint")]
print('No. of features: ', analysis_frame.shape[0])
# Out:
# No. of features:  85

# %%
# Dictionary for mapping features for analysis to datasets where they located
# Could be used later for construction parameters...yml for pipeline
analisys_features = {
    'encoded':  analysis_frame['lc_enc'].dropna().to_list(),
    'clean':    analysis_frame[(analysis_frame['lc_enc'].isna()) & (analysis_frame['lc_nf'].isna())].lc.to_list(),
    'new_feat': analysis_frame['lc_nf'].dropna().to_list(),
}
analisys_features
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# {
#     'encoded': [
#         'grade',
#         'sub_grade',
#         'emp_length',
#         'home_ownership',
#         'verification_status',
#         'purpose',
#         'addr_state',
#         'application_type',
#         'default_status'
#     ],
#     'clean': [
#         'loan_amnt',
#         'funded_amnt',
#         'funded_amnt_inv',
#         'term',
#         'int_rate',
#         'installment',
#         'delinq_2yrs',
#         'fico_range_low',
#         'mths_since_last_delinq',
#         'mths_since_last_record',
#         'pub_rec',
#         'total_acc',
#         'collections_12_mths_ex_med',
#         'mths_since_last_major_derog',
#         'acc_now_delinq',
#         'tot_coll_amt',
#         'tot_cur_bal',
#         'open_acc_6m',
#         'open_il_12m',
#         'open_il_24m',
#         'mths_since_rcnt_il',
#         'total_bal_il',
#         'il_util',
#         'open_rv_12m',
#         'open_rv_24m',
#         'max_bal_bc',
#         'all_util',
#         'total_rev_hi_lim',
#         'inq_fi',
#         'total_cu_tl',
#         'inq_last_12m',
#         'acc_open_past_24mths',
#         'avg_cur_bal',
#         'bc_open_to_buy',
#         'bc_util',
#         'delinq_amnt',
#         'mo_sin_old_il_acct',
#         'mo_sin_old_rev_tl_op',
#         'mo_sin_rcnt_rev_tl_op',
#         'mo_sin_rcnt_tl',
#         'mths_since_recent_bc',
#         'mths_since_recent_bc_dlq',
#         'mths_since_recent_inq',
#         'mths_since_recent_revol_delinq',
#         'num_accts_ever_120_pd',
#         'num_actv_bc_tl',
#         'num_actv_rev_tl',
#         'num_bc_sats',
#         'num_bc_tl',
#         'num_il_tl',
#         'num_op_rev_tl',
#         'num_rev_tl_bal_gt_0',
#         'num_sats',
#         'num_tl_120dpd_2m',
#         'num_tl_30dpd',
#         'num_tl_90g_dpd_24m',
#         'num_tl_op_past_12m',
#         'pct_tl_nvr_dlq',
#         'percent_bc_gt_75',
#         'pub_rec_bankruptcies',
#         'tax_liens',
#         'tot_hi_cred_lim',
#         'total_bal_ex_mort',
#         'total_bc_limit',
#         'total_il_high_credit_limit'
#     ],
#     'new_feat': [
#         'annual_inc_adj',
#         'dti_adj',
#         'fico_range_high_adj',
#         'inq_last_6mths_adj',
#         'open_acc_adj',
#         'revol_bal_adj',
#         'revol_util_adj',
#         'open_act_il_adj',
#         'chargeoff_within_12_mths_adj',
#         'mort_acc_adj',
#         'num_rev_accts_adj'
#     ]
# }

# %%
# Function for merging features for analisys from clean and encoded datasets
def eda_df (df_clean: pd.DataFrame, df_encode: pd.DataFrame, df_nf: pd.DataFrame, params: dict) -> pd.DataFrame:
    return pd.concat([df_clean[params['clean']], df_encode[params['encoded']], df_nf[params['new_feat']]], axis=1)

# Print analysis_features in parameters...yml format to use in pipeline
for key in analisys_features.keys():
    print(key, ":")
    for feat in analisys_features[key]:
        print(f"  - {feat}")
# Out:
# encoded :
#   - grade
#   - sub_grade
#   - emp_length
#   - home_ownership
#   - verification_status
#   - purpose
#   - addr_state
#   - application_type
#   - default_status
# clean :
#   - loan_amnt
#   - funded_amnt
#   - funded_amnt_inv
#   - term
#   - int_rate
#   - installment
#   - delinq_2yrs
#   - fico_range_low
#   - mths_since_last_delinq
#   - mths_since_last_record
#   - pub_rec
#   - total_acc
#   - collections_12_mths_ex_med
#   - mths_since_last_major_derog
#   - acc_now_delinq
#   - tot_coll_amt
#   - tot_cur_bal
#   - open_acc_6m
#   - open_il_12m
#   - open_il_24m
#   - mths_since_rcnt_il
#   - total_bal_il
#   - il_util
#   - open_rv_12m
#   - open_rv_24m
#   - max_bal_bc
#   - all_util
#   - total_rev_hi_lim
#   - inq_fi
#   - total_cu_tl
#   - inq_last_12m
#   - acc_open_past_24mths
#   - avg_cur_bal
#   - bc_open_to_buy
#   - bc_util
#   - delinq_amnt
#   - mo_sin_old_il_acct
#   - mo_sin_old_rev_tl_op
#   - mo_sin_rcnt_rev_tl_op
#   - mo_sin_rcnt_tl
#   - mths_since_recent_bc
#   - mths_since_recent_bc_dlq
#   - mths_since_recent_inq
#   - mths_since_recent_revol_delinq
#   - num_accts_ever_120_pd
#   - num_actv_bc_tl
#   - num_actv_rev_tl
#   - num_bc_sats
#   - num_bc_tl
#   - num_il_tl
#   - num_op_rev_tl
#   - num_rev_tl_bal_gt_0
#   - num_sats
#   - num_tl_120dpd_2m
#   - num_tl_30dpd
#   - num_tl_90g_dpd_24m
#   - num_tl_op_past_12m
#   - pct_tl_nvr_dlq
#   - percent_bc_gt_75
#   - pub_rec_bankruptcies
#   - tax_liens
#   - tot_hi_cred_lim
#   - total_bal_ex_mort
#   - total_bc_limit
#   - total_il_high_credit_limit
# new_feat :
#   - annual_inc_adj
#   - dti_adj
#   - fico_range_high_adj
#   - inq_last_6mths_adj
#   - open_acc_adj
#   - revol_bal_adj
#   - revol_util_adj
#   - open_act_il_adj
#   - chargeoff_within_12_mths_adj
#   - mort_acc_adj
#   - num_rev_accts_adj

# %% [markdown]
# ### Testing function

# %%
eda_df(lending_club, lending_club_enc, lending_club_nf, analisys_features).head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#            loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  \
# id
# 167338079     4000.0       4000.0           4000.0    36     13.08
# 71016917     24000.0      24000.0          24000.0    60      9.16
# 39589826      5000.0       5000.0           5000.0    36     10.49
# 134798709    24000.0      24000.0          24000.0    60     11.05
# 127097355    14000.0      14000.0          14000.0    60     13.59
#
#            installment  delinq_2yrs  fico_range_low  mths_since_last_delinq  \
# id
# 167338079       134.93          1.0           665.0                    19.0
# 71016917        500.07          0.0           680.0                     0.0
# 39589826        162.49          0.0           665.0                     0.0
# 134798709       522.42          0.0           750.0                     0.0
# 127097355       322.79          0.0           735.0                     0.0
#
#            mths_since_last_record  pub_rec  total_acc  \
# id
# 167338079                   110.0      1.0       12.0
# 71016917                      0.0      0.0       24.0
# 39589826                     61.0      1.0        9.0
# 134798709                     0.0      0.0       23.0
# 127097355                     0.0      0.0       23.0
#
#            collections_12_mths_ex_med  mths_since_last_major_derog  \
# id
# 167338079                         1.0                          0.0
# 71016917                          0.0                          0.0
# 39589826                          0.0                          0.0
# 134798709                         0.0                          0.0
# 127097355                         0.0                          0.0
#
#            acc_now_delinq  tot_coll_amt  tot_cur_bal  open_acc_6m  \
# id
# 167338079             0.0        3832.0     259024.0          0.0
# 71016917              0.0           0.0      61815.0          0.0
# 39589826              0.0           0.0     159131.0          1.0
# 134798709             0.0           0.0     104590.0          2.0
# 127097355             0.0           0.0      90253.0          2.0
#
#            open_il_12m  open_il_24m  mths_since_rcnt_il  total_bal_il  \
# id
# 167338079          0.0          1.0                16.0        9960.0
# 71016917           0.0          3.0                14.0       39118.0
# 39589826           0.0          1.0                 0.0       24095.5
# 134798709          0.0          1.0                17.0       11947.0
# 127097355          1.0          1.0                 7.0       22953.0
#
#            il_util  open_rv_12m  open_rv_24m  max_bal_bc  all_util  \
# id
# 167338079     56.0          0.0          0.0         0.0      59.0
# 71016917      72.0          1.0          1.0      2137.0      67.0
# 39589826      72.0          1.0          2.0      4569.0      57.0
# 134798709     60.0          2.0          3.0      2223.0      25.0
# 127097355     60.0          3.0          4.0      3907.0      43.0
#
#            total_rev_hi_lim  inq_fi  total_cu_tl  inq_last_12m  \
# id
# 167338079            2400.0     1.0          0.0           0.0
# 71016917            35200.0     0.0          7.0           0.0
# 39589826            11400.0     1.0          0.0           1.0
# 134798709           54500.0     2.0          0.0           2.0
# 127097355           43900.0     1.0          0.0           2.0
#
#            acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  bc_util  \
# id
# 167338079                   1.0      64756.0          6262.5     57.3
# 71016917                    4.0       6182.0          7741.0     40.5
# 39589826                    4.0      22733.0          4521.0     54.8
# 134798709                   4.0       6973.0         43140.0     12.0
# 127097355                   5.0       5641.0         17318.0     39.9
#
#            delinq_amnt  mo_sin_old_il_acct  mo_sin_old_rev_tl_op  \
# id
# 167338079          0.0               179.0                  75.0
# 71016917           0.0               145.0                 137.0
# 39589826           0.0                57.0                  57.0
# 134798709          0.0                37.0                 132.0
# 127097355          0.0                72.0                 117.0
#
#            mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mths_since_recent_bc  \
# id
# 167338079                   38.0            16.0                  14.0
# 71016917                     7.0             7.0                   7.0
# 39589826                    14.0             9.0                  14.0
# 134798709                    1.0             1.0                   1.0
# 127097355                    6.0             6.0                   6.0
#
#            mths_since_recent_bc_dlq  mths_since_recent_inq  \
# id
# 167338079                      19.0                   16.0
# 71016917                        0.0                   24.0
# 39589826                        0.0                    1.0
# 134798709                       0.0                    3.0
# 127097355                       0.0                    5.0
#
#            mths_since_recent_revol_delinq  num_accts_ever_120_pd  \
# id
# 167338079                            19.0                    1.0
# 71016917                              0.0                    0.0
# 39589826                              0.0                    0.0
# 134798709                             0.0                    1.0
# 127097355                             0.0                    0.0
#
#            num_actv_bc_tl  num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  \
# id
# 167338079             0.0              2.0          0.0        1.0        5.0
# 71016917              3.0              5.0          5.0        6.0       15.0
# 39589826              3.0              5.0          3.0        3.0        2.0
# 134798709             6.0              7.0         11.0       16.0        2.0
# 127097355             4.0              5.0          5.0        6.0        5.0
#
#            num_op_rev_tl  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# id
# 167338079            2.0                  2.0       4.0               0.0
# 71016917             7.0                  5.0      10.0               0.0
# 39589826             5.0                  5.0       7.0               0.0
# 134798709           13.0                  7.0      15.0               0.0
# 127097355           13.0                  5.0      16.0               0.0
#
#            num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  \
# id
# 167338079           0.0                 0.0                 0.0
# 71016917            0.0                 0.0                 1.0
# 39589826            0.0                 0.0                 1.0
# 134798709           0.0                 0.0                 2.0
# 127097355           0.0                 0.0                 4.0
#
#            pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# id
# 167338079            75.0              33.3                   1.0        0.0
# 71016917             95.8              60.0                   0.0        0.0
# 39589826            100.0              33.3                   0.0        1.0
# 134798709            95.7               0.0                   0.0        0.0
# 127097355           100.0               0.0                   0.0        0.0
#
#            tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# id
# 167338079         395328.0            11948.0             0.0
# 71016917           88154.0            61815.0         13000.0
# 39589826          171118.0            13124.0         10000.0
# 134798709         202606.0            18520.0         49000.0
# 127097355         152081.0            34847.0         28800.0
#
#            total_il_high_credit_limit  grade  sub_grade  emp_length  \
# id
# 167338079                     17928.0    1.0        9.0          10
# 71016917                      52954.0    1.0        6.0           6
# 39589826                       7526.0    1.0        7.0          10
# 134798709                     20000.0    1.0        8.0          10
# 127097355                     38181.0    2.0       11.0          10
#
#            home_ownership  verification_status  purpose  addr_state  \
# id
# 167338079             1.0                  1.0      4.0        34.0
# 71016917              5.0                  1.0      1.0        18.0
# 39589826              1.0                  0.0      1.0         9.0
# 134798709             1.0                  0.0      2.0        35.0
# 127097355             1.0                  1.0      2.0        29.0
#
#            application_type  default_status  annual_inc_adj  dti_adj  \
# id
# 167338079               0.0           False         48000.0    20.25
# 71016917                0.0           False         57000.0    25.33
# 39589826                0.0           False         55000.0     7.22
# 134798709               0.0           False         43500.0    24.55
# 127097355               0.0           False         48000.0    24.30
#
#            fico_range_high_adj  inq_last_6mths_adj  open_acc_adj  \
# id
# 167338079                669.0                 0.0           4.0
# 71016917                 684.0                 0.0          10.0
# 39589826                 669.0                 0.0           7.0
# 134798709                754.0                 0.0          15.0
# 127097355                739.0                 1.0          16.0
#
#            revol_bal_adj  revol_util_adj  open_act_il_adj  \
# id
# 167338079         1988.0           41.40              1.0
# 71016917         22697.0           32.25              3.0
# 39589826          6001.0           26.30              2.0
# 134798709         6573.0            6.05              1.0
# 127097355        11894.0           13.55              2.0
#
#            chargeoff_within_12_mths_adj  mort_acc_adj  num_rev_accts_adj
# id
# 167338079                           0.0           2.0                5.0
# 71016917                            0.0           0.0                9.0
# 39589826                            0.0           1.0                6.0
# 134798709                           0.0           2.0               19.0
# 127097355                           0.0           2.0               16.0

# %% [markdown]
# The `eda_df` function is now used for merging intermediate `clean` and `encoded` datasets into a primary `analysis` dataset in `analysis` pipeleine:
# - `src/lending_club/pipelines/analysis/nodes.py`
# - `src/lending_club/pipelines/analysis/pipeline.py`
#
# As a result of this pipeline primary dataset for further analysis contains 99 features, including our `target`

# %%
# Run 'analysis' pipeline:
# !kedro run -p analysis
# Out:
# [11/04/24 14:17:23] INFO     Using 'D:\Program                  __init__.py:270
#                              Files\Python\Python
#                              Venv\lc\lib\site-packages\kedro\fr
#                              amework\project\rich_logging.yml'
#                              as logging configuration.
# [11/04/24 14:17:26] INFO     Kedro project lending-club          session.py:329
# [11/04/24 14:17:30] INFO     Using synchronous mode for sequential_runner.py:67
#                              loading and saving data.
#                              Use the --async flag for
#                              potential performance
#                              gains.
#                              https://docs.kedro.org/en/
#                              stable/nodes_and_pipelines
#                              /run_a_pipeline.html#load-
#                              and-save-asynchronously
#                     INFO     Loading data from              data_catalog.py:389
#                              intermediate_lc_clean
#                              (ParquetDataset)...
# [11/04/24 14:17:31] INFO     Loading data from parameters   data_catalog.py:389
#                              (MemoryDataset)...
#                     INFO     Running node: features_eng_node:       node.py:367
#                              features_eng([intermediate_lc_clean;pa
#                              rameters]) -> [features_new]
#                     INFO     Saving data to features_new    data_catalog.py:431
#                              (ParquetDataset)...
# [11/04/24 14:17:32] INFO     Completed 1 out of 2 tasks sequential_runner.py:93
#                     INFO     Loading data from              data_catalog.py:389
#                              intermediate_lc_clean
#                              (ParquetDataset)...
#                     INFO     Loading data from              data_catalog.py:389
#                              intermediate_encoded
#                              (ParquetDataset)...
#                     INFO     Loading data from features_new data_catalog.py:389
#                              (ParquetDataset)...
#                     INFO     Loading data from parameters   data_catalog.py:389
#                              (MemoryDataset)...
# [11/04/24 14:17:33] INFO     Running node: eda_df_node:             node.py:367
#                              eda_df([intermediate_lc_clean;intermed
#                              iate_encoded;features_new;parameters])
#                               -> [primary_analysis]
# [11/04/24 14:17:35] INFO     Saving data to                 data_catalog.py:431
#                              primary_analysis
#                              (ParquetDataset)...
# [11/04/24 14:17:36] INFO     Completed 2 out of 2 tasks sequential_runner.py:93
#                     INFO     Pipeline execution completed         runner.py:125
#                              successfully.

# %% [markdown]
# ## Descriptive analysis

# %%
# Load dataset for EDA
eda_table: pd.DataFrame = catalog.load('primary_analysis')
eda_table.head()
# Out:
# [11/04/24 14:17:37] INFO     Loading data from primary_analysis (ParquetDataset)...             data_catalog.py:389
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#            loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  \
# id
# 167338079     4000.0       4000.0           4000.0    36     13.08
# 71016917     24000.0      24000.0          24000.0    60      9.16
# 39589826      5000.0       5000.0           5000.0    36     10.49
# 134798709    24000.0      24000.0          24000.0    60     11.05
# 127097355    14000.0      14000.0          14000.0    60     13.59
#
#            installment  delinq_2yrs  fico_range_low  mths_since_last_delinq  \
# id
# 167338079       134.93          1.0           665.0                    19.0
# 71016917        500.07          0.0           680.0                     0.0
# 39589826        162.49          0.0           665.0                     0.0
# 134798709       522.42          0.0           750.0                     0.0
# 127097355       322.79          0.0           735.0                     0.0
#
#            mths_since_last_record  pub_rec  total_acc  \
# id
# 167338079                   110.0      1.0       12.0
# 71016917                      0.0      0.0       24.0
# 39589826                     61.0      1.0        9.0
# 134798709                     0.0      0.0       23.0
# 127097355                     0.0      0.0       23.0
#
#            collections_12_mths_ex_med  mths_since_last_major_derog  \
# id
# 167338079                         1.0                          0.0
# 71016917                          0.0                          0.0
# 39589826                          0.0                          0.0
# 134798709                         0.0                          0.0
# 127097355                         0.0                          0.0
#
#            acc_now_delinq  tot_coll_amt  tot_cur_bal  open_acc_6m  \
# id
# 167338079             0.0        3832.0     259024.0          0.0
# 71016917              0.0           0.0      61815.0          0.0
# 39589826              0.0           0.0     159131.0          1.0
# 134798709             0.0           0.0     104590.0          2.0
# 127097355             0.0           0.0      90253.0          2.0
#
#            open_il_12m  open_il_24m  mths_since_rcnt_il  total_bal_il  \
# id
# 167338079          0.0          1.0                16.0        9960.0
# 71016917           0.0          3.0                14.0       39118.0
# 39589826           0.0          1.0                 0.0       24095.5
# 134798709          0.0          1.0                17.0       11947.0
# 127097355          1.0          1.0                 7.0       22953.0
#
#            il_util  open_rv_12m  open_rv_24m  max_bal_bc  all_util  \
# id
# 167338079     56.0          0.0          0.0         0.0      59.0
# 71016917      72.0          1.0          1.0      2137.0      67.0
# 39589826      72.0          1.0          2.0      4569.0      57.0
# 134798709     60.0          2.0          3.0      2223.0      25.0
# 127097355     60.0          3.0          4.0      3907.0      43.0
#
#            total_rev_hi_lim  inq_fi  total_cu_tl  inq_last_12m  \
# id
# 167338079            2400.0     1.0          0.0           0.0
# 71016917            35200.0     0.0          7.0           0.0
# 39589826            11400.0     1.0          0.0           1.0
# 134798709           54500.0     2.0          0.0           2.0
# 127097355           43900.0     1.0          0.0           2.0
#
#            acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  bc_util  \
# id
# 167338079                   1.0      64756.0          6262.5     57.3
# 71016917                    4.0       6182.0          7741.0     40.5
# 39589826                    4.0      22733.0          4521.0     54.8
# 134798709                   4.0       6973.0         43140.0     12.0
# 127097355                   5.0       5641.0         17318.0     39.9
#
#            delinq_amnt  mo_sin_old_il_acct  mo_sin_old_rev_tl_op  \
# id
# 167338079          0.0               179.0                  75.0
# 71016917           0.0               145.0                 137.0
# 39589826           0.0                57.0                  57.0
# 134798709          0.0                37.0                 132.0
# 127097355          0.0                72.0                 117.0
#
#            mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mths_since_recent_bc  \
# id
# 167338079                   38.0            16.0                  14.0
# 71016917                     7.0             7.0                   7.0
# 39589826                    14.0             9.0                  14.0
# 134798709                    1.0             1.0                   1.0
# 127097355                    6.0             6.0                   6.0
#
#            mths_since_recent_bc_dlq  mths_since_recent_inq  \
# id
# 167338079                      19.0                   16.0
# 71016917                        0.0                   24.0
# 39589826                        0.0                    1.0
# 134798709                       0.0                    3.0
# 127097355                       0.0                    5.0
#
#            mths_since_recent_revol_delinq  num_accts_ever_120_pd  \
# id
# 167338079                            19.0                    1.0
# 71016917                              0.0                    0.0
# 39589826                              0.0                    0.0
# 134798709                             0.0                    1.0
# 127097355                             0.0                    0.0
#
#            num_actv_bc_tl  num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  \
# id
# 167338079             0.0              2.0          0.0        1.0        5.0
# 71016917              3.0              5.0          5.0        6.0       15.0
# 39589826              3.0              5.0          3.0        3.0        2.0
# 134798709             6.0              7.0         11.0       16.0        2.0
# 127097355             4.0              5.0          5.0        6.0        5.0
#
#            num_op_rev_tl  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# id
# 167338079            2.0                  2.0       4.0               0.0
# 71016917             7.0                  5.0      10.0               0.0
# 39589826             5.0                  5.0       7.0               0.0
# 134798709           13.0                  7.0      15.0               0.0
# 127097355           13.0                  5.0      16.0               0.0
#
#            num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  \
# id
# 167338079           0.0                 0.0                 0.0
# 71016917            0.0                 0.0                 1.0
# 39589826            0.0                 0.0                 1.0
# 134798709           0.0                 0.0                 2.0
# 127097355           0.0                 0.0                 4.0
#
#            pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# id
# 167338079            75.0              33.3                   1.0        0.0
# 71016917             95.8              60.0                   0.0        0.0
# 39589826            100.0              33.3                   0.0        1.0
# 134798709            95.7               0.0                   0.0        0.0
# 127097355           100.0               0.0                   0.0        0.0
#
#            tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# id
# 167338079         395328.0            11948.0             0.0
# 71016917           88154.0            61815.0         13000.0
# 39589826          171118.0            13124.0         10000.0
# 134798709         202606.0            18520.0         49000.0
# 127097355         152081.0            34847.0         28800.0
#
#            total_il_high_credit_limit  grade  sub_grade  emp_length  \
# id
# 167338079                     17928.0    1.0        9.0          10
# 71016917                      52954.0    1.0        6.0           6
# 39589826                       7526.0    1.0        7.0          10
# 134798709                     20000.0    1.0        8.0          10
# 127097355                     38181.0    2.0       11.0          10
#
#            home_ownership  verification_status  purpose  addr_state  \
# id
# 167338079             1.0                  1.0      4.0        34.0
# 71016917              5.0                  1.0      1.0        18.0
# 39589826              1.0                  0.0      1.0         9.0
# 134798709             1.0                  0.0      2.0        35.0
# 127097355             1.0                  1.0      2.0        29.0
#
#            application_type  verification_status_joint  default_status  \
# id
# 167338079               0.0                        3.0           False
# 71016917                0.0                        3.0           False
# 39589826                0.0                        3.0           False
# 134798709               0.0                        3.0           False
# 127097355               0.0                        3.0           False
#
#            annual_inc_adj  dti_adj  fico_range_high_adj  inq_last_6mths_adj  \
# id
# 167338079         48000.0    20.25                669.0                 0.0
# 71016917          57000.0    25.33                684.0                 0.0
# 39589826          55000.0     7.22                669.0                 0.0
# 134798709         43500.0    24.55                754.0                 0.0
# 127097355         48000.0    24.30                739.0                 1.0
#
#            open_acc_adj  revol_bal_adj  revol_util_adj  open_act_il_adj  \
# id
# 167338079           4.0         1988.0           41.40              1.0
# 71016917           10.0        22697.0           32.25              3.0
# 39589826            7.0         6001.0           26.30              2.0
# 134798709          15.0         6573.0            6.05              1.0
# 127097355          16.0        11894.0           13.55              2.0
#
#            chargeoff_within_12_mths_adj  mort_acc_adj  num_rev_accts_adj
# id
# 167338079                           0.0           2.0                5.0
# 71016917                            0.0           0.0                9.0
# 39589826                            0.0           1.0                6.0
# 134798709                           0.0           2.0               19.0
# 127097355                           0.0           2.0               16.0

# %%
from scipy.stats import skew
statistics = eda_table.describe().transpose().reset_index()
statistics['skew'] = skew(eda_table[statistics['index']])
statistics.set_index('index', drop=True, inplace=True)

z_scores = np.abs(stats.zscore(eda_table.astype(float)))
gt_thresh = z_scores > 3.5
statistics['outliers_num (zs:3.5)'] = gt_thresh.sum()

statistics
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                    count           mean            std  \
# index
# loan_amnt                       100000.0   15332.373000    9468.189883
# funded_amnt                     100000.0   15328.216250    9467.415275
# funded_amnt_inv                 100000.0   15313.244829    9470.918891
# term                            100000.0      43.107840      10.957553
# int_rate                        100000.0      13.056737       4.876960
# installment                     100000.0     451.708510     273.022605
# delinq_2yrs                     100000.0       0.284730       0.823520
# fico_range_low                  100000.0     700.639200      33.800996
# mths_since_last_delinq          100000.0      16.531270      23.076073
# mths_since_last_record          100000.0      10.964470      28.367616
# pub_rec                         100000.0       0.177700       0.550750
# total_acc                       100000.0      24.040390      12.055591
# collections_12_mths_ex_med      100000.0       0.017650       0.144287
# mths_since_last_major_derog     100000.0      10.980690      22.013029
# acc_now_delinq                  100000.0       0.003460       0.063467
# tot_coll_amt                    100000.0     202.984480    1660.176681
# tot_cur_bal                     100000.0  144341.811050  162748.777193
# open_acc_6m                     100000.0       0.949370       0.950650
# open_il_12m                     100000.0       0.495240       0.852505
# open_il_24m                     100000.0       1.433640       1.367214
# mths_since_rcnt_il              100000.0      13.865950      22.897071
# total_bal_il                    100000.0   33123.342200   39086.972398
# il_util                         100000.0      70.183820      18.296131
# open_rv_12m                     100000.0       1.176510       1.256531
# open_rv_24m                     100000.0       2.453850       2.167643
# max_bal_bc                      100000.0    5575.769270    4670.924996
# all_util                        100000.0      56.404980      17.452964
# total_rev_hi_lim                100000.0   36163.940240   35415.209389
# inq_fi                          100000.0       1.052930       1.255613
# total_cu_tl                     100000.0       1.067650       2.384188
# inq_last_12m                    100000.0       1.702650       2.022635
# acc_open_past_24mths            100000.0       4.503060       3.145459
# avg_cur_bal                     100000.0   13603.618230   16516.890435
# bc_open_to_buy                  100000.0   12593.663510   17872.690074
# bc_util                         100000.0      55.880517      28.421972
# delinq_amnt                     100000.0      10.706750     694.930099
# mo_sin_old_il_acct              100000.0     125.978910      53.005821
# mo_sin_old_rev_tl_op            100000.0     179.512610      97.235290
# mo_sin_rcnt_rev_tl_op           100000.0      14.329270      17.788442
# mo_sin_rcnt_tl                  100000.0       8.268650       9.160412
# mths_since_recent_bc            100000.0      24.792210      32.110541
# mths_since_recent_bc_dlq        100000.0       8.633340      19.409618
# mths_since_recent_inq           100000.0       6.953990       5.587834
# mths_since_recent_revol_delinq  100000.0      11.455930      20.963020
# num_accts_ever_120_pd           100000.0       0.471840       1.333238
# num_actv_bc_tl                  100000.0       3.685540       2.354003
# num_actv_rev_tl                 100000.0       5.579590       3.370501
# num_bc_sats                     100000.0       4.840900       3.086983
# num_bc_tl                       100000.0       7.619860       4.637556
# num_il_tl                       100000.0       8.520490       7.344844
# num_op_rev_tl                   100000.0       8.235270       4.731972
# num_rev_tl_bal_gt_0             100000.0       5.537140       3.299153
# num_sats                        100000.0      11.685480       5.700798
# num_tl_120dpd_2m                100000.0       0.000420       0.020972
# num_tl_30dpd                    100000.0       0.002250       0.050448
# num_tl_90g_dpd_24m              100000.0       0.073470       0.451103
# num_tl_op_past_12m              100000.0       2.078560       1.821626
# pct_tl_nvr_dlq                  100000.0      94.494350       8.859890
# percent_bc_gt_75                100000.0      39.857946      35.565925
# pub_rec_bankruptcies            100000.0       0.123260       0.354328
# tax_liens                       100000.0       0.036770       0.365731
# tot_hi_cred_lim                 100000.0  182248.841080  182116.296271
# total_bal_ex_mort               100000.0   52545.436140   51300.027650
# total_bc_limit                  100000.0   24704.074580   24288.266304
# total_il_high_credit_limit      100000.0   45331.974970   46394.033542
# grade                           100000.0       1.557750       1.235775
# sub_grade                       100000.0       9.764570       6.194228
# emp_length                      100000.0       6.112350       3.772080
# home_ownership                  100000.0       2.915050       1.913460
# verification_status             100000.0       0.881340       0.772403
# purpose                         100000.0       2.686190       2.385584
# addr_state                      100000.0      23.226620      15.090873
# application_type                100000.0       0.071660       0.257925
# verification_status_joint       100000.0       2.847350       0.607480
# annual_inc_adj                  100000.0   84806.896400   88993.352818
# dti_adj                         100000.0      18.348335       8.481747
# fico_range_high_adj             100000.0     704.720200      33.824425
# inq_last_6mths_adj              100000.0       0.596780       0.922227
# open_acc_adj                    100000.0      12.479060       6.784459
# revol_bal_adj                   100000.0   18123.084060   23716.736189
# revol_util_adj                  100000.0      26.313150      14.812655
# open_act_il_adj                 100000.0       2.799610       2.902095
# chargeoff_within_12_mths_adj    100000.0       0.011080       0.137541
# mort_acc_adj                    100000.0       1.603190       2.036765
# num_rev_accts_adj               100000.0      14.592940       8.865454
#
#                                     min       25%        50%        75%  \
# index
# loan_amnt                        700.00   8000.00   13000.00   20000.00
# funded_amnt                      700.00   8000.00   13000.00   20000.00
# funded_amnt_inv                    0.00   8000.00   13000.00   20000.00
# term                              36.00     36.00      36.00      60.00
# int_rate                           5.31      9.17      12.49      16.01
# installment                       22.51    253.06     380.81     602.30
# delinq_2yrs                        0.00      0.00       0.00       0.00
# fico_range_low                   640.00    675.00     695.00     720.00
# mths_since_last_delinq             0.00      0.00       0.00      30.00
# mths_since_last_record             0.00      0.00       0.00       0.00
# pub_rec                            0.00      0.00       0.00       0.00
# total_acc                          1.00     15.00      22.00      31.00
# collections_12_mths_ex_med         0.00      0.00       0.00       0.00
# mths_since_last_major_derog        0.00      0.00       0.00       0.00
# acc_now_delinq                     0.00      0.00       0.00       0.00
# tot_coll_amt                       0.00      0.00       0.00       0.00
# tot_cur_bal                        0.00  30430.75   80931.50  214206.00
# open_acc_6m                        0.00      0.00       1.00       1.00
# open_il_12m                        0.00      0.00       0.00       1.00
# open_il_24m                        0.00      1.00       1.00       2.00
# mths_since_rcnt_il                 0.00      0.00       7.00      17.00
# total_bal_il                       0.00  15047.75   24095.50   35450.00
# il_util                            0.00     67.00      72.00      76.00
# open_rv_12m                        0.00      0.00       1.00       1.00
# open_rv_24m                        0.00      1.00       2.00       3.00
# max_bal_bc                         0.00   3233.00    4569.00    6168.25
# all_util                           0.00     49.00      57.00      65.00
# total_rev_hi_lim                   0.00  15600.00   26800.00   45000.00
# inq_fi                             0.00      0.00       1.00       1.00
# total_cu_tl                        0.00      0.00       0.00       1.00
# inq_last_12m                       0.00      1.00       1.00       2.00
# acc_open_past_24mths               0.00      2.00       4.00       6.00
# avg_cur_bal                        0.00   3194.00    7461.50   18730.50
# bc_open_to_buy                     0.00   2085.00    6262.50   15720.25
# bc_util                            0.00     33.50      57.30      80.50
# delinq_amnt                        0.00      0.00       0.00       0.00
# mo_sin_old_il_acct                 0.00     96.00     130.00     153.00
# mo_sin_old_rev_tl_op               3.00    113.00     162.00     228.00
# mo_sin_rcnt_rev_tl_op              0.00      4.00       9.00      18.00
# mo_sin_rcnt_tl                     0.00      3.00       6.00      10.00
# mths_since_recent_bc               0.00      6.00      14.00      30.00
# mths_since_recent_bc_dlq           0.00      0.00       0.00       0.00
# mths_since_recent_inq              0.00      3.00       6.00      10.00
# mths_since_recent_revol_delinq     0.00      0.00       0.00      15.00
# num_accts_ever_120_pd              0.00      0.00       0.00       0.00
# num_actv_bc_tl                     0.00      2.00       3.00       5.00
# num_actv_rev_tl                    0.00      3.00       5.00       7.00
# num_bc_sats                        0.00      3.00       4.00       6.00
# num_bc_tl                          0.00      4.00       7.00      10.00
# num_il_tl                          0.00      4.00       7.00      11.00
# num_op_rev_tl                      0.00      5.00       7.00      10.00
# num_rev_tl_bal_gt_0                0.00      3.00       5.00       7.00
# num_sats                           0.00      8.00      11.00      14.00
# num_tl_120dpd_2m                   0.00      0.00       0.00       0.00
# num_tl_30dpd                       0.00      0.00       0.00       0.00
# num_tl_90g_dpd_24m                 0.00      0.00       0.00       0.00
# num_tl_op_past_12m                 0.00      1.00       2.00       3.00
# pct_tl_nvr_dlq                    10.00     92.00     100.00     100.00
# percent_bc_gt_75                   0.00      0.00      33.30      66.70
# pub_rec_bankruptcies               0.00      0.00       0.00       0.00
# tax_liens                          0.00      0.00       0.00       0.00
# tot_hi_cred_lim                    0.00  53922.75  118273.50  261238.75
# total_bal_ex_mort                  0.00  21663.00   38952.00   65758.50
# total_bc_limit                     0.00   9000.00   17500.00   32100.00
# total_il_high_credit_limit         0.00  16000.00   34083.00   60212.25
# grade                              0.00      1.00       1.00       2.00
# sub_grade                          0.00      5.00       9.00      14.00
# emp_length                         0.00      2.00       7.00      10.00
# home_ownership                     0.00      1.00       4.00       5.00
# verification_status                0.00      0.00       1.00       1.00
# purpose                            0.00      2.00       2.00       2.00
# addr_state                         0.00      9.00      23.00      36.00
# application_type                   0.00      0.00       0.00       0.00
# verification_status_joint          0.00      3.00       3.00       3.00
# annual_inc_adj                  4200.00  50000.00   70000.00  100000.00
# dti_adj                            0.00     12.03      17.86      24.33
# fico_range_high_adj              644.00    679.00     699.00     724.00
# inq_last_6mths_adj                 0.00      0.00       0.00       1.00
# open_acc_adj                       0.00      8.00      11.00      15.00
# revol_bal_adj                      0.00   6224.00   12051.00   22054.25
# revol_util_adj                     0.00     15.50      25.30      35.60
# open_act_il_adj                    0.00      2.00       2.00       3.00
# chargeoff_within_12_mths_adj       0.00      0.00       0.00       0.00
# mort_acc_adj                       0.00      0.00       1.00       3.00
# num_rev_accts_adj                  1.00      8.00      12.00      19.00
#
#                                         max        skew  outliers_num (zs:3.5)
# index
# loan_amnt                          40000.00    0.788725                      0
# funded_amnt                        40000.00    0.789471                      0
# funded_amnt_inv                    40000.00    0.789088                      0
# term                                  60.00    0.892934                      0
# int_rate                              30.99    0.775004                    285
# installment                         1719.83    1.006219                     91
# delinq_2yrs                           18.00    5.561436                   1142
# fico_range_low                       845.00    1.101895                    393
# mths_since_last_delinq               226.00    1.256342                     60
# mths_since_last_record               124.00    2.444378                   1282
# pub_rec                               52.00   15.282150                    660
# total_acc                            115.00    1.002089                    451
# collections_12_mths_ex_med             7.00   10.400822                   1634
# mths_since_last_major_derog          226.00    1.903148                    202
# acc_now_delinq                         4.00   21.819823                    323
# tot_coll_amt                      169257.00   35.933178                    678
# tot_cur_bal                      4035706.00    2.868847                    936
# open_acc_6m                           13.00    1.883765                    865
# open_il_12m                           13.00    2.217276                   1089
# open_il_24m                           28.00    2.304861                    981
# mths_since_rcnt_il                   511.00    4.042490                   1909
# total_bal_il                      924163.00    4.537807                   1463
# il_util                              364.00   -0.540726                    754
# open_rv_12m                           26.00    2.642805                   1302
# open_rv_24m                           34.00    2.521435                   1051
# max_bal_bc                         94246.00    3.033961                   1444
# all_util                             175.00   -0.160339                    130
# total_rev_hi_lim                 1333000.00    4.830283                   1183
# inq_fi                                24.00    2.974028                   1347
# total_cu_tl                           49.00    4.097789                   1622
# inq_last_12m                          34.00    3.005273                   1569
# acc_open_past_24mths                  42.00    1.394255                    718
# avg_cur_bal                       471749.00    3.695773                   1207
# bc_open_to_buy                    393250.00    3.628545                   1461
# bc_util                              175.00   -0.189915                      2
# delinq_amnt                       130778.00  112.071804                     50
# mo_sin_old_il_acct                   999.00    0.420615                    410
# mo_sin_old_rev_tl_op                 808.00    1.051352                    538
# mo_sin_rcnt_rev_tl_op                372.00    3.619221                   1575
# mo_sin_rcnt_tl                       251.00    4.693616                   1173
# mths_since_recent_bc                 639.00    3.573399                   1536
# mths_since_recent_bc_dlq             189.00    2.337117                   1181
# mths_since_recent_inq                 24.00    1.011189                      0
# mths_since_recent_revol_delinq       183.00    1.852933                    225
# num_accts_ever_120_pd                 35.00    5.597019                   1449
# num_actv_bc_tl                        50.00    1.593292                    982
# num_actv_rev_tl                       72.00    1.673965                    853
# num_bc_sats                           59.00    1.740486                    968
# num_bc_tl                             59.00    1.430823                    877
# num_il_tl                             91.00    2.083754                   1122
# num_op_rev_tl                         72.00    1.580536                    907
# num_rev_tl_bal_gt_0                   65.00    1.605738                    733
# num_sats                              82.00    1.333580                    744
# num_tl_120dpd_2m                       2.00   51.978253                     41
# num_tl_30dpd                           4.00   26.270977                    213
# num_tl_90g_dpd_24m                    18.00   13.216567                   1145
# num_tl_op_past_12m                    29.00    1.528486                    746
# pct_tl_nvr_dlq                       100.00   -2.395688                   1340
# percent_bc_gt_75                     100.00    0.427702                      0
# pub_rec_bankruptcies                   7.00    3.333348                    481
# tax_liens                             52.00   44.906391                    702
# tot_hi_cred_lim                  4265968.00    2.740851                    908
# total_bal_ex_mort                1162942.00    3.453326                   1340
# total_bc_limit                    425150.00    2.719646                   1227
# total_il_high_credit_limit       1029490.00    2.925285                   1246
# grade                                  6.00    0.640524                    420
# sub_grade                             34.00    0.593434                    206
# emp_length                            10.00   -0.287220                      0
# home_ownership                         5.00    0.033990                      0
# verification_status                    2.00    0.207000                      0
# purpose                               13.00    2.178988                    773
# addr_state                            50.00    0.054000                      0
# application_type                       1.00    3.321442                   7166
# verification_status_joint              3.00   -4.015314                   3350
# annual_inc_adj                  10999200.00   44.248464                    432
# dti_adj                               49.86    0.224183                      7
# fico_range_high_adj                  850.00    1.100201                    395
# inq_last_6mths_adj                    25.00    2.197385                   1415
# open_acc_adj                         118.00    1.783569                    932
# revol_bal_adj                    1107809.00    7.607089                   1132
# revol_util_adj                       107.05    0.843817                    858
# open_act_il_adj                       51.00    3.677273                   1937
# chargeoff_within_12_mths_adj          12.00   25.070316                    912
# mort_acc_adj                          47.00    2.040619                    971
# num_rev_accts_adj                    129.00    1.699403                    901

# %%
eda_table.default_status.describe()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# count     100000
# unique         2
# top        False
# freq       87569
# Name: default_status, dtype: object

# %% [markdown]
# >**Key statistics**
# >`Annual income` is highly left skewed, where distance between median and max is very high. `Loan amoumts`, `interest rates`, `installments` and `fico ranges` are slightly skewed to left. All of these features, has 280-400 outliers at z-core **3.5**, except loan amount (none).
#
# >`Default status` has 87.5% of `false` values, that means our target is inbalanced. For better prediction outcome of our model dataset shpild be balanced fisrt.

# %% [markdown]
# ## Selecting features

# %%
import matplotlib.pyplot  as plt
import seaborn as sns

def sel_high_corr_feat(df: pd.DataFrame, corr_treshold):
    eda_corr=df.corr()
    def_stat_corr = eda_corr.default_status.sort_values().drop('default_status')
    target_high_corr = def_stat_corr[np.abs(def_stat_corr) > corr_treshold]
    fig, ax = plt.subplots(figsize=(30, 10))
    ax = sns.barplot(def_stat_corr, color='lightgrey')
    ax = sns.barplot(target_high_corr, color="green")
    for label in ax.get_xticklabels():
        label.set_rotation(90)
    plt.title('Correlation to Defalt status', fontsize=20, pad=20)
    plt.show()
    return target_high_corr


target_high_corr_feat = sel_high_corr_feat(eda_table, 0.05)
print("No of High correlated to target features: ", target_high_corr_feat.shape[0])
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 3000x1000 with 1 Axes>
# No of High correlated to target features:  27

# %%
sns.set_theme(style="whitegrid")

# Compute a correlation matrix and convert to long-form
corr_mtx = eda_table[target_high_corr_feat.index.to_list()].corr().stack().reset_index(name='Correlation')
# Draw each cell as a scatter point with varying size and color
g = sns.relplot(
    data=corr_mtx,
    x="level_0", y="level_1", hue="Correlation", size="Correlation",
    palette="vlag", hue_norm=(-1, 1), edgecolor=".7",
    height=10, sizes=(50, 250), size_norm=(-.2, .8),
)
# Tweak the figure to finalize
g.set(xlabel="", ylabel="", aspect="equal")
g.despine(left=True, bottom=True)
g.ax.margins(.02)
for label in g.ax.get_xticklabels():
    label.set_rotation(90)
plt.title('Correlation heatmap', fontsize=20, pad=20)
plt.show()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1093.72x1000 with 1 Axes>

# %%
df_high_corr = corr_mtx[(corr_mtx.Correlation != 1) & (corr_mtx.Correlation > 0.75)].sort_values(by='Correlation', ascending=False).drop_duplicates('Correlation')

print("No of highly correlated features:", df_high_corr.shape[0])
df_high_corr
# Out:
# No of highly correlated features: 11
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                  level_0               level_1  Correlation
# 1    fico_range_high_adj        fico_range_low     0.998984
# 115      tot_hi_cred_lim           tot_cur_bal     0.982831
# 701                grade             sub_grade     0.973179
# 674             int_rate             sub_grade     0.962326
# 673             int_rate                 grade     0.937408
# 83        total_bc_limit        bc_open_to_buy     0.854934
# 477              bc_util      percent_bc_gt_75     0.847135
# 169          avg_cur_bal           tot_cur_bal     0.824250
# 138     total_rev_hi_lim        total_bc_limit     0.812928
# 114      tot_hi_cred_lim           avg_cur_bal     0.788517
# 589   num_tl_op_past_12m  acc_open_past_24mths     0.767958

# %% [markdown]
# >This dataset has 27 features that has correlation to `target` more than 5%, 11 of them has correlation between each other by more than 75% and might be dropped from model input.

# %%
# TODO: Remove
# Select important variables for prediction model
important_feat = list(set(target_high_corr_feat.index.to_list()) - set(df_high_corr['level_0']))

# Print for parameters....yml
print("features:")
[print("  - ", feat) for feat in important_feat]
# Out:
# features:
#   -  open_rv_24m
#   -  mort_acc_adj
#   -  term
#   -  sub_grade
#   -  tot_cur_bal
#   -  open_acc_6m
#   -  dti_adj
#   -  fico_range_low
#   -  mths_since_recent_inq
#   -  percent_bc_gt_75
#   -  mths_since_rcnt_il
#   -  inq_last_6mths_adj
#   -  max_bal_bc
#   -  acc_open_past_24mths
#   -  bc_open_to_buy
#   -  home_ownership
#   -  mo_sin_rcnt_rev_tl_op
#   -  verification_status
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None
# ]

# %%
# Redefine function that will select features with strong correlation
# to the target based on two thresholds feeded as parameters: 
#   - correlation to target
#   - intercorellation between features
def sel_high_corr_feat(df: pd.DataFrame, params: dict):
    eda_corr=df.corr()
    def_stat_corr = eda_corr.default_status.sort_values().drop('default_status')
    # Compute a correlation matrix and convert to long-form
    target_high_corr = def_stat_corr[np.abs(def_stat_corr) > params['corr_treshold']]
    corr_mtx = df[target_high_corr.index.to_list()].corr().stack().reset_index(name='Correlation')
    df_high_corr = corr_mtx[(corr_mtx.Correlation != 1) & (corr_mtx.Correlation > params['intercorr_treshold'])].sort_values(by='Correlation', ascending=False).drop_duplicates('Correlation')
    # Select important variables for prediction model
    important_feat = {
        'target': 'default_status',
        'model_features': list(set(target_high_corr.index.to_list()) - set(df_high_corr['level_0']))}
    return important_feat

print(sel_high_corr_feat(eda_table, {'corr_treshold': 0.05, 'intercorr':0.75}))
# Out:
# {'model_features': ['default_status', 'open_rv_24m', 'mort_acc_adj', 'term', 'sub_grade', 'tot_cur_bal', 'open_acc_6m', 'dti_adj', 'fico_range_low', 'mths_since_recent_inq', 'percent_bc_gt_75', 'mths_since_rcnt_il', 'inq_last_6mths_adj', 'max_bal_bc', 'acc_open_past_24mths', 'bc_open_to_buy', 'home_ownership', 'mo_sin_rcnt_rev_tl_op', 'verification_status']}

# %% [markdown]
# After analysis of our dataset I choose 18 features that has stronger correlation to our target and will be used in my model.
# The function above will be used in `features` pipeline to select features for baseline model and save them in `features` table:
# - `src\lending_club\pipelines\features\nodes.py`
# - `src\lending_club\pipelines\features\pipeline.py`
#
# Run pipeline:

# %%
# !kedro run -p features
# Out:
# [11/04/24 15:20:56] INFO     Using 'D:\Program                  __init__.py:270
#                              Files\Python\Python
#                              Venv\lc\lib\site-packages\kedro\fr
#                              amework\project\rich_logging.yml'
#                              as logging configuration.
# [11/04/24 15:20:59] INFO     Kedro project lending-club          session.py:329
# [11/04/24 15:21:08] INFO     Using synchronous mode for sequential_runner.py:67
#                              loading and saving data.
#                              Use the --async flag for
#                              potential performance
#                              gains.
#                              https://docs.kedro.org/en/
#                              stable/nodes_and_pipelines
#                              /run_a_pipeline.html#load-
#                              and-save-asynchronously
#                     INFO     Loading data from              data_catalog.py:389
#                              primary_analysis
#                              (ParquetDataset)...
# [11/04/24 15:21:09] INFO     Loading data from parameters   data_catalog.py:389
#                              (MemoryDataset)...
#                     INFO     Running node: selected_features_node:  node.py:367
#                              selected_features([primary_analysis;pa
#                              rameters]) -> [model_features#yml]
# [11/04/24 15:21:13] INFO     Saving data to                 data_catalog.py:431
#                              model_features#yml
#                              (YAMLDataset)...
#                     INFO     Completed 1 out of 1 tasks sequential_runner.py:93
#                     INFO     Pipeline execution completed         runner.py:125
#                              successfully.
