# %% [markdown]
# # INFO
#
# This notebook will be used for construction data processing nodes and data exploration purposes within Kedro framework.

# %%
# Load Kedro extention
# %load_ext kedro.ipython
# Out:
# [10/29/24 00:33:22] INFO     Using                                                                  ]8;id=207340;file:///Users/andrejcemeris/anaconda3/envs/kedro_env/lib/python3.10/site-packages/kedro/framework/project/__init__.py\__init__.py]8;;\:]8;id=496509;file:///Users/andrejcemeris/anaconda3/envs/kedro_env/lib/python3.10/site-packages/kedro/framework/project/__init__.py#270\270]8;;\
#                              '/Users/andrejcemeris/anaconda3/envs/kedro_env/lib/python3.10/site-pac
#                              kages/kedro/framework/project/rich_logging.yml' as logging
#                              configuration.
#                     INFO     Registered line magic '%reload_kedro'                                   ]8;id=134357;file:///Users/andrejcemeris/anaconda3/envs/kedro_env/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=434173;file:///Users/andrejcemeris/anaconda3/envs/kedro_env/lib/python3.10/site-packages/kedro/ipython/__init__.py#61\61]8;;\
#                     INFO     Registered line magic '%load_node'                                      ]8;id=899280;file:///Users/andrejcemeris/anaconda3/envs/kedro_env/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=864241;file:///Users/andrejcemeris/anaconda3/envs/kedro_env/lib/python3.10/site-packages/kedro/ipython/__init__.py#63\63]8;;\
#                     INFO     Resolved project path as:                                              ]8;id=653266;file:///Users/andrejcemeris/anaconda3/envs/kedro_env/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=116362;file:///Users/andrejcemeris/anaconda3/envs/kedro_env/lib/python3.10/site-packages/kedro/ipython/__init__.py#178\178]8;;\
#                              /Users/andrejcemeris/Projects/Python3/lending-club.
#                              To set a different path, run '%reload_kedro <project_root>'
# [10/29/24 00:33:26] INFO     Kedro is sending anonymous usage data with the sole purpose of improving ]8;id=732713;file:///Users/andrejcemeris/anaconda3/envs/kedro_env/lib/python3.10/site-packages/kedro_telemetry/plugin.py\plugin.py]8;;\:]8;id=463612;file:///Users/andrejcemeris/anaconda3/envs/kedro_env/lib/python3.10/site-packages/kedro_telemetry/plugin.py#233\233]8;;\
#                              the product. No personal data or IP addresses are stored on our side. If
#                              you want to opt out, set the `KEDRO_DISABLE_TELEMETRY` or `DO_NOT_TRACK`
#                              environment variables, or create a `.telemetry` file in the current
#                              working directory with the contents `consent: false`. Read more at
#                              https://docs.kedro.org/en/stable/configuration/telemetry.html
# [10/29/24 00:33:27] INFO     Kedro project lending_club                                             ]8;id=663546;file:///Users/andrejcemeris/anaconda3/envs/kedro_env/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=223624;file:///Users/andrejcemeris/anaconda3/envs/kedro_env/lib/python3.10/site-packages/kedro/ipython/__init__.py#144\144]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            ]8;id=961733;file:///Users/andrejcemeris/anaconda3/envs/kedro_env/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=962550;file:///Users/andrejcemeris/anaconda3/envs/kedro_env/lib/python3.10/site-packages/kedro/ipython/__init__.py#145\145]8;;\
#                              'pipelines'
# [10/29/24 00:33:29] INFO     Registered line magic 'run_viz'                                        ]8;id=188323;file:///Users/andrejcemeris/anaconda3/envs/kedro_env/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=598410;file:///Users/andrejcemeris/anaconda3/envs/kedro_env/lib/python3.10/site-packages/kedro/ipython/__init__.py#151\151]8;;\

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Load Lending Club dataset defined as 'original_lc_dataset' in catalog.yml
lending_club = catalog.load("original_lc_dataset")
lending_club.head()
# Out:
#                     INFO     Loading data from original_lc_dataset (CSVDataset)...              ]8;id=607052;file:///Users/andrejcemeris/anaconda3/envs/kedro_env/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=525100;file:///Users/andrejcemeris/anaconda3/envs/kedro_env/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#    Unnamed: 0.1  Unnamed: 0         id  loan_amnt  funded_amnt  \
# 0       1746494       25450  167338079     4000.0       4000.0
# 1       2370717       81861   71016917    24000.0      24000.0
# 2       2264870      397109   39589826     5000.0       5000.0
# 3        595422       15492  134798709    24000.0      24000.0
# 4        562657       90591  127097355    14000.0      14000.0
#
#    funded_amnt_inv        term int_rate  installment grade sub_grade  \
# 0           4000.0   36 months   13.08%       134.93     B        B5
# 1          24000.0   60 months    9.16%       500.07     B        B2
# 2           5000.0   36 months   10.49%       162.49     B        B3
# 3          24000.0   60 months   11.05%       522.42     B        B4
# 4          14000.0   60 months   13.59%       322.79     C        C2
#
#         emp_title emp_length home_ownership  annual_inc verification_status  \
# 0         cashier  10+ years       MORTGAGE     48000.0     Source Verified
# 1             ABM    6 years           RENT     57000.0     Source Verified
# 2          driver  10+ years       MORTGAGE     55000.0        Not Verified
# 3             NaN        NaN       MORTGAGE     43500.0        Not Verified
# 4  Shipping Clerk  10+ years       MORTGAGE     48000.0     Source Verified
#
#     issue_d loan_status pymnt_plan  \
# 0  Mar-2020     Current          n
# 1  Feb-2016     Current          n
# 2  Jan-2015  Fully Paid          n
# 3  Jun-2018     Current          n
# 4  Jan-2018  Fully Paid          n
#
#                                                  url             purpose  \
# 0  https://lendingclub.com/browse/loanDetail.acti...    home_improvement
# 1  https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 2  https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 3  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 4  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
#
#                      title zip_code addr_state    dti  delinq_2yrs  \
# 0         Home improvement    115xx         NY  20.25          1.0
# 1  Credit card refinancing    708xx         LA  25.33          0.0
# 2  Credit card refinancing    347xx         FL   7.22          0.0
# 3       Debt consolidation    443xx         OH  24.55          0.0
# 4       Debt consolidation    681xx         NE  24.30          0.0
#
#   earliest_cr_line  fico_range_low  fico_range_high  inq_last_6mths  \
# 0         Dec-2004           665.0            669.0             0.0
# 1         Jan-2004           680.0            684.0             0.0
# 2         Apr-2010           665.0            669.0             0.0
# 3         Oct-2005           750.0            754.0             0.0
# 4         Apr-2008           735.0            739.0             1.0
#
#    mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  \
# 0                    19.0                   110.0       4.0      1.0
# 1                     NaN                     NaN      10.0      0.0
# 2                     NaN                    61.0       7.0      1.0
# 3                     NaN                     NaN      15.0      0.0
# 4                     NaN                     NaN      16.0      0.0
#
#    revol_bal revol_util  total_acc initial_list_status  out_prncp  \
# 0     1988.0      82.8%       12.0                   w    3816.34
# 1    22697.0      64.5%       24.0                   w    4333.29
# 2     6001.0      52.6%        9.0                   f       0.00
# 3     6573.0      12.1%       23.0                   w   16317.69
# 4    11894.0      27.1%       23.0                   w       0.00
#
#    out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 0        3816.34    266.950000           266.95           183.66
# 1        4333.29  25496.160000         25496.16         19666.71
# 2           0.00   5846.672836          5846.67          5000.00
# 3       16317.69  12000.930000         12000.93          7682.31
# 4           0.00  16605.680000         16605.68         14000.00
#
#    total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee  \
# 0          83.29                 0.0         0.0                      0.0
# 1        5829.45                 0.0         0.0                      0.0
# 2         846.67                 0.0         0.0                      0.0
# 3        4318.62                 0.0         0.0                      0.0
# 4        2605.68                 0.0         0.0                      0.0
#
#   last_pymnt_d  last_pymnt_amnt next_pymnt_d last_credit_pull_d  \
# 0     May-2020           134.93     Jun-2020           May-2020
# 1     May-2020           500.07     Jun-2020           May-2020
# 2     Jan-2018           162.43          NaN           May-2020
# 3     May-2020           522.42     Jun-2020           May-2020
# 4     Jul-2019         11128.82          NaN           Feb-2020
#
#    last_fico_range_high  last_fico_range_low  collections_12_mths_ex_med  \
# 0                 669.0                665.0                         1.0
# 1                 704.0                700.0                         0.0
# 2                 789.0                785.0                         0.0
# 3                 749.0                745.0                         0.0
# 4                 779.0                775.0                         0.0
#
#    mths_since_last_major_derog  policy_code application_type  \
# 0                          NaN          1.0       Individual
# 1                          NaN          1.0       Individual
# 2                          NaN          1.0       Individual
# 3                          NaN          1.0       Individual
# 4                          NaN          1.0       Individual
#
#    annual_inc_joint  dti_joint verification_status_joint  acc_now_delinq  \
# 0               NaN        NaN                       NaN             0.0
# 1               NaN        NaN                       NaN             0.0
# 2               NaN        NaN                       NaN             0.0
# 3               NaN        NaN                       NaN             0.0
# 4               NaN        NaN                       NaN             0.0
#
#    tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  open_il_12m  \
# 0        3832.0     259024.0          0.0          1.0          0.0
# 1           0.0      61815.0          0.0          3.0          0.0
# 2           0.0     159131.0          NaN          NaN          NaN
# 3           0.0     104590.0          2.0          1.0          0.0
# 4           0.0      90253.0          2.0          2.0          1.0
#
#    open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 0          1.0                16.0        9960.0     56.0          0.0
# 1          3.0                14.0       39118.0     72.0          1.0
# 2          NaN                 NaN           NaN      NaN          NaN
# 3          1.0                17.0       11947.0     60.0          2.0
# 4          1.0                 7.0       22953.0     60.0          3.0
#
#    open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  total_cu_tl  \
# 0          0.0         0.0      59.0            2400.0     1.0          0.0
# 1          1.0      2137.0      67.0           35200.0     0.0          7.0
# 2          NaN         NaN       NaN           11400.0     NaN          NaN
# 3          3.0      2223.0      25.0           54500.0     2.0          0.0
# 4          4.0      3907.0      43.0           43900.0     1.0          0.0
#
#    inq_last_12m  acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  bc_util  \
# 0           0.0                   1.0      64756.0             NaN      NaN
# 1           0.0                   4.0       6182.0          7741.0     40.5
# 2           NaN                   4.0      22733.0          4521.0     54.8
# 3           2.0                   4.0       6973.0         43140.0     12.0
# 4           2.0                   5.0       5641.0         17318.0     39.9
#
#    chargeoff_within_12_mths  delinq_amnt  mo_sin_old_il_acct  \
# 0                       0.0          0.0               179.0
# 1                       0.0          0.0               145.0
# 2                       0.0          0.0                57.0
# 3                       0.0          0.0                37.0
# 4                       0.0          0.0                72.0
#
#    mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  \
# 0                  75.0                   38.0            16.0       2.0
# 1                 137.0                    7.0             7.0       0.0
# 2                  57.0                   14.0             9.0       1.0
# 3                 132.0                    1.0             1.0       2.0
# 4                 117.0                    6.0             6.0       2.0
#
#    mths_since_recent_bc  mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 0                   NaN                      19.0                   16.0
# 1                   7.0                       NaN                   24.0
# 2                  14.0                       NaN                    1.0
# 3                   1.0                       NaN                    3.0
# 4                   6.0                       NaN                    5.0
#
#    mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 0                            19.0                    1.0             0.0
# 1                             NaN                    0.0             3.0
# 2                             NaN                    0.0             3.0
# 3                             NaN                    1.0             6.0
# 4                             NaN                    0.0             4.0
#
#    num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 0              2.0          0.0        1.0        5.0            2.0
# 1              5.0          5.0        6.0       15.0            7.0
# 2              5.0          3.0        3.0        2.0            5.0
# 3              7.0         11.0       16.0        2.0           13.0
# 4              5.0          5.0        6.0        5.0           13.0
#
#    num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 0            5.0                  2.0       4.0               0.0
# 1            9.0                  5.0      10.0               0.0
# 2            6.0                  5.0       7.0               0.0
# 3           19.0                  7.0      15.0               0.0
# 4           16.0                  5.0      16.0               0.0
#
#    num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 0           0.0                 0.0                 0.0            75.0
# 1           0.0                 0.0                 1.0            95.8
# 2           0.0                 0.0                 1.0           100.0
# 3           0.0                 0.0                 2.0            95.7
# 4           0.0                 0.0                 4.0           100.0
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0               NaN                   1.0        0.0         395328.0
# 1              60.0                   0.0        0.0          88154.0
# 2              33.3                   0.0        1.0         171118.0
# 3               0.0                   0.0        0.0         202606.0
# 4               0.0                   0.0        0.0         152081.0
#
#    total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0            11948.0             0.0                     17928.0
# 1            61815.0         13000.0                     52954.0
# 2            13124.0         10000.0                      7526.0
# 3            18520.0         49000.0                     20000.0
# 4            34847.0         28800.0                     38181.0
#
#    revol_bal_joint  sec_app_fico_range_low  sec_app_fico_range_high  \
# 0              NaN                     NaN                      NaN
# 1              NaN                     NaN                      NaN
# 2              NaN                     NaN                      NaN
# 3              NaN                     NaN                      NaN
# 4              NaN                     NaN                      NaN
#
#   sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# 0                      NaN                     NaN               NaN
# 1                      NaN                     NaN               NaN
# 2                      NaN                     NaN               NaN
# 3                      NaN                     NaN               NaN
# 4                      NaN                     NaN               NaN
#
#    sec_app_open_acc  sec_app_revol_util  sec_app_open_act_il  \
# 0               NaN                 NaN                  NaN
# 1               NaN                 NaN                  NaN
# 2               NaN                 NaN                  NaN
# 3               NaN                 NaN                  NaN
# 4               NaN                 NaN                  NaN
#
#    sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# 0                    NaN                               NaN
# 1                    NaN                               NaN
# 2                    NaN                               NaN
# 3                    NaN                               NaN
# 4                    NaN                               NaN
#
#    sec_app_collections_12_mths_ex_med hardship_flag hardship_type  \
# 0                                 NaN             N           NaN
# 1                                 NaN             N           NaN
# 2                                 NaN             N           NaN
# 3                                 NaN             N           NaN
# 4                                 NaN             N           NaN
#
#   hardship_reason hardship_status  deferral_term  hardship_amount  \
# 0             NaN             NaN            NaN              NaN
# 1             NaN             NaN            NaN              NaN
# 2             NaN             NaN            NaN              NaN
# 3             NaN             NaN            NaN              NaN
# 4             NaN             NaN            NaN              NaN
#
#   hardship_start_date hardship_end_date payment_plan_start_date  \
# 0                 NaN               NaN                     NaN
# 1                 NaN               NaN                     NaN
# 2                 NaN               NaN                     NaN
# 3                 NaN               NaN                     NaN
# 4                 NaN               NaN                     NaN
#
#    hardship_length  hardship_dpd hardship_loan_status  \
# 0              NaN           NaN                  NaN
# 1              NaN           NaN                  NaN
# 2              NaN           NaN                  NaN
# 3              NaN           NaN                  NaN
# 4              NaN           NaN                  NaN
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                         NaN                             NaN
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
#
#    hardship_last_payment_amount debt_settlement_flag
# 0                           NaN                    N
# 1                           NaN                    N
# 2                           NaN                    N
# 3                           NaN                    N
# 4                           NaN                    N

# %%
# Load dictionary
lc_dict = catalog.load("lc_dataset_dictionary")
lc_dict
# Out:
# [10/29/24 00:33:34] INFO     Loading data from lc_dataset_dictionary (ExcelDataset)...          ]8;id=876743;file:///Users/andrejcemeris/anaconda3/envs/kedro_env/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=90829;file:///Users/andrejcemeris/anaconda3/envs/kedro_env/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                     LoanStatNew  \
# 0                                acc_now_delinq
# 1                          acc_open_past_24mths
# 2                                    addr_state
# 3                                      all_util
# 4                                    annual_inc
# 5                              annual_inc_joint
# 6                              application_type
# 7                                   avg_cur_bal
# 8                                bc_open_to_buy
# 9                                       bc_util
# 10                     chargeoff_within_12_mths
# 11                      collection_recovery_fee
# 12                   collections_12_mths_ex_med
# 13                         debt_settlement_flag
# 14                    debt_settlement_flag_date
# 15                                deferral_term
# 16                                  delinq_2yrs
# 17                                  delinq_amnt
# 18                                         desc
# 19                          disbursement_method
# 20                                          dti
# 21                                    dti_joint
# 22                             earliest_cr_line
# 23                                   emp_length
# 24                                    emp_title
# 25                              fico_range_high
# 26                               fico_range_low
# 27                                  funded_amnt
# 28                              funded_amnt_inv
# 29                                        grade
# 30                              hardship_amount
# 31                                 hardship_dpd
# 32                            hardship_end_date
# 33                                hardship_flag
# 34                 hardship_last_payment_amount
# 35                              hardship_length
# 36                         hardship_loan_status
# 37               hardship_payoff_balance_amount
# 38                              hardship_reason
# 39                          hardship_start_date
# 40                              hardship_status
# 41                                hardship_type
# 42                               home_ownership
# 43                                           id
# 44                                      il_util
# 45                          initial_list_status
# 46                                       inq_fi
# 47                                 inq_last_12m
# 48                               inq_last_6mths
# 49                                  installment
# 50                                     int_rate
# 51                                      issue_d
# 52                           last_credit_pull_d
# 53                         last_fico_range_high
# 54                          last_fico_range_low
# 55                              last_pymnt_amnt
# 56                                 last_pymnt_d
# 57                                    loan_amnt
# 58                                  loan_status
# 59                                   max_bal_bc
# 60                                    member_id
# 61                           mo_sin_old_il_acct
# 62                         mo_sin_old_rev_tl_op
# 63                        mo_sin_rcnt_rev_tl_op
# 64                               mo_sin_rcnt_tl
# 65                                     mort_acc
# 66                       mths_since_last_delinq
# 67                  mths_since_last_major_derog
# 68                       mths_since_last_record
# 69                           mths_since_rcnt_il
# 70                         mths_since_recent_bc
# 71                     mths_since_recent_bc_dlq
# 72                        mths_since_recent_inq
# 73               mths_since_recent_revol_delinq
# 74                                 next_pymnt_d
# 75                        num_accts_ever_120_pd
# 76                               num_actv_bc_tl
# 77                              num_actv_rev_tl
# 78                                  num_bc_sats
# 79                                    num_bc_tl
# 80                                    num_il_tl
# 81                                num_op_rev_tl
# 82                                num_rev_accts
# 83                          num_rev_tl_bal_gt_0
# 84                                     num_sats
# 85                             num_tl_120dpd_2m
# 86                                 num_tl_30dpd
# 87                           num_tl_90g_dpd_24m
# 88                           num_tl_op_past_12m
# 89                                     open_acc
# 90                                  open_acc_6m
# 91                                  open_act_il
# 92                                  open_il_12m
# 93                                  open_il_24m
# 94                                  open_rv_12m
# 95                                  open_rv_24m
# 96   orig_projected_additional_accrued_interest
# 97                                    out_prncp
# 98                                out_prncp_inv
# 99                      payment_plan_start_date
# 100                              pct_tl_nvr_dlq
# 101                            percent_bc_gt_75
# 102                                 policy_code
# 103                                     pub_rec
# 104                        pub_rec_bankruptcies
# 105                                     purpose
# 106                                  pymnt_plan
# 107                                  recoveries
# 108                                   revol_bal
# 109                            revol_bal_joint
# 110                                  revol_util
# 111           sec_app_chargeoff_within_12_mths
# 112         sec_app_collections_12_mths_ex_med
# 113                   sec_app_earliest_cr_line
# 114                    sec_app_fico_range_high
# 115                     sec_app_fico_range_low
# 116                     sec_app_inq_last_6mths
# 117                           sec_app_mort_acc
# 118        sec_app_mths_since_last_major_derog
# 119                      sec_app_num_rev_accts
# 120                           sec_app_open_acc
# 121                         sec_app_open_act_il
# 122                         sec_app_revol_util
# 123                           settlement_amount
# 124                             settlement_date
# 125                       settlement_percentage
# 126                           settlement_status
# 127                             settlement_term
# 128                                   sub_grade
# 129                                   tax_liens
# 130                                        term
# 131                                       title
# 132                                tot_coll_amt
# 133                                 tot_cur_bal
# 134                             tot_hi_cred_lim
# 135                                   total_acc
# 136                           total_bal_ex_mort
# 137                                total_bal_il
# 138                              total_bc_limit
# 139                                 total_cu_tl
# 140                  total_il_high_credit_limit
# 141                                 total_pymnt
# 142                             total_pymnt_inv
# 143                               total_rec_int
# 144                          total_rec_late_fee
# 145                             total_rec_prncp
# 146                          total_rev_hi_lim
# 147                                         url
# 148                         verification_status
# 149                       verified_status_joint
# 150                                    zip_code
# 151                                         NaN
# 152                                         NaN
#
#                                            Description
# 0    The number of accounts on which the borrower i...
# 1           Number of trades opened in past 24 months.
# 2    The state provided by the borrower in the loan...
# 3                Balance to credit limit on all trades
# 4    The self-reported annual income provided by th...
# 5    The combined self-reported annual income provi...
# 6    Indicates whether the loan is an individual ap...
# 7              Average current balance of all accounts
# 8            Total open to buy on revolving bankcards.
# 9    Ratio of total current balance to high credit/...
# 10              Number of charge-offs within 12 months
# 11                      post charge off collection fee
# 12   Number of collections in 12 months excluding m...
# 13   Flags whether or not the borrower, who has cha...
# 14   The most recent date that the Debt_Settlement_...
# 15   Amount of months that the borrower is expected...
# 16   The number of 30+ days past-due incidences of ...
# 17   The past-due amount owed for the accounts on w...
# 18           Loan description provided by the borrower
# 19   The method by which the borrower receives thei...
# 20   A ratio calculated using the borrower’s total ...
# 21   A ratio calculated using the co-borrowers' tot...
# 22   The month the borrower's earliest reported cre...
# 23   Employment length in years. Possible values ar...
# 24   The job title supplied by the Borrower when ap...
# 25   The upper boundary range the borrower’s FICO a...
# 26   The lower boundary range the borrower’s FICO a...
# 27   The total amount committed to that loan at tha...
# 28   The total amount committed by investors for th...
# 29                              LC assigned loan grade
# 30   The interest payment that the borrower has com...
# 31   Account days past due as of the hardship plan ...
# 32            The end date of the hardship plan period
# 33   Flags whether or not the borrower is on a hard...
# 34   The last payment amount as of the hardship pla...
# 35   The number of months the borrower will make sm...
# 36      Loan Status as of the hardship plan start date
# 37   The payoff balance amount as of the hardship p...
# 38   Describes the reason the hardship plan was off...
# 39          The start date of the hardship plan period
# 40   Describes if the hardship plan is active, pend...
# 41                Describes the hardship plan offering
# 42   The home ownership status provided by the borr...
# 43       A unique LC assigned ID for the loan listing.
# 44   Ratio of total current balance to high credit/...
# 45   The initial listing status of the loan. Possib...
# 46                Number of personal finance inquiries
# 47        Number of credit inquiries in past 12 months
# 48   The number of inquiries in past 6 months (excl...
# 49   The monthly payment owed by the borrower if th...
# 50                           Interest Rate on the loan
# 51                 The month which the loan was funded
# 52   The most recent month LC pulled credit for thi...
# 53   The upper boundary range the borrower’s last F...
# 54   The lower boundary range the borrower’s last F...
# 55                  Last total payment amount received
# 56                     Last month payment was received
# 57   The listed amount of the loan applied for by t...
# 58                          Current status of the loan
# 59   Maximum current balance owed on all revolving ...
# 60    A unique LC assigned Id for the borrower member.
# 61   Months since oldest bank installment account o...
# 62        Months since oldest revolving account opened
# 63   Months since most recent revolving account opened
# 64             Months since most recent account opened
# 65                        Number of mortgage accounts.
# 66   The number of months since the borrower's last...
# 67     Months since most recent 90-day or worse rating
# 68   The number of months since the last public rec...
# 69   Months since most recent installment accounts ...
# 70   Months since most recent bankcard account opened.
# 71       Months since most recent bankcard delinquency
# 72                   Months since most recent inquiry.
# 73     Months since most recent revolving delinquency.
# 74                         Next scheduled payment date
# 75   Number of accounts ever 120 or more days past due
# 76        Number of currently active bankcard accounts
# 77         Number of currently active revolving trades
# 78            Number of satisfactory bankcard accounts
# 79                         Number of bankcard accounts
# 80                      Number of installment accounts
# 81                   Number of open revolving accounts
# 82                        Number of revolving accounts
# 83          Number of revolving trades with balance >0
# 84                     Number of satisfactory accounts
# 85   Number of accounts currently 120 days past due...
# 86   Number of accounts currently 30 days past due ...
# 87   Number of accounts 90 or more days past due in...
# 88         Number of accounts opened in past 12 months
# 89   The number of open credit lines in the borrowe...
# 90              Number of open trades in last 6 months
# 91       Number of currently active installment trades
# 92   Number of installment accounts opened in past ...
# 93   Number of installment accounts opened in past ...
# 94   Number of revolving trades opened in past 12 m...
# 95   Number of revolving trades opened in past 24 m...
# 96   The original projected additional interest amo...
# 97   Remaining outstanding principal for total amou...
# 98   Remaining outstanding principal for portion of...
# 99   The day the first hardship plan payment is due...
# 100                 Percent of trades never delinquent
# 101  Percentage of all bankcard accounts > 75% of l...
# 102  publicly available policy_code=1\nnew products...
# 103                Number of derogatory public records
# 104               Number of public record bankruptcies
# 105  A category provided by the borrower for the lo...
# 106  Indicates if a payment plan has been put in pl...
# 107                     post charge off gross recovery
# 108                     Total credit revolving balance
# 109   Sum of revolving credit balance of the co-bor...
# 110  Revolving line utilization rate, or the amount...
# 111   Number of charge-offs within last 12 months a...
# 112   Number of collections within last 12 months e...
# 113   Earliest credit line at time of application f...
# 114       FICO range (low) for the secondary applicant
# 115      FICO range (high) for the secondary applicant
# 116   Credit inquiries in the last 6 months at time...
# 117   Number of mortgage accounts at time of applic...
# 118   Months since most recent 90-day or worse rati...
# 119   Number of revolving accounts at time of appli...
# 120   Number of open trades at time of application ...
# 121   Number of currently active installment trades...
# 122   Ratio of total current balance to high credit...
# 123  The loan amount that the borrower has agreed t...
# 124  The date that the borrower agrees to the settl...
# 125  The settlement amount as a percentage of the p...
# 126  The status of the borrower’s settlement plan. ...
# 127  The number of months that the borrower will be...
# 128                          LC assigned loan subgrade
# 129                                Number of tax liens
# 130  The number of payments on the loan. Values are...
# 131            The loan title provided by the borrower
# 132                 Total collection amounts ever owed
# 133              Total current balance of all accounts
# 134                     Total high credit/credit limit
# 135  The total number of credit lines currently in ...
# 136            Total credit balance excluding mortgage
# 137  Total current balance of all installment accounts
# 138            Total bankcard high credit/credit limit
# 139                           Number of finance trades
# 140         Total installment high credit/credit limit
# 141  Payments received to date for total amount funded
# 142  Payments received to date for portion of total...
# 143                          Interest received to date
# 144                         Late fees received to date
# 145                         Principal received to date
# 146           Total revolving high credit/credit limit
# 147             URL for the LC page with listing data.
# 148  Indicates if income was verified by LC, not ve...
# 149  Indicates if the co-borrowers' joint income wa...
# 150  The first 3 numbers of the zip code provided b...
# 151                                                NaN
# 152  * Employer Title replaces Employer Name for al...

# %%
lending_club.select_dtypes(object).head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#          term int_rate grade sub_grade       emp_title emp_length  \
# 0   36 months   13.08%     B        B5         cashier  10+ years
# 1   60 months    9.16%     B        B2             ABM    6 years
# 2   36 months   10.49%     B        B3          driver  10+ years
# 3   60 months   11.05%     B        B4             NaN        NaN
# 4   60 months   13.59%     C        C2  Shipping Clerk  10+ years
#
#   home_ownership verification_status   issue_d loan_status pymnt_plan  \
# 0       MORTGAGE     Source Verified  Mar-2020     Current          n
# 1           RENT     Source Verified  Feb-2016     Current          n
# 2       MORTGAGE        Not Verified  Jan-2015  Fully Paid          n
# 3       MORTGAGE        Not Verified  Jun-2018     Current          n
# 4       MORTGAGE     Source Verified  Jan-2018  Fully Paid          n
#
#                                                  url             purpose  \
# 0  https://lendingclub.com/browse/loanDetail.acti...    home_improvement
# 1  https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 2  https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 3  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 4  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
#
#                      title zip_code addr_state earliest_cr_line revol_util  \
# 0         Home improvement    115xx         NY         Dec-2004      82.8%
# 1  Credit card refinancing    708xx         LA         Jan-2004      64.5%
# 2  Credit card refinancing    347xx         FL         Apr-2010      52.6%
# 3       Debt consolidation    443xx         OH         Oct-2005      12.1%
# 4       Debt consolidation    681xx         NE         Apr-2008      27.1%
#
#   initial_list_status last_pymnt_d next_pymnt_d last_credit_pull_d  \
# 0                   w     May-2020     Jun-2020           May-2020
# 1                   w     May-2020     Jun-2020           May-2020
# 2                   f     Jan-2018          NaN           May-2020
# 3                   w     May-2020     Jun-2020           May-2020
# 4                   w     Jul-2019          NaN           Feb-2020
#
#   application_type verification_status_joint sec_app_earliest_cr_line  \
# 0       Individual                       NaN                      NaN
# 1       Individual                       NaN                      NaN
# 2       Individual                       NaN                      NaN
# 3       Individual                       NaN                      NaN
# 4       Individual                       NaN                      NaN
#
#   hardship_flag hardship_type hardship_reason hardship_status  \
# 0             N           NaN             NaN             NaN
# 1             N           NaN             NaN             NaN
# 2             N           NaN             NaN             NaN
# 3             N           NaN             NaN             NaN
# 4             N           NaN             NaN             NaN
#
#   hardship_start_date hardship_end_date payment_plan_start_date  \
# 0                 NaN               NaN                     NaN
# 1                 NaN               NaN                     NaN
# 2                 NaN               NaN                     NaN
# 3                 NaN               NaN                     NaN
# 4                 NaN               NaN                     NaN
#
#   hardship_loan_status debt_settlement_flag
# 0                  NaN                    N
# 1                  NaN                    N
# 2                  NaN                    N
# 3                  NaN                    N
# 4                  NaN                    N

# %%
# Check some features if they are boolean
bool_list = ['pymnt_plan', 'hardship_flag', 'debt_settlement_flag', 'verification_status', 'verification_status_joint', ]
for x in bool_list:
    print(lending_club[x].value_counts())
    print("")
# Out:
# pymnt_plan
# n    100000
# Name: count, dtype: int64
#
# hardship_flag
# N    94507
# Y     4166
# Name: count, dtype: int64
#
# debt_settlement_flag
# N    98244
# Y     1756
# Name: count, dtype: int64
#
# verification_status
# Source Verified    38932
# Not Verified       36467
# Verified           24601
# Name: count, dtype: int64
#
# verification_status_joint
# Not Verified       3350
# Source Verified    1934
# Verified           1347
# Name: count, dtype: int64

# %%
# Define functions to parse different kind of values to numbers
def _parse_pct(x: pd.Series) -> pd.Series:
    return x.str.replace("%", "").astype(float)

def _parse_term(x: pd.Series) -> pd.Series:
    return x.str.replace(" months", "").astype(int)

def _parse_date(x: pd.Series) -> pd.Series:
    return pd.to_datetime(x, format="%b-%Y")

def _parse_bool(x: pd.Series) -> pd.Series:
    return x.where(x.isna(), x=="Y")

# Make a list of percentage features, formatted as string
pct_list = ['int_rate', 'revol_util']

# Make a list of columns that contains dates in text format
date_list = ['issue_d', 'earliest_cr_line', 'last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d',
             'sec_app_earliest_cr_line', 'hardship_start_date', 'hardship_end_date', 'payment_plan_start_date']

# Make a list of boolean features
bool_list = ['pymnt_plan', 'hardship_flag', 'debt_settlement_flag']

# Check functions output
print(f"Parse percentage:\n{_parse_pct(lending_club.int_rate.head())}\n")
print(f"Parse term:\n{_parse_term(lending_club.term.head())}\n")
print(f"Parse date:\n{_parse_date(lending_club.issue_d.head())}\n")
print(f"Parse bool:\n{pd.concat([lending_club.hardship_flag.head(15),_parse_bool(lending_club.hardship_flag.head(15))], axis=1)}\n")
# Out:
# Parse percentage:
# 0    13.08
# 1     9.16
# 2    10.49
# 3    11.05
# 4    13.59
# Name: int_rate, dtype: float64
#
# Parse term:
# 0    36
# 1    60
# 2    36
# 3    60
# 4    60
# Name: term, dtype: int64
#
# Parse date:
# 0   2020-03-01
# 1   2016-02-01
# 2   2015-01-01
# 3   2018-06-01
# 4   2018-01-01
# Name: issue_d, dtype: datetime64[ns]
#
# Parse bool:
#    hardship_flag hardship_flag
# 0              N         False
# 1              N         False
# 2              N         False
# 3              N         False
# 4              N         False
# 5              N         False
# 6              N         False
# 7              N         False
# 8              Y          True
# 9              N         False
# 10           NaN           NaN
# 11             N         False
# 12             N         False
# 13             N         False
# 14             N         False

# %% [markdown]
# Functions defined above where used in `data_processing` pipeline (see `src/lending_club/pipelines/data_processing/nodes.py` and `src/lending_club/pipelines/data_processing/pipeline.py`) to process raw dataset and save into intermediate dataset with proper data types in `.parquet` format.
#
# Run this pipeline with command:
# >  kedro run -p data_processing
