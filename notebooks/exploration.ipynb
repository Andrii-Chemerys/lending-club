# %% [markdown]
# # INFO
#
# This notebook will be used for construction data processing nodes and exploration purposes within Kedro framework.

# %%
############################################################################
# It is recomended to create new vitual environment for each Kedro project #
############################################################################

# Uncomment and run the line below if your environment does't have 
# Kedro or any other dependencies needed. 

#! pip install -r requirements.txt

# %%
# Load Kedro extention
# %load_ext kedro.ipython
# Out:
# [10/29/24 13:52:34] INFO     Using 'd:\Program Files\Python\Python                                  __init__.py:270
#                              Venv\PowerBI\Lib\site-packages\kedro\framework\project\rich_logging.ym
#                              l' as logging configuration.
#                     INFO     Registered line magic '%reload_kedro'                                   __init__.py:61
#                     INFO     Registered line magic '%load_node'                                      __init__.py:63
#                     INFO     Resolved project path as: c:\Users\chemerys\Downloads\lending-club.    __init__.py:178
#                              To set a different path, run '%reload_kedro <project_root>'
#                     WARNING  d:\Program Files\Python\Python                                         warnings.py:110
#                              Venv\PowerBI\Lib\site-packages\kedro_viz\__init__.py:13:
#                              KedroVizPythonVersionWarning: Please be advised that Kedro Viz is not
#                              yet fully
#                                      compatible with the Python version you are currently using.
#                                warnings.warn(
# [10/29/24 13:52:40] INFO     Kedro is sending anonymous usage data with the sole purpose of improving plugin.py:233
#                              the product. No personal data or IP addresses are stored on our side. If
#                              you want to opt out, set the `KEDRO_DISABLE_TELEMETRY` or `DO_NOT_TRACK`
#                              environment variables, or create a `.telemetry` file in the current
#                              working directory with the contents `consent: false`. Read more at
#                              https://docs.kedro.org/en/stable/configuration/telemetry.html
#                     DEBUG    Failed to send data to Heap. Exception of type 'SSLError' was raised.    plugin.py:341
#                     INFO     Kedro project lending_club                                             __init__.py:144
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            __init__.py:145
#                              'pipelines'
# [10/29/24 13:52:42] INFO     Registered line magic 'run_viz'                                        __init__.py:151

# %% [markdown]
# # Data processing
# ---

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('max_colwidth', 500)

# Load Lending Club dataset defined as 'original_lc_dataset' in catalog.yml
lending_club = catalog.load("original_lc_dataset")
lending_club.head()
# Out:
# [10/29/24 13:53:12] INFO     Loading data from original_lc_dataset (CSVDataset)...              data_catalog.py:389
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#    Unnamed: 0.1  Unnamed: 0         id  loan_amnt  funded_amnt  \
# 0       1746494       25450  167338079     4000.0       4000.0
# 1       2370717       81861   71016917    24000.0      24000.0
# 2       2264870      397109   39589826     5000.0       5000.0
# 3        595422       15492  134798709    24000.0      24000.0
# 4        562657       90591  127097355    14000.0      14000.0
#
#    funded_amnt_inv        term int_rate  installment grade sub_grade  \
# 0           4000.0   36 months   13.08%       134.93     B        B5
# 1          24000.0   60 months    9.16%       500.07     B        B2
# 2           5000.0   36 months   10.49%       162.49     B        B3
# 3          24000.0   60 months   11.05%       522.42     B        B4
# 4          14000.0   60 months   13.59%       322.79     C        C2
#
#         emp_title emp_length home_ownership  annual_inc verification_status  \
# 0         cashier  10+ years       MORTGAGE     48000.0     Source Verified
# 1             ABM    6 years           RENT     57000.0     Source Verified
# 2          driver  10+ years       MORTGAGE     55000.0        Not Verified
# 3             NaN        NaN       MORTGAGE     43500.0        Not Verified
# 4  Shipping Clerk  10+ years       MORTGAGE     48000.0     Source Verified
#
#     issue_d loan_status pymnt_plan  \
# 0  Mar-2020     Current          n
# 1  Feb-2016     Current          n
# 2  Jan-2015  Fully Paid          n
# 3  Jun-2018     Current          n
# 4  Jan-2018  Fully Paid          n
#
#                                                                   url  \
# 0  https://lendingclub.com/browse/loanDetail.action?loan_id=167338079
# 1   https://lendingclub.com/browse/loanDetail.action?loan_id=71016917
# 2   https://lendingclub.com/browse/loanDetail.action?loan_id=39589826
# 3  https://lendingclub.com/browse/loanDetail.action?loan_id=134798709
# 4  https://lendingclub.com/browse/loanDetail.action?loan_id=127097355
#
#               purpose                    title zip_code addr_state    dti  \
# 0    home_improvement         Home improvement    115xx         NY  20.25
# 1         credit_card  Credit card refinancing    708xx         LA  25.33
# 2         credit_card  Credit card refinancing    347xx         FL   7.22
# 3  debt_consolidation       Debt consolidation    443xx         OH  24.55
# 4  debt_consolidation       Debt consolidation    681xx         NE  24.30
#
#    delinq_2yrs earliest_cr_line  fico_range_low  fico_range_high  \
# 0          1.0         Dec-2004           665.0            669.0
# 1          0.0         Jan-2004           680.0            684.0
# 2          0.0         Apr-2010           665.0            669.0
# 3          0.0         Oct-2005           750.0            754.0
# 4          0.0         Apr-2008           735.0            739.0
#
#    inq_last_6mths  mths_since_last_delinq  mths_since_last_record  open_acc  \
# 0             0.0                    19.0                   110.0       4.0
# 1             0.0                     NaN                     NaN      10.0
# 2             0.0                     NaN                    61.0       7.0
# 3             0.0                     NaN                     NaN      15.0
# 4             1.0                     NaN                     NaN      16.0
#
#    pub_rec  revol_bal revol_util  total_acc initial_list_status  out_prncp  \
# 0      1.0     1988.0      82.8%       12.0                   w    3816.34
# 1      0.0    22697.0      64.5%       24.0                   w    4333.29
# 2      1.0     6001.0      52.6%        9.0                   f       0.00
# 3      0.0     6573.0      12.1%       23.0                   w   16317.69
# 4      0.0    11894.0      27.1%       23.0                   w       0.00
#
#    out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 0        3816.34    266.950000           266.95           183.66
# 1        4333.29  25496.160000         25496.16         19666.71
# 2           0.00   5846.672836          5846.67          5000.00
# 3       16317.69  12000.930000         12000.93          7682.31
# 4           0.00  16605.680000         16605.68         14000.00
#
#    total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee  \
# 0          83.29                 0.0         0.0                      0.0
# 1        5829.45                 0.0         0.0                      0.0
# 2         846.67                 0.0         0.0                      0.0
# 3        4318.62                 0.0         0.0                      0.0
# 4        2605.68                 0.0         0.0                      0.0
#
#   last_pymnt_d  last_pymnt_amnt next_pymnt_d last_credit_pull_d  \
# 0     May-2020           134.93     Jun-2020           May-2020
# 1     May-2020           500.07     Jun-2020           May-2020
# 2     Jan-2018           162.43          NaN           May-2020
# 3     May-2020           522.42     Jun-2020           May-2020
# 4     Jul-2019         11128.82          NaN           Feb-2020
#
#    last_fico_range_high  last_fico_range_low  collections_12_mths_ex_med  \
# 0                 669.0                665.0                         1.0
# 1                 704.0                700.0                         0.0
# 2                 789.0                785.0                         0.0
# 3                 749.0                745.0                         0.0
# 4                 779.0                775.0                         0.0
#
#    mths_since_last_major_derog  policy_code application_type  \
# 0                          NaN          1.0       Individual
# 1                          NaN          1.0       Individual
# 2                          NaN          1.0       Individual
# 3                          NaN          1.0       Individual
# 4                          NaN          1.0       Individual
#
#    annual_inc_joint  dti_joint verification_status_joint  acc_now_delinq  \
# 0               NaN        NaN                       NaN             0.0
# 1               NaN        NaN                       NaN             0.0
# 2               NaN        NaN                       NaN             0.0
# 3               NaN        NaN                       NaN             0.0
# 4               NaN        NaN                       NaN             0.0
#
#    tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  open_il_12m  \
# 0        3832.0     259024.0          0.0          1.0          0.0
# 1           0.0      61815.0          0.0          3.0          0.0
# 2           0.0     159131.0          NaN          NaN          NaN
# 3           0.0     104590.0          2.0          1.0          0.0
# 4           0.0      90253.0          2.0          2.0          1.0
#
#    open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 0          1.0                16.0        9960.0     56.0          0.0
# 1          3.0                14.0       39118.0     72.0          1.0
# 2          NaN                 NaN           NaN      NaN          NaN
# 3          1.0                17.0       11947.0     60.0          2.0
# 4          1.0                 7.0       22953.0     60.0          3.0
#
#    open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  total_cu_tl  \
# 0          0.0         0.0      59.0            2400.0     1.0          0.0
# 1          1.0      2137.0      67.0           35200.0     0.0          7.0
# 2          NaN         NaN       NaN           11400.0     NaN          NaN
# 3          3.0      2223.0      25.0           54500.0     2.0          0.0
# 4          4.0      3907.0      43.0           43900.0     1.0          0.0
#
#    inq_last_12m  acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  bc_util  \
# 0           0.0                   1.0      64756.0             NaN      NaN
# 1           0.0                   4.0       6182.0          7741.0     40.5
# 2           NaN                   4.0      22733.0          4521.0     54.8
# 3           2.0                   4.0       6973.0         43140.0     12.0
# 4           2.0                   5.0       5641.0         17318.0     39.9
#
#    chargeoff_within_12_mths  delinq_amnt  mo_sin_old_il_acct  \
# 0                       0.0          0.0               179.0
# 1                       0.0          0.0               145.0
# 2                       0.0          0.0                57.0
# 3                       0.0          0.0                37.0
# 4                       0.0          0.0                72.0
#
#    mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  \
# 0                  75.0                   38.0            16.0       2.0
# 1                 137.0                    7.0             7.0       0.0
# 2                  57.0                   14.0             9.0       1.0
# 3                 132.0                    1.0             1.0       2.0
# 4                 117.0                    6.0             6.0       2.0
#
#    mths_since_recent_bc  mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 0                   NaN                      19.0                   16.0
# 1                   7.0                       NaN                   24.0
# 2                  14.0                       NaN                    1.0
# 3                   1.0                       NaN                    3.0
# 4                   6.0                       NaN                    5.0
#
#    mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 0                            19.0                    1.0             0.0
# 1                             NaN                    0.0             3.0
# 2                             NaN                    0.0             3.0
# 3                             NaN                    1.0             6.0
# 4                             NaN                    0.0             4.0
#
#    num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 0              2.0          0.0        1.0        5.0            2.0
# 1              5.0          5.0        6.0       15.0            7.0
# 2              5.0          3.0        3.0        2.0            5.0
# 3              7.0         11.0       16.0        2.0           13.0
# 4              5.0          5.0        6.0        5.0           13.0
#
#    num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 0            5.0                  2.0       4.0               0.0
# 1            9.0                  5.0      10.0               0.0
# 2            6.0                  5.0       7.0               0.0
# 3           19.0                  7.0      15.0               0.0
# 4           16.0                  5.0      16.0               0.0
#
#    num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 0           0.0                 0.0                 0.0            75.0
# 1           0.0                 0.0                 1.0            95.8
# 2           0.0                 0.0                 1.0           100.0
# 3           0.0                 0.0                 2.0            95.7
# 4           0.0                 0.0                 4.0           100.0
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0               NaN                   1.0        0.0         395328.0
# 1              60.0                   0.0        0.0          88154.0
# 2              33.3                   0.0        1.0         171118.0
# 3               0.0                   0.0        0.0         202606.0
# 4               0.0                   0.0        0.0         152081.0
#
#    total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0            11948.0             0.0                     17928.0
# 1            61815.0         13000.0                     52954.0
# 2            13124.0         10000.0                      7526.0
# 3            18520.0         49000.0                     20000.0
# 4            34847.0         28800.0                     38181.0
#
#    revol_bal_joint  sec_app_fico_range_low  sec_app_fico_range_high  \
# 0              NaN                     NaN                      NaN
# 1              NaN                     NaN                      NaN
# 2              NaN                     NaN                      NaN
# 3              NaN                     NaN                      NaN
# 4              NaN                     NaN                      NaN
#
#   sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# 0                      NaN                     NaN               NaN
# 1                      NaN                     NaN               NaN
# 2                      NaN                     NaN               NaN
# 3                      NaN                     NaN               NaN
# 4                      NaN                     NaN               NaN
#
#    sec_app_open_acc  sec_app_revol_util  sec_app_open_act_il  \
# 0               NaN                 NaN                  NaN
# 1               NaN                 NaN                  NaN
# 2               NaN                 NaN                  NaN
# 3               NaN                 NaN                  NaN
# 4               NaN                 NaN                  NaN
#
#    sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# 0                    NaN                               NaN
# 1                    NaN                               NaN
# 2                    NaN                               NaN
# 3                    NaN                               NaN
# 4                    NaN                               NaN
#
#    sec_app_collections_12_mths_ex_med hardship_flag hardship_type  \
# 0                                 NaN             N           NaN
# 1                                 NaN             N           NaN
# 2                                 NaN             N           NaN
# 3                                 NaN             N           NaN
# 4                                 NaN             N           NaN
#
#   hardship_reason hardship_status  deferral_term  hardship_amount  \
# 0             NaN             NaN            NaN              NaN
# 1             NaN             NaN            NaN              NaN
# 2             NaN             NaN            NaN              NaN
# 3             NaN             NaN            NaN              NaN
# 4             NaN             NaN            NaN              NaN
#
#   hardship_start_date hardship_end_date payment_plan_start_date  \
# 0                 NaN               NaN                     NaN
# 1                 NaN               NaN                     NaN
# 2                 NaN               NaN                     NaN
# 3                 NaN               NaN                     NaN
# 4                 NaN               NaN                     NaN
#
#    hardship_length  hardship_dpd hardship_loan_status  \
# 0              NaN           NaN                  NaN
# 1              NaN           NaN                  NaN
# 2              NaN           NaN                  NaN
# 3              NaN           NaN                  NaN
# 4              NaN           NaN                  NaN
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                         NaN                             NaN
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
#
#    hardship_last_payment_amount debt_settlement_flag
# 0                           NaN                    N
# 1                           NaN                    N
# 2                           NaN                    N
# 3                           NaN                    N
# 4                           NaN                    N

# %%
# Load Lending Club dataset defined as 'original_lc_dataset' in catalog.yml
lending_club = catalog.load("original_lc_dataset")
lending_club.head()

# %%
# Load dictionary
lc_dict = catalog.load("lc_dataset_dictionary")
lc_dict
# Out:
# [10/29/24 13:50:05] INFO     Loading data from lc_dataset_dictionary (ExcelDataset)...          data_catalog.py:389
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                     LoanStatNew  \
# 0                                acc_now_delinq
# 1                          acc_open_past_24mths
# 2                                    addr_state
# 3                                      all_util
# 4                                    annual_inc
# 5                              annual_inc_joint
# 6                              application_type
# 7                                   avg_cur_bal
# 8                                bc_open_to_buy
# 9                                       bc_util
# 10                     chargeoff_within_12_mths
# 11                      collection_recovery_fee
# 12                   collections_12_mths_ex_med
# 13                         debt_settlement_flag
# 14                    debt_settlement_flag_date
# 15                                deferral_term
# 16                                  delinq_2yrs
# 17                                  delinq_amnt
# 18                                         desc
# 19                          disbursement_method
# 20                                          dti
# 21                                    dti_joint
# 22                             earliest_cr_line
# 23                                   emp_length
# 24                                    emp_title
# 25                              fico_range_high
# 26                               fico_range_low
# 27                                  funded_amnt
# 28                              funded_amnt_inv
# 29                                        grade
# 30                              hardship_amount
# 31                                 hardship_dpd
# 32                            hardship_end_date
# 33                                hardship_flag
# 34                 hardship_last_payment_amount
# 35                              hardship_length
# 36                         hardship_loan_status
# 37               hardship_payoff_balance_amount
# 38                              hardship_reason
# 39                          hardship_start_date
# 40                              hardship_status
# 41                                hardship_type
# 42                               home_ownership
# 43                                           id
# 44                                      il_util
# 45                          initial_list_status
# 46                                       inq_fi
# 47                                 inq_last_12m
# 48                               inq_last_6mths
# 49                                  installment
# 50                                     int_rate
# 51                                      issue_d
# 52                           last_credit_pull_d
# 53                         last_fico_range_high
# 54                          last_fico_range_low
# 55                              last_pymnt_amnt
# 56                                 last_pymnt_d
# 57                                    loan_amnt
# 58                                  loan_status
# 59                                   max_bal_bc
# 60                                    member_id
# 61                           mo_sin_old_il_acct
# 62                         mo_sin_old_rev_tl_op
# 63                        mo_sin_rcnt_rev_tl_op
# 64                               mo_sin_rcnt_tl
# 65                                     mort_acc
# 66                       mths_since_last_delinq
# 67                  mths_since_last_major_derog
# 68                       mths_since_last_record
# 69                           mths_since_rcnt_il
# 70                         mths_since_recent_bc
# 71                     mths_since_recent_bc_dlq
# 72                        mths_since_recent_inq
# 73               mths_since_recent_revol_delinq
# 74                                 next_pymnt_d
# 75                        num_accts_ever_120_pd
# 76                               num_actv_bc_tl
# 77                              num_actv_rev_tl
# 78                                  num_bc_sats
# 79                                    num_bc_tl
# 80                                    num_il_tl
# 81                                num_op_rev_tl
# 82                                num_rev_accts
# 83                          num_rev_tl_bal_gt_0
# 84                                     num_sats
# 85                             num_tl_120dpd_2m
# 86                                 num_tl_30dpd
# 87                           num_tl_90g_dpd_24m
# 88                           num_tl_op_past_12m
# 89                                     open_acc
# 90                                  open_acc_6m
# 91                                  open_act_il
# 92                                  open_il_12m
# 93                                  open_il_24m
# 94                                  open_rv_12m
# 95                                  open_rv_24m
# 96   orig_projected_additional_accrued_interest
# 97                                    out_prncp
# 98                                out_prncp_inv
# 99                      payment_plan_start_date
# 100                              pct_tl_nvr_dlq
# 101                            percent_bc_gt_75
# 102                                 policy_code
# 103                                     pub_rec
# 104                        pub_rec_bankruptcies
# 105                                     purpose
# 106                                  pymnt_plan
# 107                                  recoveries
# 108                                   revol_bal
# 109                            revol_bal_joint
# 110                                  revol_util
# 111           sec_app_chargeoff_within_12_mths
# 112         sec_app_collections_12_mths_ex_med
# 113                   sec_app_earliest_cr_line
# 114                    sec_app_fico_range_high
# 115                     sec_app_fico_range_low
# 116                     sec_app_inq_last_6mths
# 117                           sec_app_mort_acc
# 118        sec_app_mths_since_last_major_derog
# 119                      sec_app_num_rev_accts
# 120                           sec_app_open_acc
# 121                         sec_app_open_act_il
# 122                         sec_app_revol_util
# 123                           settlement_amount
# 124                             settlement_date
# 125                       settlement_percentage
# 126                           settlement_status
# 127                             settlement_term
# 128                                   sub_grade
# 129                                   tax_liens
# 130                                        term
# 131                                       title
# 132                                tot_coll_amt
# 133                                 tot_cur_bal
# 134                             tot_hi_cred_lim
# 135                                   total_acc
# 136                           total_bal_ex_mort
# 137                                total_bal_il
# 138                              total_bc_limit
# 139                                 total_cu_tl
# 140                  total_il_high_credit_limit
# 141                                 total_pymnt
# 142                             total_pymnt_inv
# 143                               total_rec_int
# 144                          total_rec_late_fee
# 145                             total_rec_prncp
# 146                          total_rev_hi_lim
# 147                                         url
# 148                         verification_status
# 149                       verified_status_joint
# 150                                    zip_code
# 151                                         NaN
# 152                                         NaN
#
#                                                                                                                                                                                                                                    Description
# 0                                                                                                                                                                              The number of accounts on which the borrower is now delinquent.
# 1                                                                                                                                                                                                   Number of trades opened in past 24 months.
# 2                                                                                                                                                                                   The state provided by the borrower in the loan application
# 3                                                                                                                                                                                                        Balance to credit limit on all trades
# 4                                                                                                                                                                The self-reported annual income provided by the borrower during registration.
# 5                                                                                                                                                    The combined self-reported annual income provided by the co-borrowers during registration
# 6                                                                                                                                         Indicates whether the loan is an individual application or a joint application with two co-borrowers
# 7                                                                                                                                                                                                      Average current balance of all accounts
# 8                                                                                                                                                                                                    Total open to buy on revolving bankcards.
# 9                                                                                                                                                        Ratio of total current balance to high credit/credit limit for all bankcard accounts.
# 10                                                                                                                                                                                                      Number of charge-offs within 12 months
# 11                                                                                                                                                                                                              post charge off collection fee
# 12                                                                                                                                                                            Number of collections in 12 months excluding medical collections
# 13                                                                                                                                          Flags whether or not the borrower, who has charged-off, is working with a debt-settlement company.
# 14                                                                                                                                                                           The most recent date that the Debt_Settlement_Flag has been set
# 15                                                                                                               Amount of months that the borrower is expected to pay less than the contractual monthly payment amount due to a hardship plan
# 16                                                                                                                                The number of 30+ days past-due incidences of delinquency in the borrower's credit file for the past 2 years
# 17                                                                                                                                                          The past-due amount owed for the accounts on which the borrower is now delinquent.
# 18                                                                                                                                                                                                   Loan description provided by the borrower
# 19                                                                                                                                                 The method by which the borrower receives their loan. Possible values are: CASH, DIRECT_PAY
# 20                                    A ratio calculated using the borrower’s total monthly debt payments on the total debt obligations, excluding mortgage and the requested LC loan, divided by the borrower’s self-reported monthly income.
# 21                          A ratio calculated using the co-borrowers' total monthly payments on the total debt obligations, excluding mortgages and the requested LC loan, divided by the co-borrowers' combined self-reported monthly income
# 22                                                                                                                                                                           The month the borrower's earliest reported credit line was opened
# 23                                                                                                          Employment length in years. Possible values are between 0 and 10 where 0 means less than one year and 10 means ten or more years.
# 24                                                                                                                                                                         The job title supplied by the Borrower when applying for the loan.*
# 25                                                                                                                                                                The upper boundary range the borrower’s FICO at loan origination belongs to.
# 26                                                                                                                                                                The lower boundary range the borrower’s FICO at loan origination belongs to.
# 27                                                                                                                                                                              The total amount committed to that loan at that point in time.
# 28                                                                                                                                                                The total amount committed by investors for that loan at that point in time.
# 29                                                                                                                                                                                                                      LC assigned loan grade
# 30                                                                                                                                   The interest payment that the borrower has committed to make each month while they are on a hardship plan
# 31                                                                                                                                                                                    Account days past due as of the hardship plan start date
# 32                                                                                                                                                                                                    The end date of the hardship plan period
# 33                                                                                                                                                                                     Flags whether or not the borrower is on a hardship plan
# 34                                                                                                                                                                                  The last payment amount as of the hardship plan start date
# 35                                                                                                                                 The number of months the borrower will make smaller payments than normally obligated due to a hardship plan
# 36                                                                                                                                                                                              Loan Status as of the hardship plan start date
# 37                                                                                                                                                                                The payoff balance amount as of the hardship plan start date
# 38                                                                                                                                                                                          Describes the reason the hardship plan was offered
# 39                                                                                                                                                                                                  The start date of the hardship plan period
# 40                                                                                                                                                           Describes if the hardship plan is active, pending, canceled, completed, or broken
# 41                                                                                                                                                                                                        Describes the hardship plan offering
# 42                                                                                       The home ownership status provided by the borrower during registration or obtained from the credit report. Our values are: RENT, OWN, MORTGAGE, OTHER
# 43                                                                                                                                                                                               A unique LC assigned ID for the loan listing.
# 44                                                                                                                                                              Ratio of total current balance to high credit/credit limit on all install acct
# 45                                                                                                                                                                          The initial listing status of the loan. Possible values are – W, F
# 46                                                                                                                                                                                                        Number of personal finance inquiries
# 47                                                                                                                                                                                                Number of credit inquiries in past 12 months
# 48                                                                                                                                                            The number of inquiries in past 6 months (excluding auto and mortgage inquiries)
# 49                                                                                                                                                                            The monthly payment owed by the borrower if the loan originates.
# 50                                                                                                                                                                                                                   Interest Rate on the loan
# 51                                                                                                                                                                                                         The month which the loan was funded
# 52                                                                                                                                                                                        The most recent month LC pulled credit for this loan
# 53                                                                                                                                                                        The upper boundary range the borrower’s last FICO pulled belongs to.
# 54                                                                                                                                                                        The lower boundary range the borrower’s last FICO pulled belongs to.
# 55                                                                                                                                                                                                          Last total payment amount received
# 56                                                                                                                                                                                                             Last month payment was received
# 57                                                                The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value.
# 58                                                                                                                                                                                                                  Current status of the loan
# 59                                                                                                                                                                                      Maximum current balance owed on all revolving accounts
# 60                                                                                                                                                                                            A unique LC assigned Id for the borrower member.
# 61                                                                                                                                                                                         Months since oldest bank installment account opened
# 62                                                                                                                                                                                                Months since oldest revolving account opened
# 63                                                                                                                                                                                           Months since most recent revolving account opened
# 64                                                                                                                                                                                                     Months since most recent account opened
# 65                                                                                                                                                                                                                Number of mortgage accounts.
# 66                                                                                                                                                                                 The number of months since the borrower's last delinquency.
# 67                                                                                                                                                                                             Months since most recent 90-day or worse rating
# 68                                                                                                                                                                                          The number of months since the last public record.
# 69                                                                                                                                                                                        Months since most recent installment accounts opened
# 70                                                                                                                                                                                           Months since most recent bankcard account opened.
# 71                                                                                                                                                                                               Months since most recent bankcard delinquency
# 72                                                                                                                                                                                                           Months since most recent inquiry.
# 73                                                                                                                                                                                             Months since most recent revolving delinquency.
# 74                                                                                                                                                                                                                 Next scheduled payment date
# 75                                                                                                                                                                                           Number of accounts ever 120 or more days past due
# 76                                                                                                                                                                                                Number of currently active bankcard accounts
# 77                                                                                                                                                                                                 Number of currently active revolving trades
# 78                                                                                                                                                                                                    Number of satisfactory bankcard accounts
# 79                                                                                                                                                                                                                 Number of bankcard accounts
# 80                                                                                                                                                                                                              Number of installment accounts
# 81                                                                                                                                                                                                           Number of open revolving accounts
# 82                                                                                                                                                                                                                Number of revolving accounts
# 83                                                                                                                                                                                                  Number of revolving trades with balance >0
# 84                                                                                                                                                                                                             Number of satisfactory accounts
# 85                                                                                                                                                                   Number of accounts currently 120 days past due (updated in past 2 months)
# 86                                                                                                                                                                    Number of accounts currently 30 days past due (updated in past 2 months)
# 87                                                                                                                                                                               Number of accounts 90 or more days past due in last 24 months
# 88                                                                                                                                                                                                 Number of accounts opened in past 12 months
# 89                                                                                                                                                                              The number of open credit lines in the borrower's credit file.
# 90                                                                                                                                                                                                      Number of open trades in last 6 months
# 91                                                                                                                                                                                               Number of currently active installment trades
# 92                                                                                                                                                                                     Number of installment accounts opened in past 12 months
# 93                                                                                                                                                                                     Number of installment accounts opened in past 24 months
# 94                                                                                                                                                                                         Number of revolving trades opened in past 12 months
# 95                                                                                                                                                                                         Number of revolving trades opened in past 24 months
# 96                       The original projected additional interest amount that will accrue for the given hardship payment plan as of the Hardship Start Date. This field will be null if the borrower has broken their hardship payment plan.
# 97                                                                                                                                                                                     Remaining outstanding principal for total amount funded
# 98                                                                                                                                                             Remaining outstanding principal for portion of total amount funded by investors
# 99   The day the first hardship plan payment is due. For example, if a borrower has a hardship plan period of 3 months, the start date is the start of the three-month period in which the borrower is allowed to make interest-only payments.
# 100                                                                                                                                                                                                         Percent of trades never delinquent
# 101                                                                                                                                                                                        Percentage of all bankcard accounts > 75% of limit.
# 102                                                                                                                                                        publicly available policy_code=1\nnew products not publicly available policy_code=2
# 103                                                                                                                                                                                                        Number of derogatory public records
# 104                                                                                                                                                                                                       Number of public record bankruptcies
# 105                                                                                                                                                                                 A category provided by the borrower for the loan request.
# 106                                                                                                                                                                             Indicates if a payment plan has been put in place for the loan
# 107                                                                                                                                                                                                             post charge off gross recovery
# 108                                                                                                                                                                                                             Total credit revolving balance
# 109                                                                                                                                                             Sum of revolving credit balance of the co-borrowers, net of duplicate balances
# 110                                                                                                                 Revolving line utilization rate, or the amount of credit the borrower is using relative to all available revolving credit.
# 111                                                                                                                                             Number of charge-offs within last 12 months at time of application for the secondary applicant
# 112                                                                                                               Number of collections within last 12 months excluding medical collections at time of application for the secondary applicant
# 113                                                                                                                                                                    Earliest credit line at time of application for the secondary applicant
# 114                                                                                                                                                                                               FICO range (low) for the secondary applicant
# 115                                                                                                                                                                                              FICO range (high) for the secondary applicant
# 116                                                                                                                                                   Credit inquiries in the last 6 months at time of application for the secondary applicant
# 117                                                                                                                                                             Number of mortgage accounts at time of application for the secondary applicant
# 118                                                                                                                                         Months since most recent 90-day or worse rating at time of application for the secondary applicant
# 119                                                                                                                                                            Number of revolving accounts at time of application for the secondary applicant
# 120                                                                                                                                                                   Number of open trades at time of application for the secondary applicant
# 121                                                                                                                                           Number of currently active installment trades at time of application for the secondary applicant
# 122                                                                                                                                                      Ratio of total current balance to high credit/credit limit for all revolving accounts
# 123                                                                                                                                                                                 The loan amount that the borrower has agreed to settle for
# 124                                                                                                                                                                                   The date that the borrower agrees to the settlement plan
# 125                                                                                                                                                             The settlement amount as a percentage of the payoff balance amount on the loan
# 126                                                                                                                      The status of the borrower’s settlement plan. Possible values are: COMPLETE, ACTIVE, BROKEN, CANCELLED, DENIED, DRAFT
# 127                                                                                                                                                                      The number of months that the borrower will be on the settlement plan
# 128                                                                                                                                                                                                                  LC assigned loan subgrade
# 129                                                                                                                                                                                                                        Number of tax liens
# 130                                                                                                                                                       The number of payments on the loan. Values are in months and can be either 36 or 60.
# 131                                                                                                                                                                                                    The loan title provided by the borrower
# 132                                                                                                                                                                                                         Total collection amounts ever owed
# 133                                                                                                                                                                                                      Total current balance of all accounts
# 134                                                                                                                                                                                                             Total high credit/credit limit
# 135                                                                                                                                                                   The total number of credit lines currently in the borrower's credit file
# 136                                                                                                                                                                                                    Total credit balance excluding mortgage
# 137                                                                                                                                                                                          Total current balance of all installment accounts
# 138                                                                                                                                                                                                    Total bankcard high credit/credit limit
# 139                                                                                                                                                                                                                   Number of finance trades
# 140                                                                                                                                                                                                 Total installment high credit/credit limit
# 141                                                                                                                                                                                          Payments received to date for total amount funded
# 142                                                                                                                                                                  Payments received to date for portion of total amount funded by investors
# 143                                                                                                                                                                                                                  Interest received to date
# 144                                                                                                                                                                                                                 Late fees received to date
# 145                                                                                                                                                                                                                 Principal received to date
# 146                                                                                                                                                                                                   Total revolving high credit/credit limit
# 147                                                                                                                                                                                                     URL for the LC page with listing data.
# 148                                                                                                                                                 Indicates if income was verified by LC, not verified, or if the income source was verified
# 149                                                                                                                         Indicates if the co-borrowers' joint income was verified by LC, not verified, or if the income source was verified
# 150                                                                                                                                                      The first 3 numbers of the zip code provided by the borrower in the loan application.
# 151                                                                                                                                                                                                                                        NaN
# 152                                                                                                                                                               * Employer Title replaces Employer Name for all loans listed after 9/23/2013

# %%
lending_club.select_dtypes(object).head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#          term int_rate grade sub_grade       emp_title emp_length  \
# 0   36 months   13.08%     B        B5         cashier  10+ years
# 1   60 months    9.16%     B        B2             ABM    6 years
# 2   36 months   10.49%     B        B3          driver  10+ years
# 3   60 months   11.05%     B        B4             NaN        NaN
# 4   60 months   13.59%     C        C2  Shipping Clerk  10+ years
#
#   home_ownership verification_status   issue_d loan_status pymnt_plan  \
# 0       MORTGAGE     Source Verified  Mar-2020     Current          n
# 1           RENT     Source Verified  Feb-2016     Current          n
# 2       MORTGAGE        Not Verified  Jan-2015  Fully Paid          n
# 3       MORTGAGE        Not Verified  Jun-2018     Current          n
# 4       MORTGAGE     Source Verified  Jan-2018  Fully Paid          n
#
#                                                                   url  \
# 0  https://lendingclub.com/browse/loanDetail.action?loan_id=167338079
# 1   https://lendingclub.com/browse/loanDetail.action?loan_id=71016917
# 2   https://lendingclub.com/browse/loanDetail.action?loan_id=39589826
# 3  https://lendingclub.com/browse/loanDetail.action?loan_id=134798709
# 4  https://lendingclub.com/browse/loanDetail.action?loan_id=127097355
#
#               purpose                    title zip_code addr_state  \
# 0    home_improvement         Home improvement    115xx         NY
# 1         credit_card  Credit card refinancing    708xx         LA
# 2         credit_card  Credit card refinancing    347xx         FL
# 3  debt_consolidation       Debt consolidation    443xx         OH
# 4  debt_consolidation       Debt consolidation    681xx         NE
#
#   earliest_cr_line revol_util initial_list_status last_pymnt_d next_pymnt_d  \
# 0         Dec-2004      82.8%                   w     May-2020     Jun-2020
# 1         Jan-2004      64.5%                   w     May-2020     Jun-2020
# 2         Apr-2010      52.6%                   f     Jan-2018          NaN
# 3         Oct-2005      12.1%                   w     May-2020     Jun-2020
# 4         Apr-2008      27.1%                   w     Jul-2019          NaN
#
#   last_credit_pull_d application_type verification_status_joint  \
# 0           May-2020       Individual                       NaN
# 1           May-2020       Individual                       NaN
# 2           May-2020       Individual                       NaN
# 3           May-2020       Individual                       NaN
# 4           Feb-2020       Individual                       NaN
#
#   sec_app_earliest_cr_line hardship_flag hardship_type hardship_reason  \
# 0                      NaN             N           NaN             NaN
# 1                      NaN             N           NaN             NaN
# 2                      NaN             N           NaN             NaN
# 3                      NaN             N           NaN             NaN
# 4                      NaN             N           NaN             NaN
#
#   hardship_status hardship_start_date hardship_end_date  \
# 0             NaN                 NaN               NaN
# 1             NaN                 NaN               NaN
# 2             NaN                 NaN               NaN
# 3             NaN                 NaN               NaN
# 4             NaN                 NaN               NaN
#
#   payment_plan_start_date hardship_loan_status debt_settlement_flag
# 0                     NaN                  NaN                    N
# 1                     NaN                  NaN                    N
# 2                     NaN                  NaN                    N
# 3                     NaN                  NaN                    N
# 4                     NaN                  NaN                    N

# %%
# Check some features if they are boolean
bool_list = ['pymnt_plan', 'hardship_flag', 'debt_settlement_flag', 'verification_status', 'verification_status_joint', ]
for x in bool_list:
    print(lending_club[x].value_counts())
    print("")
# Out:
# pymnt_plan
# n    100000
# Name: count, dtype: int64
#
# hardship_flag
# N    94507
# Y     4166
# Name: count, dtype: int64
#
# debt_settlement_flag
# N    98244
# Y     1756
# Name: count, dtype: int64
#
# verification_status
# Source Verified    38932
# Not Verified       36467
# Verified           24601
# Name: count, dtype: int64
#
# verification_status_joint
# Not Verified       3350
# Source Verified    1934
# Verified           1347
# Name: count, dtype: int64

# %%
# Define functions to parse different kind of values to numbers
def _parse_pct(x: pd.Series) -> pd.Series:
    return x.str.replace("%", "").astype(float)

def _parse_term(x: pd.Series) -> pd.Series:
    return x.str.replace(" months", "").astype(int)

def _parse_date(x: pd.Series) -> pd.Series:
    return pd.to_datetime(x, format="%b-%Y")

def _parse_bool(x: pd.Series) -> pd.Series:
    return x.where(x.isna(), x=="Y")

# Make a list of percentage features, formatted as string
pct_list = ['int_rate', 'revol_util']

# Make a list of columns that contains dates in text format
date_list = ['issue_d', 'earliest_cr_line', 'last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d',
             'sec_app_earliest_cr_line', 'hardship_start_date', 'hardship_end_date', 'payment_plan_start_date']

# Make a list of boolean features
bool_list = ['pymnt_plan', 'hardship_flag', 'debt_settlement_flag']

# Check functions output
print(f"Parse percentage:\n{_parse_pct(lending_club.int_rate.head())}\n")
print(f"Parse term:\n{_parse_term(lending_club.term.head())}\n")
print(f"Parse date:\n{_parse_date(lending_club.issue_d.head())}\n")
print(f"Parse bool:\n{pd.concat([lending_club.hardship_flag.head(15),_parse_bool(lending_club.hardship_flag.head(15))], axis=1)}\n")
# Out:
# Parse percentage:
# 0    13.08
# 1     9.16
# 2    10.49
# 3    11.05
# 4    13.59
# Name: int_rate, dtype: float64
#
# Parse term:
# 0    36
# 1    60
# 2    36
# 3    60
# 4    60
# Name: term, dtype: int32
#
# Parse date:
# 0   2020-03-01
# 1   2016-02-01
# 2   2015-01-01
# 3   2018-06-01
# 4   2018-01-01
# Name: issue_d, dtype: datetime64[ns]
#
# Parse bool:
#    hardship_flag hardship_flag
# 0              N         False
# 1              N         False
# 2              N         False
# 3              N         False
# 4              N         False
# 5              N         False
# 6              N         False
# 7              N         False
# 8              Y          True
# 9              N         False
# 10           NaN           NaN
# 11             N         False
# 12             N         False
# 13             N         False
# 14             N         False

# %% [markdown]
# Functions defined above where used in `data_processing` pipeline to process raw dataset and save into intermediate dataset with proper data types in `.parquet` format:
# - [nodes.py](https://github.com/Andrii-Chemerys/lending-club/blob/master/src/lending_club/pipelines/data_processing/nodes.py) in `src/lending_club/pipelines/data_processing/nodes.py`
# - [pipeline.py](https://github.com/Andrii-Chemerys/lending-club/blob/master/src/lending_club/pipelines/data_processing/pipeline.py) in `src/lending_club/pipelines/data_processing/pipeline.py`)
#
# Run this pipeline with command:

# %%
# !kedro run -p data_processing
# Out:
# [10/29/24 13:50:11] INFO     Using 'D:\Program                  __init__.py:270
#                              Files\Python\Python
#                              Venv\PowerBI\Lib\site-packages\ked
#                              ro\framework\project\rich_logging.
#                              yml' as logging configuration.
#                     WARNING  D:\Program Files\Python\Python     warnings.py:110
#                              Venv\PowerBI\Lib\site-packages\ked
#                              ro_viz\__init__.py:13:
#                              KedroVizPythonVersionWarning:
#                              Please be advised that Kedro Viz
#                              is not yet fully
#                                      compatible with the Python
#                              version you are currently using.
#                                warnings.warn(
#
# [10/29/24 13:50:13] INFO     Kedro project lending-club          session.py:329
# [10/29/24 13:50:15] INFO     Kedro is sending anonymous usage     plugin.py:233
#                              data with the sole purpose of
#                              improving the product. No personal
#                              data or IP addresses are stored on
#                              our side. If you want to opt out,
#                              set the `KEDRO_DISABLE_TELEMETRY` or
#                              `DO_NOT_TRACK` environment
#                              variables, or create a `.telemetry`
#                              file in the current working
#                              directory with the contents
#                              `consent: false`. Read more at
#                              https://docs.kedro.org/en/stable/con
#                              figuration/telemetry.html
#                     DEBUG    Failed to send data to Heap.         plugin.py:341
#                              Exception of type 'SSLError' was
#                              raised.
#                     INFO     Using synchronous mode for sequential_runner.py:67
#                              loading and saving data.
#                              Use the --async flag for
#                              potential performance
#                              gains.
#                              https://docs.kedro.org/en/
#                              stable/nodes_and_pipelines
#                              /run_a_pipeline.html#load-
#                              and-save-asynchronously
#                     INFO     Loading data from              data_catalog.py:389
#                              original_lc_dataset
#                              (CSVDataset)...
# [10/29/24 13:50:18] INFO     Running node:                          node.py:367
#                              processing_lc([original_lc_dataset])
#                              -> [intermediate_lc_dataset]
# [10/29/24 13:50:20] INFO     Saving data to                 data_catalog.py:431
#                              intermediate_lc_dataset
#                              (ParquetDataset)...
# [10/29/24 13:50:22] INFO     Completed 1 out of 1 tasks sequential_runner.py:93
#                     INFO     Pipeline execution completed         runner.py:125
#                              successfully.

# %% [markdown]
# # Data cleaning
# ---
# New dataset with apropriate data types, produced by `data_processing` pipeline will be used for further data cleaning process

# %%
lending_club = catalog.load("intermediate_lc_dataset")
lending_club.dtypes
# Out:
# [10/29/24 13:53:52] INFO     Loading data from intermediate_lc_dataset (ParquetDataset)...      data_catalog.py:389
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Unnamed: 0.1                                           int64
# Unnamed: 0                                             int64
# loan_amnt                                            float64
# funded_amnt                                          float64
# funded_amnt_inv                                      float64
# term                                                   int32
# int_rate                                             float64
# installment                                          float64
# grade                                                 object
# sub_grade                                             object
# emp_title                                             object
# emp_length                                            object
# home_ownership                                        object
# annual_inc                                           float64
# verification_status                                   object
# issue_d                                       datetime64[ns]
# loan_status                                           object
# pymnt_plan                                            object
# url                                                   object
# purpose                                               object
# title                                                 object
# zip_code                                              object
# addr_state                                            object
# dti                                                  float64
# delinq_2yrs                                          float64
# earliest_cr_line                              datetime64[ns]
# fico_range_low                                       float64
# fico_range_high                                      float64
# inq_last_6mths                                       float64
# mths_since_last_delinq                               float64
# mths_since_last_record                               float64
# open_acc                                             float64
# pub_rec                                              float64
# revol_bal                                            float64
# revol_util                                           float64
# total_acc                                            float64
# initial_list_status                                   object
# out_prncp                                            float64
# out_prncp_inv                                        float64
# total_pymnt                                          float64
# total_pymnt_inv                                      float64
# total_rec_prncp                                      float64
# total_rec_int                                        float64
# total_rec_late_fee                                   float64
# recoveries                                           float64
# collection_recovery_fee                              float64
# last_pymnt_d                                  datetime64[ns]
# last_pymnt_amnt                                      float64
# next_pymnt_d                                  datetime64[ns]
# last_credit_pull_d                            datetime64[ns]
# last_fico_range_high                                 float64
# last_fico_range_low                                  float64
# collections_12_mths_ex_med                           float64
# mths_since_last_major_derog                          float64
# policy_code                                          float64
# application_type                                      object
# annual_inc_joint                                     float64
# dti_joint                                            float64
# verification_status_joint                             object
# acc_now_delinq                                       float64
# tot_coll_amt                                         float64
# tot_cur_bal                                          float64
# open_acc_6m                                          float64
# open_act_il                                          float64
# open_il_12m                                          float64
# open_il_24m                                          float64
# mths_since_rcnt_il                                   float64
# total_bal_il                                         float64
# il_util                                              float64
# open_rv_12m                                          float64
# open_rv_24m                                          float64
# max_bal_bc                                           float64
# all_util                                             float64
# total_rev_hi_lim                                     float64
# inq_fi                                               float64
# total_cu_tl                                          float64
# inq_last_12m                                         float64
# acc_open_past_24mths                                 float64
# avg_cur_bal                                          float64
# bc_open_to_buy                                       float64
# bc_util                                              float64
# chargeoff_within_12_mths                             float64
# delinq_amnt                                          float64
# mo_sin_old_il_acct                                   float64
# mo_sin_old_rev_tl_op                                 float64
# mo_sin_rcnt_rev_tl_op                                float64
# mo_sin_rcnt_tl                                       float64
# mort_acc                                             float64
# mths_since_recent_bc                                 float64
# mths_since_recent_bc_dlq                             float64
# mths_since_recent_inq                                float64
# mths_since_recent_revol_delinq                       float64
# num_accts_ever_120_pd                                float64
# num_actv_bc_tl                                       float64
# num_actv_rev_tl                                      float64
# num_bc_sats                                          float64
# num_bc_tl                                            float64
# num_il_tl                                            float64
# num_op_rev_tl                                        float64
# num_rev_accts                                        float64
# num_rev_tl_bal_gt_0                                  float64
# num_sats                                             float64
# num_tl_120dpd_2m                                     float64
# num_tl_30dpd                                         float64
# num_tl_90g_dpd_24m                                   float64
# num_tl_op_past_12m                                   float64
# pct_tl_nvr_dlq                                       float64
# percent_bc_gt_75                                     float64
# pub_rec_bankruptcies                                 float64
# tax_liens                                            float64
# tot_hi_cred_lim                                      float64
# total_bal_ex_mort                                    float64
# total_bc_limit                                       float64
# total_il_high_credit_limit                           float64
# revol_bal_joint                                      float64
# sec_app_fico_range_low                               float64
# sec_app_fico_range_high                              float64
# sec_app_earliest_cr_line                      datetime64[ns]
# sec_app_inq_last_6mths                               float64
# sec_app_mort_acc                                     float64
# sec_app_open_acc                                     float64
# sec_app_revol_util                                   float64
# sec_app_open_act_il                                  float64
# sec_app_num_rev_accts                                float64
# sec_app_chargeoff_within_12_mths                     float64
# sec_app_collections_12_mths_ex_med                   float64
# hardship_flag                                         object
# hardship_type                                         object
# hardship_reason                                       object
# hardship_status                                       object
# deferral_term                                        float64
# hardship_amount                                      float64
# hardship_start_date                           datetime64[ns]
# hardship_end_date                             datetime64[ns]
# payment_plan_start_date                       datetime64[ns]
# hardship_length                                      float64
# hardship_dpd                                         float64
# hardship_loan_status                                  object
# orig_projected_additional_accrued_interest           float64
# hardship_payoff_balance_amount                       float64
# hardship_last_payment_amount                         float64
# debt_settlement_flag                                    bool
# dtype: object

# %%
unique_val = lending_club.select_dtypes(object).nunique()
missing_val = lending_club.select_dtypes(object).isna().sum()
cat_feat = pd.DataFrame({'unique_val':unique_val, 'missing_val':missing_val}).sort_values(by='unique_val', ascending=False)
cat_feat
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                            unique_val  missing_val
# url                            100000            0
# emp_title                       40094         8954
# title                            3455          780
# zip_code                          878            0
# addr_state                         51            0
# sub_grade                          35            0
# hardship_reason                    17        95105
# purpose                            14            0
# emp_length                         11         6950
# loan_status                        10            0
# hardship_loan_status                9        95116
# grade                               7            0
# hardship_type                       6        95105
# home_ownership                      6            0
# hardship_status                     4        95105
# verification_status                 3            0
# verification_status_joint           3        93369
# initial_list_status                 2            0
# application_type                    2            0
# hardship_flag                       2         1327
# pymnt_plan                          1            0

# %%
# Define function to drop unnecessary features
def _drop_features(df: pd.DataFrame, drop_list: list) -> pd.DataFrame:
    return df.drop(drop_list, axis=1)

# Prepare dictionary-like parameters for 'parameters_data_clean.yml'
data_clean_dict = {
    # List of columns that makes no sense or has too much categorical unique values and will be droped
    'drop_list': ['Unnamed: 0.1', 'Unnamed: 0', 'url', 'emp_title', 'title', 'zip_code']
}
# Print parameter list for 'parameters_data_clean.yml'
print("drop_list:")
for x in drop_list:
    print(f"    - {x}")
# Out:
# drop_list:
#     - Unnamed: 0.1
#     - Unnamed: 0
#     - url
#     - emp_title
#     - title
#     - zip_code

# %%
#
